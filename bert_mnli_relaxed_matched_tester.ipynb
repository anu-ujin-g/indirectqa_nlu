# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install transformers==2.5.1
# Out:
# Requirement already satisfied: transformers==2.5.1 in /usr/local/lib/python3.7/dist-packages (2.5.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers==2.5.1) (4.41.1)
# Requirement already satisfied: tokenizers==0.5.2 in /usr/local/lib/python3.7/dist-packages (from transformers==2.5.1) (0.5.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers==2.5.1) (2019.12.20)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.7/dist-packages (from transformers==2.5.1) (0.1.95)
# Requirement already satisfied: sacremoses in /usr/local/lib/python3.7/dist-packages (from transformers==2.5.1) (0.0.45)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from transformers==2.5.1) (1.19.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers==2.5.1) (2.23.0)
# Requirement already satisfied: boto3 in /usr/local/lib/python3.7/dist-packages (from transformers==2.5.1) (1.17.54)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers==2.5.1) (3.0.12)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==2.5.1) (1.15.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==2.5.1) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==2.5.1) (1.0.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==2.5.1) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==2.5.1) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==2.5.1) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==2.5.1) (2020.12.5)
# Requirement already satisfied: s3transfer<0.5.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from boto3->transformers==2.5.1) (0.4.0)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /usr/local/lib/python3.7/dist-packages (from boto3->transformers==2.5.1) (0.10.0)
# Requirement already satisfied: botocore<1.21.0,>=1.20.54 in /usr/local/lib/python3.7/dist-packages (from boto3->transformers==2.5.1) (1.20.54)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.7/dist-packages (from botocore<1.21.0,>=1.20.54->boto3->transformers==2.5.1) (2.8.1)

# %%
import torch
import torch.nn as nn 
from torch.utils.data import DataLoader, RandomSampler, SequentialSampler, TensorDataset
from transformers import AutoTokenizer, AutoModelForSequenceClassification, AdamW, get_linear_schedule_with_warmup
# from transformers import AutoTokenizer, BertTokenizer, EvalPrediction, BertPreTrainedModel, BertConfig, BertModel, BertForSequenceClassification, AdamW, get_linear_schedule_with_warmup

import random
import pandas as pd
import numpy as np
from tqdm import tqdm

from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score

# %%
    import torch
    torch.cuda.empty_cache()

# %%
cd '/content/drive/MyDrive/'
# Out:
# /content/drive/MyDrive

# %% [markdown]
# ## Data pre-processing

# %% [markdown]
# Relaxed-matched

# %%
# circa_og = pd.read_csv('NLU_Project/circa-data.tsv', sep='\t', index_col='id')
circa_og = pd.read_csv('/content/drive/MyDrive/AMBER_TENG_NYU_DRIVE_TO_BROWN/NYU_SPRING2021/NLU/NLU_Project/circa-data.tsv', sep='\t', index_col='id')
circa_r = circa_og.drop(circa_og.loc[circa_og['goldstandard2']=='Other'].index)
circa_r = circa_r.drop(circa_r.loc[circa_r['goldstandard2'].isnull()].index)

# %%
YN_r = (circa_r['question-X'].map(str)+' '+circa_r['answer-Y']).apply(lambda row: row.strip())
relaxed_labels = circa_r['goldstandard2'].unique()
relaxed_label = circa_r['goldstandard2']
relaxed_dict = {}
for idx, label in enumerate(relaxed_labels):
    relaxed_dict[label] = idx
circa_r['relaxed'] = circa_r.goldstandard2.replace(relaxed_dict)
relaxed = circa_r['relaxed']

# %% [markdown]
# ## Modeling

# %%
import tensorflow as tf

# Get the GPU device name.
device_name = tf.test.gpu_device_name()
print(device_name)

if torch.cuda.is_available():    

    # Tell PyTorch to use the GPU.    
    device = torch.device("cuda")
# Out:
# /device:GPU:0

# %% [markdown]
# ### Relaxed

# %%
from transformers import PreTrainedModel
from transformers import BertConfig, BertModel
from transformers.modeling_tf_bert import TFBertForSequenceClassification
from transformers import BertForSequenceClassification

# %% [markdown]
# ## Model Specs
# - BERT-MNLI-YN Relaxed learning rate: 5e-5
# - MNLI learning rate: 2e-5 ; 3 epochs; batch size 16 vs 32
#   - https://huggingface.co/ishan/bert-base-uncased-mnli
#   - The training parameters were kept the same as Devlin et al., 2019 (learning rate = 2e-5, training epochs = 3, max_sequence_len = 128 and batch_size = 32).
# - BERT-MNLI-YN Strict learning rate: 2e-5

# %%
# tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased") 
tokenizer = AutoTokenizer.from_pretrained('ishan/bert-base-uncased-mnli') 
model = BertForSequenceClassification.from_pretrained(
    "bert-base-uncased", # Use the 12-layer BERT model, with an uncased vocab.
    num_labels = 3, # The number of output labels--2 for binary classification.
                    # You can increase this for multi-class tasks.   
    output_attentions = False, # Whether the model returns attentions weights.
    output_hidden_states = False, # Whether the model returns all hidden-states.
)
# device = torch.device("cpu")
# Tell pytorch to run this model on the GPU.
# model.cuda()
model.to(device)

learning_rate = 5e-5
optimizer = AdamW(model.parameters(), lr=learning_rate, eps=1e-8)

# %%
torch.cuda.memory_summary(device=None, abbreviated=False)
# Out:
# '|===========================================================================|\n|                  PyTorch CUDA memory summary, device ID 0                 |\n|---------------------------------------------------------------------------|\n|            CUDA OOMs: 0            |        cudaMalloc retries: 0         |\n|===========================================================================|\n|        Metric         | Cur Usage  | Peak Usage | Tot Alloc  | Tot Freed  |\n|---------------------------------------------------------------------------|\n| Allocated memory      |    2934 MB |    2934 MB |   16360 GB |   16357 GB |\n|       from large pool |    2931 MB |    2931 MB |   13132 GB |   13129 GB |\n|       from small pool |       3 MB |      93 MB |    3227 GB |    3227 GB |\n|---------------------------------------------------------------------------|\n| Active memory         |    2934 MB |    2934 MB |   16360 GB |   16357 GB |\n|       from large pool |    2931 MB |    2931 MB |   13132 GB |   13129 GB |\n|       from small pool |       3 MB |      93 MB |    3227 GB |    3227 GB |\n|---------------------------------------------------------------------------|\n| GPU reserved memory   |    3190 MB |    3190 MB |    3608 MB |  428032 KB |\n|       from large pool |    3180 MB |    3180 MB |    3490 MB |  317440 KB |\n|       from small pool |      10 MB |     118 MB |     118 MB |  110592 KB |\n|---------------------------------------------------------------------------|\n| Non-releasable memory |  261226 KB |  274792 KB |   27118 GB |   27118 GB |\n|       from large pool |  254464 KB |  254464 KB |   23511 GB |   23510 GB |\n|       from small pool |    6762 KB |   29032 KB |    3607 GB |    3607 GB |\n|---------------------------------------------------------------------------|\n| Allocations           |    1415    |    1471    |   15619 K  |   15618 K  |\n|       from large pool |     525    |     525    |    3192 K  |    3191 K  |\n|       from small pool |     890    |     965    |   12427 K  |   12426 K  |\n|---------------------------------------------------------------------------|\n| Active allocs         |    1415    |    1471    |   15619 K  |   15618 K  |\n|       from large pool |     525    |     525    |    3192 K  |    3191 K  |\n|       from small pool |     890    |     965    |   12427 K  |   12426 K  |\n|---------------------------------------------------------------------------|\n| GPU reserved segments |     136    |     182    |     202    |      66    |\n|       from large pool |     131    |     131    |     143    |      12    |\n|       from small pool |       5    |      59    |      59    |      54    |\n|---------------------------------------------------------------------------|\n| Non-releasable allocs |     138    |     172    |    6118 K  |    6118 K  |\n|       from large pool |     118    |     118    |    1786 K  |    1786 K  |\n|       from small pool |      20    |      62    |    4331 K  |    4331 K  |\n|===========================================================================|\n'

# %%
max_len = 0
for entry in YN_r.values:
    input_ids = tokenizer.encode(entry,  add_special_tokens=True)
    max_len = max(max_len, len(input_ids))
print(max_len)
# Out:
# 43

# %%
df = pd.concat([YN_r, relaxed_label, relaxed], axis=1).rename(columns={0:'YN_r'})
df
# Out:
#                                                     YN_r  ... relaxed
# id                                                        ...
# 0         Are you employed? I'm a veterinary technician.  ...       0
# 1        Are you a fan of Korean food? I wouldn't say so  ...       1
# 2      Are you bringing any pets into the flat? I do ...  ...       1
# 3      Would you like to get some fresh air in your f...  ...       0
# 4      Is your family still living in the neighborhoo...  ...       2
# ...                                                  ...  ...     ...
# 34263                  Do you like to drink? I am in AA.  ...       1
# 34264         Do you like pie? My favorite pie is pecan.  ...       0
# 34265  Want to go to a concert with me? I'd rather do...  ...       1
# 34266  Do you like hip/hop music? I can't dance to hi...  ...       1
# 34267  Do you see yourself raising a family in New Yo...  ...       1
#
# [32993 rows x 3 columns]

# %%
train_relaxed, val_relaxed, trainy_relaxed, valy_relaxed = train_test_split(df.index.values, df.relaxed.values, test_size=.4, stratify=df.relaxed.values)
test_relaxed, dev_relaxed, testy_relaxed, devy_relaxed = train_test_split(val_relaxed, valy_relaxed, test_size=.5, stratify=valy_relaxed)

# %%
df['data_type'] = ['not_set']*df.shape[0]
df.loc[train_relaxed,'data_type'] = 'train'
df.loc[dev_relaxed,'data_type'] = 'dev'
df.loc[test_relaxed,'data_type'] = 'test'

# %%
df.groupby(['goldstandard2','relaxed','data_type']).count()
# Out:
#                                                      YN_r
# goldstandard2                     relaxed data_type
# In the middle, neither yes nor no 2       dev         190
#                                           test        190
#                                           train       569
# No                                1       dev        2566
#                                           test       2567
#                                           train      7700
# Yes                               0       dev        3326
#                                           test       3326
#                                           train      9976
# Yes, subject to some conditions   3       dev         517
#                                           test        516
#                                           train      1550

# %%
encoded_data_train = tokenizer.batch_encode_plus(
    df[df.data_type=='train'].YN_r.values, 
    add_special_tokens=True, 
    return_attention_mask=True, 
    pad_to_max_length=True, 
    max_length=256, 
    return_tensors='pt'
)

encoded_data_dev = tokenizer.batch_encode_plus(
    df[df.data_type=='dev'].YN_r.values, 
    add_special_tokens=True, 
    return_attention_mask=True, 
    pad_to_max_length=True, 
    max_length=256, 
    return_tensors='pt'
)


input_ids_train = encoded_data_train['input_ids']
attention_masks_train = encoded_data_train['attention_mask']
labels_train = torch.tensor(df[df.data_type=='train'].relaxed.values)

input_ids_dev = encoded_data_dev['input_ids']
attention_masks_dev = encoded_data_dev['attention_mask']
labels_dev = torch.tensor(df[df.data_type=='dev'].relaxed.values)

# %%
dataset_train = TensorDataset(input_ids_train, attention_masks_train, labels_train)
dataset_dev = TensorDataset(input_ids_dev, attention_masks_dev, labels_dev)

# %%
len(dataset_train)
# Out:
# 19795

# %%
# model
# relaxed_dict
len(relaxed_dict)
# Out:
# 4

# %%
model.classifier
# Out:
# Linear(in_features=768, out_features=3, bias=True)

# %%
# model

# %%
# model = BertForSequenceClassification.from_pretrained("bert-base-uncased",
#                                                       num_labels=len(relaxed_dict),
#                                                       output_attentions=False,
#                                                       output_hidden_states=False)

# model = BertForSequenceClassification.from_pretrained('ishan/bert-base-uncased-mnli',
#                                                       num_labels=4,
#                                                       # num_labels=len(relaxed_dict),
#                                                       output_attentions=False,
#                                                       output_hidden_states=False)
model.classifier = torch.nn.Linear(model.classifier.in_features, 4)
model.num_labels = 4
optimizer = AdamW(model.parameters(), lr=learning_rate, eps=1e-8)
model.to(device)
# Out:
# BertForSequenceClassification(
#   (bert): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(30522, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (1): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (2): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (3): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (4): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (5): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (6): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (7): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (8): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (9): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (10): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (11): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (dropout): Dropout(p=0.1, inplace=False)
#   (classifier): Linear(in_features=768, out_features=4, bias=True)
# )

# %%
# batch_size = 32
batch_size = 16

dataloader_train = DataLoader(dataset_train, 
                              sampler=RandomSampler(dataset_train), 
                              batch_size=batch_size)

dataloader_validation = DataLoader(dataset_dev, 
                                   sampler=SequentialSampler(dataset_dev), 
                                   batch_size=batch_size)

optimizer = AdamW(model.parameters(),
                  lr = learning_rate,
                  eps = 1e-8)

# %%
# epochs = 3
epochs = 2
total_steps = len(dataloader_train) * epochs
scheduler = get_linear_schedule_with_warmup(optimizer, 
                                            num_warmup_steps = 0, 
                                            num_training_steps = total_steps)

# %%
def f1_score_func(preds, labels):
    preds_flat = np.argmax(preds, axis=1).flatten()
    labels_flat = labels.flatten()
    return f1_score(labels_flat, preds_flat, average='weighted')

def accuracy_per_class(preds, labels):
    label_dict_inverse = {v: k for k, v in relaxed_dict.items()}
    
    preds_flat = np.argmax(preds, axis=1).flatten()
    labels_flat = labels.flatten()

    for label in np.unique(labels_flat):
        y_preds = preds_flat[labels_flat==label]
        y_true = labels_flat[labels_flat==label]
        print(f'Class: {label_dict_inverse[label]}')
        print(f'Accuracy: {len(y_preds[y_preds==label])}/{len(y_true)} = {len(y_preds[y_preds==label])/len(y_true)}\n')

def flat_accuracy(preds, labels):
    pred_flat = np.argmax(preds, axis=1).flatten()
    labels_flat = labels.flatten()
    return np.sum(pred_flat == labels_flat) / len(labels_flat)

# %%
seed_val = 42

random.seed(seed_val)
np.random.seed(seed_val)
torch.manual_seed(seed_val)
torch.cuda.manual_seed_all(seed_val)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# device = torch.device('cpu')
model.to(device)

print(device)
# Out:
# cuda

# %%
def evaluate(dataloader_val):

    model.eval()
    
    loss_val_total = 0
    predictions, true_vals = [], []
    
    for batch in dataloader_val:
        
        batch = tuple(b.to(device) for b in batch)
        
        inputs = {'input_ids':      batch[0],
                  'attention_mask': batch[1],
                  'labels':         batch[2],
                 }

        with torch.no_grad():        
            outputs = model(**inputs)
            
        loss = outputs[0]
        logits = outputs[1]
        loss_val_total += loss.item()

        logits = logits.detach().cpu().numpy()
        label_ids = inputs['labels'].cpu().numpy()
        predictions.append(logits)
        true_vals.append(label_ids)
    
    loss_val_avg = loss_val_total/len(dataloader_val) 
    
    predictions = np.concatenate(predictions, axis=0)
    true_vals = np.concatenate(true_vals, axis=0)
            
    return loss_val_avg, predictions, true_vals

# %%
for epoch in tqdm(range(1, epochs+1)):
    
    model.train()
    
    loss_train_total = 0

    progress_bar = tqdm(dataloader_train, desc='Epoch {:1d}'.format(epoch), leave=False, disable=False)
    for batch in progress_bar:

        model.zero_grad()
        
        batch = tuple(b.to(device) for b in batch)
        
        inputs = {'input_ids':      batch[0],
                  'attention_mask': batch[1],
                  'labels':         batch[2],
                 }       

        outputs = model(**inputs)
        
        loss = outputs[0]
        loss_train_total += loss.item()
        loss.backward()

        torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)

        optimizer.step()
        # scheduler.step()
        
        progress_bar.set_postfix({'training_loss': '{:.3f}'.format(loss.item()/len(batch))})
         
        
    torch.save(model.state_dict(), f'finetuned_BERT_relaxed_epoch_{epoch}.model')
        
    tqdm.write(f'\nEpoch {epoch}')
    
    loss_train_avg = loss_train_total/len(dataloader_train)            
    tqdm.write(f'Training loss: {loss_train_avg}')
    
    dev_loss, predictions, true_vals = evaluate(dataloader_validation)
    dev_f1 = f1_score_func(predictions, true_vals)
    tqdm.write(f'Validation loss: {dev_loss}')
    tqdm.write(f'F1 Score (Weighted): {dev_f1}')
# Out:
# Streaming output truncated to the last 5000 lines.
#
# Epoch 1:  33%|███▎      | 407/1238 [09:23<19:10,  1.38s/it, training_loss=0.288]
#
#
# Epoch 1:  33%|███▎      | 408/1238 [09:23<19:07,  1.38s/it, training_loss=0.288]
#
#
# Epoch 1:  33%|███▎      | 408/1238 [09:25<19:07,  1.38s/it, training_loss=0.137]
#
#
# Epoch 1:  33%|███▎      | 409/1238 [09:25<19:03,  1.38s/it, training_loss=0.137]
#
#
# Epoch 1:  33%|███▎      | 409/1238 [09:26<19:03,  1.38s/it, training_loss=0.124]
#
#
# Epoch 1:  33%|███▎      | 410/1238 [09:26<19:04,  1.38s/it, training_loss=0.124]
#
#
# Epoch 1:  33%|███▎      | 410/1238 [09:27<19:04,  1.38s/it, training_loss=0.245]
#
#
# Epoch 1:  33%|███▎      | 411/1238 [09:27<19:02,  1.38s/it, training_loss=0.245]
#
#
# Epoch 1:  33%|███▎      | 411/1238 [09:29<19:02,  1.38s/it, training_loss=0.237]
#
#
# Epoch 1:  33%|███▎      | 412/1238 [09:29<18:58,  1.38s/it, training_loss=0.237]
#
#
# Epoch 1:  33%|███▎      | 412/1238 [09:30<18:58,  1.38s/it, training_loss=0.091]
#
#
# Epoch 1:  33%|███▎      | 413/1238 [09:30<18:55,  1.38s/it, training_loss=0.091]
#
#
# Epoch 1:  33%|███▎      | 413/1238 [09:32<18:55,  1.38s/it, training_loss=0.289]
#
#
# Epoch 1:  33%|███▎      | 414/1238 [09:32<18:52,  1.37s/it, training_loss=0.289]
#
#
# Epoch 1:  33%|███▎      | 414/1238 [09:33<18:52,  1.37s/it, training_loss=0.206]
#
#
# Epoch 1:  34%|███▎      | 415/1238 [09:33<18:53,  1.38s/it, training_loss=0.206]
#
#
# Epoch 1:  34%|███▎      | 415/1238 [09:34<18:53,  1.38s/it, training_loss=0.210]
#
#
# Epoch 1:  34%|███▎      | 416/1238 [09:34<18:50,  1.37s/it, training_loss=0.210]
#
#
# Epoch 1:  34%|███▎      | 416/1238 [09:36<18:50,  1.37s/it, training_loss=0.152]
#
#
# Epoch 1:  34%|███▎      | 417/1238 [09:36<18:48,  1.37s/it, training_loss=0.152]
#
#
# Epoch 1:  34%|███▎      | 417/1238 [09:37<18:48,  1.37s/it, training_loss=0.158]
#
#
# Epoch 1:  34%|███▍      | 418/1238 [09:37<18:49,  1.38s/it, training_loss=0.158]
#
#
# Epoch 1:  34%|███▍      | 418/1238 [09:39<18:49,  1.38s/it, training_loss=0.238]
#
#
# Epoch 1:  34%|███▍      | 419/1238 [09:39<18:54,  1.39s/it, training_loss=0.238]
#
#
# Epoch 1:  34%|███▍      | 419/1238 [09:40<18:54,  1.39s/it, training_loss=0.152]
#
#
# Epoch 1:  34%|███▍      | 420/1238 [09:40<18:51,  1.38s/it, training_loss=0.152]
#
#
# Epoch 1:  34%|███▍      | 420/1238 [09:41<18:51,  1.38s/it, training_loss=0.074]
#
#
# Epoch 1:  34%|███▍      | 421/1238 [09:41<18:48,  1.38s/it, training_loss=0.074]
#
#
# Epoch 1:  34%|███▍      | 421/1238 [09:43<18:48,  1.38s/it, training_loss=0.300]
#
#
# Epoch 1:  34%|███▍      | 422/1238 [09:43<18:51,  1.39s/it, training_loss=0.300]
#
#
# Epoch 1:  34%|███▍      | 422/1238 [09:44<18:51,  1.39s/it, training_loss=0.090]
#
#
# Epoch 1:  34%|███▍      | 423/1238 [09:44<18:48,  1.38s/it, training_loss=0.090]
#
#
# Epoch 1:  34%|███▍      | 423/1238 [09:45<18:48,  1.38s/it, training_loss=0.178]
#
#
# Epoch 1:  34%|███▍      | 424/1238 [09:45<18:45,  1.38s/it, training_loss=0.178]
#
#
# Epoch 1:  34%|███▍      | 424/1238 [09:47<18:45,  1.38s/it, training_loss=0.131]
#
#
# Epoch 1:  34%|███▍      | 425/1238 [09:47<18:45,  1.38s/it, training_loss=0.131]
#
#
# Epoch 1:  34%|███▍      | 425/1238 [09:48<18:45,  1.38s/it, training_loss=0.270]
#
#
# Epoch 1:  34%|███▍      | 426/1238 [09:48<18:40,  1.38s/it, training_loss=0.270]
#
#
# Epoch 1:  34%|███▍      | 426/1238 [09:50<18:40,  1.38s/it, training_loss=0.166]
#
#
# Epoch 1:  34%|███▍      | 427/1238 [09:50<18:37,  1.38s/it, training_loss=0.166]
#
#
# Epoch 1:  34%|███▍      | 427/1238 [09:51<18:37,  1.38s/it, training_loss=0.054]
#
#
# Epoch 1:  35%|███▍      | 428/1238 [09:51<18:38,  1.38s/it, training_loss=0.054]
#
#
# Epoch 1:  35%|███▍      | 428/1238 [09:52<18:38,  1.38s/it, training_loss=0.230]
#
#
# Epoch 1:  35%|███▍      | 429/1238 [09:52<18:41,  1.39s/it, training_loss=0.230]
#
#
# Epoch 1:  35%|███▍      | 429/1238 [09:54<18:41,  1.39s/it, training_loss=0.169]
#
#
# Epoch 1:  35%|███▍      | 430/1238 [09:54<18:37,  1.38s/it, training_loss=0.169]
#
#
# Epoch 1:  35%|███▍      | 430/1238 [09:55<18:37,  1.38s/it, training_loss=0.258]
#
#
# Epoch 1:  35%|███▍      | 431/1238 [09:55<18:33,  1.38s/it, training_loss=0.258]
#
#
# Epoch 1:  35%|███▍      | 431/1238 [09:56<18:33,  1.38s/it, training_loss=0.144]
#
#
# Epoch 1:  35%|███▍      | 432/1238 [09:56<18:33,  1.38s/it, training_loss=0.144]
#
#
# Epoch 1:  35%|███▍      | 432/1238 [09:58<18:33,  1.38s/it, training_loss=0.182]
#
#
# Epoch 1:  35%|███▍      | 433/1238 [09:58<18:32,  1.38s/it, training_loss=0.182]
#
#
# Epoch 1:  35%|███▍      | 433/1238 [09:59<18:32,  1.38s/it, training_loss=0.245]
#
#
# Epoch 1:  35%|███▌      | 434/1238 [09:59<18:30,  1.38s/it, training_loss=0.245]
#
#
# Epoch 1:  35%|███▌      | 434/1238 [10:01<18:30,  1.38s/it, training_loss=0.258]
#
#
# Epoch 1:  35%|███▌      | 435/1238 [10:01<18:28,  1.38s/it, training_loss=0.258]
#
#
# Epoch 1:  35%|███▌      | 435/1238 [10:02<18:28,  1.38s/it, training_loss=0.119]
#
#
# Epoch 1:  35%|███▌      | 436/1238 [10:02<18:28,  1.38s/it, training_loss=0.119]
#
#
# Epoch 1:  35%|███▌      | 436/1238 [10:03<18:28,  1.38s/it, training_loss=0.148]
#
#
# Epoch 1:  35%|███▌      | 437/1238 [10:03<18:24,  1.38s/it, training_loss=0.148]
#
#
# Epoch 1:  35%|███▌      | 437/1238 [10:05<18:24,  1.38s/it, training_loss=0.184]
#
#
# Epoch 1:  35%|███▌      | 438/1238 [10:05<18:25,  1.38s/it, training_loss=0.184]
#
#
# Epoch 1:  35%|███▌      | 438/1238 [10:06<18:25,  1.38s/it, training_loss=0.188]
#
#
# Epoch 1:  35%|███▌      | 439/1238 [10:06<18:24,  1.38s/it, training_loss=0.188]
#
#
# Epoch 1:  35%|███▌      | 439/1238 [10:08<18:24,  1.38s/it, training_loss=0.139]
#
#
# Epoch 1:  36%|███▌      | 440/1238 [10:08<18:21,  1.38s/it, training_loss=0.139]
#
#
# Epoch 1:  36%|███▌      | 440/1238 [10:09<18:21,  1.38s/it, training_loss=0.151]
#
#
# Epoch 1:  36%|███▌      | 441/1238 [10:09<18:17,  1.38s/it, training_loss=0.151]
#
#
# Epoch 1:  36%|███▌      | 441/1238 [10:10<18:17,  1.38s/it, training_loss=0.156]
#
#
# Epoch 1:  36%|███▌      | 442/1238 [10:10<18:17,  1.38s/it, training_loss=0.156]
#
#
# Epoch 1:  36%|███▌      | 442/1238 [10:12<18:17,  1.38s/it, training_loss=0.163]
#
#
# Epoch 1:  36%|███▌      | 443/1238 [10:12<18:20,  1.38s/it, training_loss=0.163]
#
#
# Epoch 1:  36%|███▌      | 443/1238 [10:13<18:20,  1.38s/it, training_loss=0.224]
#
#
# Epoch 1:  36%|███▌      | 444/1238 [10:13<18:19,  1.39s/it, training_loss=0.224]
#
#
# Epoch 1:  36%|███▌      | 444/1238 [10:14<18:19,  1.39s/it, training_loss=0.282]
#
#
# Epoch 1:  36%|███▌      | 445/1238 [10:14<18:15,  1.38s/it, training_loss=0.282]
#
#
# Epoch 1:  36%|███▌      | 445/1238 [10:16<18:15,  1.38s/it, training_loss=0.235]
#
#
# Epoch 1:  36%|███▌      | 446/1238 [10:16<18:13,  1.38s/it, training_loss=0.235]
#
#
# Epoch 1:  36%|███▌      | 446/1238 [10:17<18:13,  1.38s/it, training_loss=0.246]
#
#
# Epoch 1:  36%|███▌      | 447/1238 [10:17<18:12,  1.38s/it, training_loss=0.246]
#
#
# Epoch 1:  36%|███▌      | 447/1238 [10:19<18:12,  1.38s/it, training_loss=0.275]
#
#
# Epoch 1:  36%|███▌      | 448/1238 [10:19<18:09,  1.38s/it, training_loss=0.275]
#
#
# Epoch 1:  36%|███▌      | 448/1238 [10:20<18:09,  1.38s/it, training_loss=0.175]
#
#
# Epoch 1:  36%|███▋      | 449/1238 [10:20<18:10,  1.38s/it, training_loss=0.175]
#
#
# Epoch 1:  36%|███▋      | 449/1238 [10:21<18:10,  1.38s/it, training_loss=0.141]
#
#
# Epoch 1:  36%|███▋      | 450/1238 [10:21<18:11,  1.38s/it, training_loss=0.141]
#
#
# Epoch 1:  36%|███▋      | 450/1238 [10:23<18:11,  1.38s/it, training_loss=0.220]
#
#
# Epoch 1:  36%|███▋      | 451/1238 [10:23<18:06,  1.38s/it, training_loss=0.220]
#
#
# Epoch 1:  36%|███▋      | 451/1238 [10:24<18:06,  1.38s/it, training_loss=0.293]
#
#
# Epoch 1:  37%|███▋      | 452/1238 [10:24<18:05,  1.38s/it, training_loss=0.293]
#
#
# Epoch 1:  37%|███▋      | 452/1238 [10:25<18:05,  1.38s/it, training_loss=0.190]
#
#
# Epoch 1:  37%|███▋      | 453/1238 [10:25<18:03,  1.38s/it, training_loss=0.190]
#
#
# Epoch 1:  37%|███▋      | 453/1238 [10:27<18:03,  1.38s/it, training_loss=0.213]
#
#
# Epoch 1:  37%|███▋      | 454/1238 [10:27<18:02,  1.38s/it, training_loss=0.213]
#
#
# Epoch 1:  37%|███▋      | 454/1238 [10:28<18:02,  1.38s/it, training_loss=0.248]
#
#
# Epoch 1:  37%|███▋      | 455/1238 [10:28<18:03,  1.38s/it, training_loss=0.248]
#
#
# Epoch 1:  37%|███▋      | 455/1238 [10:30<18:03,  1.38s/it, training_loss=0.209]
#
#
# Epoch 1:  37%|███▋      | 456/1238 [10:30<18:05,  1.39s/it, training_loss=0.209]
#
#
# Epoch 1:  37%|███▋      | 456/1238 [10:31<18:05,  1.39s/it, training_loss=0.277]
#
#
# Epoch 1:  37%|███▋      | 457/1238 [10:31<18:04,  1.39s/it, training_loss=0.277]
#
#
# Epoch 1:  37%|███▋      | 457/1238 [10:32<18:04,  1.39s/it, training_loss=0.121]
#
#
# Epoch 1:  37%|███▋      | 458/1238 [10:32<18:02,  1.39s/it, training_loss=0.121]
#
#
# Epoch 1:  37%|███▋      | 458/1238 [10:34<18:02,  1.39s/it, training_loss=0.090]
#
#
# Epoch 1:  37%|███▋      | 459/1238 [10:34<18:00,  1.39s/it, training_loss=0.090]
#
#
# Epoch 1:  37%|███▋      | 459/1238 [10:35<18:00,  1.39s/it, training_loss=0.173]
#
#
# Epoch 1:  37%|███▋      | 460/1238 [10:35<17:55,  1.38s/it, training_loss=0.173]
#
#
# Epoch 1:  37%|███▋      | 460/1238 [10:37<17:55,  1.38s/it, training_loss=0.215]
#
#
# Epoch 1:  37%|███▋      | 461/1238 [10:37<17:55,  1.38s/it, training_loss=0.215]
#
#
# Epoch 1:  37%|███▋      | 461/1238 [10:38<17:55,  1.38s/it, training_loss=0.159]
#
#
# Epoch 1:  37%|███▋      | 462/1238 [10:38<17:52,  1.38s/it, training_loss=0.159]
#
#
# Epoch 1:  37%|███▋      | 462/1238 [10:39<17:52,  1.38s/it, training_loss=0.167]
#
#
# Epoch 1:  37%|███▋      | 463/1238 [10:39<17:52,  1.38s/it, training_loss=0.167]
#
#
# Epoch 1:  37%|███▋      | 463/1238 [10:41<17:52,  1.38s/it, training_loss=0.120]
#
#
# Epoch 1:  37%|███▋      | 464/1238 [10:41<17:49,  1.38s/it, training_loss=0.120]
#
#
# Epoch 1:  37%|███▋      | 464/1238 [10:42<17:49,  1.38s/it, training_loss=0.244]
#
#
# Epoch 1:  38%|███▊      | 465/1238 [10:42<17:48,  1.38s/it, training_loss=0.244]
#
#
# Epoch 1:  38%|███▊      | 465/1238 [10:43<17:48,  1.38s/it, training_loss=0.162]
#
#
# Epoch 1:  38%|███▊      | 466/1238 [10:43<17:46,  1.38s/it, training_loss=0.162]
#
#
# Epoch 1:  38%|███▊      | 466/1238 [10:45<17:46,  1.38s/it, training_loss=0.247]
#
#
# Epoch 1:  38%|███▊      | 467/1238 [10:45<17:46,  1.38s/it, training_loss=0.247]
#
#
# Epoch 1:  38%|███▊      | 467/1238 [10:46<17:46,  1.38s/it, training_loss=0.222]
#
#
# Epoch 1:  38%|███▊      | 468/1238 [10:46<17:43,  1.38s/it, training_loss=0.222]
#
#
# Epoch 1:  38%|███▊      | 468/1238 [10:48<17:43,  1.38s/it, training_loss=0.069]
#
#
# Epoch 1:  38%|███▊      | 469/1238 [10:48<17:41,  1.38s/it, training_loss=0.069]
#
#
# Epoch 1:  38%|███▊      | 469/1238 [10:49<17:41,  1.38s/it, training_loss=0.185]
#
#
# Epoch 1:  38%|███▊      | 470/1238 [10:49<17:38,  1.38s/it, training_loss=0.185]
#
#
# Epoch 1:  38%|███▊      | 470/1238 [10:50<17:38,  1.38s/it, training_loss=0.130]
#
#
# Epoch 1:  38%|███▊      | 471/1238 [10:50<17:39,  1.38s/it, training_loss=0.130]
#
#
# Epoch 1:  38%|███▊      | 471/1238 [10:52<17:39,  1.38s/it, training_loss=0.189]
#
#
# Epoch 1:  38%|███▊      | 472/1238 [10:52<17:37,  1.38s/it, training_loss=0.189]
#
#
# Epoch 1:  38%|███▊      | 472/1238 [10:53<17:37,  1.38s/it, training_loss=0.070]
#
#
# Epoch 1:  38%|███▊      | 473/1238 [10:53<17:35,  1.38s/it, training_loss=0.070]
#
#
# Epoch 1:  38%|███▊      | 473/1238 [10:55<17:35,  1.38s/it, training_loss=0.147]
#
#
# Epoch 1:  38%|███▊      | 474/1238 [10:55<17:30,  1.38s/it, training_loss=0.147]
#
#
# Epoch 1:  38%|███▊      | 474/1238 [10:56<17:30,  1.38s/it, training_loss=0.090]
#
#
# Epoch 1:  38%|███▊      | 475/1238 [10:56<17:29,  1.38s/it, training_loss=0.090]
#
#
# Epoch 1:  38%|███▊      | 475/1238 [10:57<17:29,  1.38s/it, training_loss=0.167]
#
#
# Epoch 1:  38%|███▊      | 476/1238 [10:57<17:30,  1.38s/it, training_loss=0.167]
#
#
# Epoch 1:  38%|███▊      | 476/1238 [10:59<17:30,  1.38s/it, training_loss=0.213]
#
#
# Epoch 1:  39%|███▊      | 477/1238 [10:59<17:27,  1.38s/it, training_loss=0.213]
#
#
# Epoch 1:  39%|███▊      | 477/1238 [11:00<17:27,  1.38s/it, training_loss=0.415]
#
#
# Epoch 1:  39%|███▊      | 478/1238 [11:00<17:25,  1.38s/it, training_loss=0.415]
#
#
# Epoch 1:  39%|███▊      | 478/1238 [11:01<17:25,  1.38s/it, training_loss=0.242]
#
#
# Epoch 1:  39%|███▊      | 479/1238 [11:01<17:26,  1.38s/it, training_loss=0.242]
#
#
# Epoch 1:  39%|███▊      | 479/1238 [11:03<17:26,  1.38s/it, training_loss=0.154]
#
#
# Epoch 1:  39%|███▉      | 480/1238 [11:03<17:25,  1.38s/it, training_loss=0.154]
#
#
# Epoch 1:  39%|███▉      | 480/1238 [11:04<17:25,  1.38s/it, training_loss=0.362]
#
#
# Epoch 1:  39%|███▉      | 481/1238 [11:04<17:26,  1.38s/it, training_loss=0.362]
#
#
# Epoch 1:  39%|███▉      | 481/1238 [11:06<17:26,  1.38s/it, training_loss=0.197]
#
#
# Epoch 1:  39%|███▉      | 482/1238 [11:06<17:27,  1.39s/it, training_loss=0.197]
#
#
# Epoch 1:  39%|███▉      | 482/1238 [11:07<17:27,  1.39s/it, training_loss=0.106]
#
#
# Epoch 1:  39%|███▉      | 483/1238 [11:07<17:24,  1.38s/it, training_loss=0.106]
#
#
# Epoch 1:  39%|███▉      | 483/1238 [11:08<17:24,  1.38s/it, training_loss=0.195]
#
#
# Epoch 1:  39%|███▉      | 484/1238 [11:08<17:20,  1.38s/it, training_loss=0.195]
#
#
# Epoch 1:  39%|███▉      | 484/1238 [11:10<17:20,  1.38s/it, training_loss=0.168]
#
#
# Epoch 1:  39%|███▉      | 485/1238 [11:10<17:17,  1.38s/it, training_loss=0.168]
#
#
# Epoch 1:  39%|███▉      | 485/1238 [11:11<17:17,  1.38s/it, training_loss=0.300]
#
#
# Epoch 1:  39%|███▉      | 486/1238 [11:11<17:13,  1.37s/it, training_loss=0.300]
#
#
# Epoch 1:  39%|███▉      | 486/1238 [11:12<17:13,  1.37s/it, training_loss=0.125]
#
#
# Epoch 1:  39%|███▉      | 487/1238 [11:12<17:12,  1.37s/it, training_loss=0.125]
#
#
# Epoch 1:  39%|███▉      | 487/1238 [11:14<17:12,  1.37s/it, training_loss=0.152]
#
#
# Epoch 1:  39%|███▉      | 488/1238 [11:14<17:13,  1.38s/it, training_loss=0.152]
#
#
# Epoch 1:  39%|███▉      | 488/1238 [11:15<17:13,  1.38s/it, training_loss=0.209]
#
#
# Epoch 1:  39%|███▉      | 489/1238 [11:15<17:12,  1.38s/it, training_loss=0.209]
#
#
# Epoch 1:  39%|███▉      | 489/1238 [11:17<17:12,  1.38s/it, training_loss=0.140]
#
#
# Epoch 1:  40%|███▉      | 490/1238 [11:17<17:10,  1.38s/it, training_loss=0.140]
#
#
# Epoch 1:  40%|███▉      | 490/1238 [11:18<17:10,  1.38s/it, training_loss=0.114]
#
#
# Epoch 1:  40%|███▉      | 491/1238 [11:18<17:12,  1.38s/it, training_loss=0.114]
#
#
# Epoch 1:  40%|███▉      | 491/1238 [11:19<17:12,  1.38s/it, training_loss=0.100]
#
#
# Epoch 1:  40%|███▉      | 492/1238 [11:19<17:09,  1.38s/it, training_loss=0.100]
#
#
# Epoch 1:  40%|███▉      | 492/1238 [11:21<17:09,  1.38s/it, training_loss=0.305]
#
#
# Epoch 1:  40%|███▉      | 493/1238 [11:21<17:08,  1.38s/it, training_loss=0.305]
#
#
# Epoch 1:  40%|███▉      | 493/1238 [11:22<17:08,  1.38s/it, training_loss=0.197]
#
#
# Epoch 1:  40%|███▉      | 494/1238 [11:22<17:06,  1.38s/it, training_loss=0.197]
#
#
# Epoch 1:  40%|███▉      | 494/1238 [11:23<17:06,  1.38s/it, training_loss=0.178]
#
#
# Epoch 1:  40%|███▉      | 495/1238 [11:23<17:04,  1.38s/it, training_loss=0.178]
#
#
# Epoch 1:  40%|███▉      | 495/1238 [11:25<17:04,  1.38s/it, training_loss=0.124]
#
#
# Epoch 1:  40%|████      | 496/1238 [11:25<17:03,  1.38s/it, training_loss=0.124]
#
#
# Epoch 1:  40%|████      | 496/1238 [11:26<17:03,  1.38s/it, training_loss=0.259]
#
#
# Epoch 1:  40%|████      | 497/1238 [11:26<17:01,  1.38s/it, training_loss=0.259]
#
#
# Epoch 1:  40%|████      | 497/1238 [11:28<17:01,  1.38s/it, training_loss=0.253]
#
#
# Epoch 1:  40%|████      | 498/1238 [11:28<16:59,  1.38s/it, training_loss=0.253]
#
#
# Epoch 1:  40%|████      | 498/1238 [11:29<16:59,  1.38s/it, training_loss=0.336]
#
#
# Epoch 1:  40%|████      | 499/1238 [11:29<16:58,  1.38s/it, training_loss=0.336]
#
#
# Epoch 1:  40%|████      | 499/1238 [11:30<16:58,  1.38s/it, training_loss=0.121]
#
#
# Epoch 1:  40%|████      | 500/1238 [11:30<16:59,  1.38s/it, training_loss=0.121]
#
#
# Epoch 1:  40%|████      | 500/1238 [11:32<16:59,  1.38s/it, training_loss=0.111]
#
#
# Epoch 1:  40%|████      | 501/1238 [11:32<16:56,  1.38s/it, training_loss=0.111]
#
#
# Epoch 1:  40%|████      | 501/1238 [11:33<16:56,  1.38s/it, training_loss=0.132]
#
#
# Epoch 1:  41%|████      | 502/1238 [11:33<16:59,  1.39s/it, training_loss=0.132]
#
#
# Epoch 1:  41%|████      | 502/1238 [11:35<16:59,  1.39s/it, training_loss=0.220]
#
#
# Epoch 1:  41%|████      | 503/1238 [11:35<16:56,  1.38s/it, training_loss=0.220]
#
#
# Epoch 1:  41%|████      | 503/1238 [11:36<16:56,  1.38s/it, training_loss=0.140]
#
#
# Epoch 1:  41%|████      | 504/1238 [11:36<16:54,  1.38s/it, training_loss=0.140]
#
#
# Epoch 1:  41%|████      | 504/1238 [11:37<16:54,  1.38s/it, training_loss=0.191]
#
#
# Epoch 1:  41%|████      | 505/1238 [11:37<16:49,  1.38s/it, training_loss=0.191]
#
#
# Epoch 1:  41%|████      | 505/1238 [11:39<16:49,  1.38s/it, training_loss=0.105]
#
#
# Epoch 1:  41%|████      | 506/1238 [11:39<16:51,  1.38s/it, training_loss=0.105]
#
#
# Epoch 1:  41%|████      | 506/1238 [11:40<16:51,  1.38s/it, training_loss=0.115]
#
#
# Epoch 1:  41%|████      | 507/1238 [11:40<16:47,  1.38s/it, training_loss=0.115]
#
#
# Epoch 1:  41%|████      | 507/1238 [11:41<16:47,  1.38s/it, training_loss=0.193]
#
#
# Epoch 1:  41%|████      | 508/1238 [11:41<16:50,  1.38s/it, training_loss=0.193]
#
#
# Epoch 1:  41%|████      | 508/1238 [11:43<16:50,  1.38s/it, training_loss=0.313]
#
#
# Epoch 1:  41%|████      | 509/1238 [11:43<16:46,  1.38s/it, training_loss=0.313]
#
#
# Epoch 1:  41%|████      | 509/1238 [11:44<16:46,  1.38s/it, training_loss=0.332]
#
#
# Epoch 1:  41%|████      | 510/1238 [11:44<16:45,  1.38s/it, training_loss=0.332]
#
#
# Epoch 1:  41%|████      | 510/1238 [11:46<16:45,  1.38s/it, training_loss=0.206]
#
#
# Epoch 1:  41%|████▏     | 511/1238 [11:46<16:47,  1.39s/it, training_loss=0.206]
#
#
# Epoch 1:  41%|████▏     | 511/1238 [11:47<16:47,  1.39s/it, training_loss=0.218]
#
#
# Epoch 1:  41%|████▏     | 512/1238 [11:47<16:44,  1.38s/it, training_loss=0.218]
#
#
# Epoch 1:  41%|████▏     | 512/1238 [11:48<16:44,  1.38s/it, training_loss=0.244]
#
#
# Epoch 1:  41%|████▏     | 513/1238 [11:48<16:40,  1.38s/it, training_loss=0.244]
#
#
# Epoch 1:  41%|████▏     | 513/1238 [11:50<16:40,  1.38s/it, training_loss=0.174]
#
#
# Epoch 1:  42%|████▏     | 514/1238 [11:50<16:38,  1.38s/it, training_loss=0.174]
#
#
# Epoch 1:  42%|████▏     | 514/1238 [11:51<16:38,  1.38s/it, training_loss=0.212]
#
#
# Epoch 1:  42%|████▏     | 515/1238 [11:51<16:35,  1.38s/it, training_loss=0.212]
#
#
# Epoch 1:  42%|████▏     | 515/1238 [11:52<16:35,  1.38s/it, training_loss=0.131]
#
#
# Epoch 1:  42%|████▏     | 516/1238 [11:52<16:34,  1.38s/it, training_loss=0.131]
#
#
# Epoch 1:  42%|████▏     | 516/1238 [11:54<16:34,  1.38s/it, training_loss=0.244]
#
#
# Epoch 1:  42%|████▏     | 517/1238 [11:54<16:33,  1.38s/it, training_loss=0.244]
#
#
# Epoch 1:  42%|████▏     | 517/1238 [11:55<16:33,  1.38s/it, training_loss=0.138]
#
#
# Epoch 1:  42%|████▏     | 518/1238 [11:55<16:33,  1.38s/it, training_loss=0.138]
#
#
# Epoch 1:  42%|████▏     | 518/1238 [11:57<16:33,  1.38s/it, training_loss=0.238]
#
#
# Epoch 1:  42%|████▏     | 519/1238 [11:57<16:33,  1.38s/it, training_loss=0.238]
#
#
# Epoch 1:  42%|████▏     | 519/1238 [11:58<16:33,  1.38s/it, training_loss=0.142]
#
#
# Epoch 1:  42%|████▏     | 520/1238 [11:58<16:31,  1.38s/it, training_loss=0.142]
#
#
# Epoch 1:  42%|████▏     | 520/1238 [11:59<16:31,  1.38s/it, training_loss=0.257]
#
#
# Epoch 1:  42%|████▏     | 521/1238 [11:59<16:30,  1.38s/it, training_loss=0.257]
#
#
# Epoch 1:  42%|████▏     | 521/1238 [12:01<16:30,  1.38s/it, training_loss=0.220]
#
#
# Epoch 1:  42%|████▏     | 522/1238 [12:01<16:29,  1.38s/it, training_loss=0.220]
#
#
# Epoch 1:  42%|████▏     | 522/1238 [12:02<16:29,  1.38s/it, training_loss=0.186]
#
#
# Epoch 1:  42%|████▏     | 523/1238 [12:02<16:27,  1.38s/it, training_loss=0.186]
#
#
# Epoch 1:  42%|████▏     | 523/1238 [12:04<16:27,  1.38s/it, training_loss=0.181]
#
#
# Epoch 1:  42%|████▏     | 524/1238 [12:04<16:28,  1.38s/it, training_loss=0.181]
#
#
# Epoch 1:  42%|████▏     | 524/1238 [12:05<16:28,  1.38s/it, training_loss=0.151]
#
#
# Epoch 1:  42%|████▏     | 525/1238 [12:05<16:28,  1.39s/it, training_loss=0.151]
#
#
# Epoch 1:  42%|████▏     | 525/1238 [12:06<16:28,  1.39s/it, training_loss=0.179]
#
#
# Epoch 1:  42%|████▏     | 526/1238 [12:06<16:25,  1.38s/it, training_loss=0.179]
#
#
# Epoch 1:  42%|████▏     | 526/1238 [12:08<16:25,  1.38s/it, training_loss=0.134]
#
#
# Epoch 1:  43%|████▎     | 527/1238 [12:08<16:25,  1.39s/it, training_loss=0.134]
#
#
# Epoch 1:  43%|████▎     | 527/1238 [12:09<16:25,  1.39s/it, training_loss=0.281]
#
#
# Epoch 1:  43%|████▎     | 528/1238 [12:09<16:22,  1.38s/it, training_loss=0.281]
#
#
# Epoch 1:  43%|████▎     | 528/1238 [12:10<16:22,  1.38s/it, training_loss=0.054]
#
#
# Epoch 1:  43%|████▎     | 529/1238 [12:10<16:22,  1.39s/it, training_loss=0.054]
#
#
# Epoch 1:  43%|████▎     | 529/1238 [12:12<16:22,  1.39s/it, training_loss=0.158]
#
#
# Epoch 1:  43%|████▎     | 530/1238 [12:12<16:21,  1.39s/it, training_loss=0.158]
#
#
# Epoch 1:  43%|████▎     | 530/1238 [12:13<16:21,  1.39s/it, training_loss=0.126]
#
#
# Epoch 1:  43%|████▎     | 531/1238 [12:13<16:18,  1.38s/it, training_loss=0.126]
#
#
# Epoch 1:  43%|████▎     | 531/1238 [12:15<16:18,  1.38s/it, training_loss=0.138]
#
#
# Epoch 1:  43%|████▎     | 532/1238 [12:15<16:17,  1.38s/it, training_loss=0.138]
#
#
# Epoch 1:  43%|████▎     | 532/1238 [12:16<16:17,  1.38s/it, training_loss=0.065]
#
#
# Epoch 1:  43%|████▎     | 533/1238 [12:16<16:17,  1.39s/it, training_loss=0.065]
#
#
# Epoch 1:  43%|████▎     | 533/1238 [12:17<16:17,  1.39s/it, training_loss=0.168]
#
#
# Epoch 1:  43%|████▎     | 534/1238 [12:17<16:13,  1.38s/it, training_loss=0.168]
#
#
# Epoch 1:  43%|████▎     | 534/1238 [12:19<16:13,  1.38s/it, training_loss=0.114]
#
#
# Epoch 1:  43%|████▎     | 535/1238 [12:19<16:14,  1.39s/it, training_loss=0.114]
#
#
# Epoch 1:  43%|████▎     | 535/1238 [12:20<16:14,  1.39s/it, training_loss=0.292]
#
#
# Epoch 1:  43%|████▎     | 536/1238 [12:20<16:11,  1.38s/it, training_loss=0.292]
#
#
# Epoch 1:  43%|████▎     | 536/1238 [12:22<16:11,  1.38s/it, training_loss=0.352]
#
#
# Epoch 1:  43%|████▎     | 537/1238 [12:22<16:06,  1.38s/it, training_loss=0.352]
#
#
# Epoch 1:  43%|████▎     | 537/1238 [12:23<16:06,  1.38s/it, training_loss=0.271]
#
#
# Epoch 1:  43%|████▎     | 538/1238 [12:23<16:07,  1.38s/it, training_loss=0.271]
#
#
# Epoch 1:  43%|████▎     | 538/1238 [12:24<16:07,  1.38s/it, training_loss=0.104]
#
#
# Epoch 1:  44%|████▎     | 539/1238 [12:24<16:07,  1.38s/it, training_loss=0.104]
#
#
# Epoch 1:  44%|████▎     | 539/1238 [12:26<16:07,  1.38s/it, training_loss=0.159]
#
#
# Epoch 1:  44%|████▎     | 540/1238 [12:26<16:06,  1.38s/it, training_loss=0.159]
#
#
# Epoch 1:  44%|████▎     | 540/1238 [12:27<16:06,  1.38s/it, training_loss=0.180]
#
#
# Epoch 1:  44%|████▎     | 541/1238 [12:27<16:04,  1.38s/it, training_loss=0.180]
#
#
# Epoch 1:  44%|████▎     | 541/1238 [12:28<16:04,  1.38s/it, training_loss=0.159]
#
#
# Epoch 1:  44%|████▍     | 542/1238 [12:28<16:02,  1.38s/it, training_loss=0.159]
#
#
# Epoch 1:  44%|████▍     | 542/1238 [12:30<16:02,  1.38s/it, training_loss=0.284]
#
#
# Epoch 1:  44%|████▍     | 543/1238 [12:30<16:01,  1.38s/it, training_loss=0.284]
#
#
# Epoch 1:  44%|████▍     | 543/1238 [12:31<16:01,  1.38s/it, training_loss=0.238]
#
#
# Epoch 1:  44%|████▍     | 544/1238 [12:31<15:59,  1.38s/it, training_loss=0.238]
#
#
# Epoch 1:  44%|████▍     | 544/1238 [12:33<15:59,  1.38s/it, training_loss=0.328]
#
#
# Epoch 1:  44%|████▍     | 545/1238 [12:33<15:56,  1.38s/it, training_loss=0.328]
#
#
# Epoch 1:  44%|████▍     | 545/1238 [12:34<15:56,  1.38s/it, training_loss=0.060]
#
#
# Epoch 1:  44%|████▍     | 546/1238 [12:34<15:54,  1.38s/it, training_loss=0.060]
#
#
# Epoch 1:  44%|████▍     | 546/1238 [12:35<15:54,  1.38s/it, training_loss=0.200]
#
#
# Epoch 1:  44%|████▍     | 547/1238 [12:35<15:51,  1.38s/it, training_loss=0.200]
#
#
# Epoch 1:  44%|████▍     | 547/1238 [12:37<15:51,  1.38s/it, training_loss=0.159]
#
#
# Epoch 1:  44%|████▍     | 548/1238 [12:37<15:49,  1.38s/it, training_loss=0.159]
#
#
# Epoch 1:  44%|████▍     | 548/1238 [12:38<15:49,  1.38s/it, training_loss=0.138]
#
#
# Epoch 1:  44%|████▍     | 549/1238 [12:38<15:51,  1.38s/it, training_loss=0.138]
#
#
# Epoch 1:  44%|████▍     | 549/1238 [12:39<15:51,  1.38s/it, training_loss=0.118]
#
#
# Epoch 1:  44%|████▍     | 550/1238 [12:39<15:50,  1.38s/it, training_loss=0.118]
#
#
# Epoch 1:  44%|████▍     | 550/1238 [12:41<15:50,  1.38s/it, training_loss=0.103]
#
#
# Epoch 1:  45%|████▍     | 551/1238 [12:41<15:46,  1.38s/it, training_loss=0.103]
#
#
# Epoch 1:  45%|████▍     | 551/1238 [12:42<15:46,  1.38s/it, training_loss=0.171]
#
#
# Epoch 1:  45%|████▍     | 552/1238 [12:42<15:43,  1.38s/it, training_loss=0.171]
#
#
# Epoch 1:  45%|████▍     | 552/1238 [12:44<15:43,  1.38s/it, training_loss=0.098]
#
#
# Epoch 1:  45%|████▍     | 553/1238 [12:44<15:43,  1.38s/it, training_loss=0.098]
#
#
# Epoch 1:  45%|████▍     | 553/1238 [12:45<15:43,  1.38s/it, training_loss=0.053]
#
#
# Epoch 1:  45%|████▍     | 554/1238 [12:45<15:42,  1.38s/it, training_loss=0.053]
#
#
# Epoch 1:  45%|████▍     | 554/1238 [12:46<15:42,  1.38s/it, training_loss=0.213]
#
#
# Epoch 1:  45%|████▍     | 555/1238 [12:46<15:43,  1.38s/it, training_loss=0.213]
#
#
# Epoch 1:  45%|████▍     | 555/1238 [12:48<15:43,  1.38s/it, training_loss=0.140]
#
#
# Epoch 1:  45%|████▍     | 556/1238 [12:48<15:41,  1.38s/it, training_loss=0.140]
#
#
# Epoch 1:  45%|████▍     | 556/1238 [12:49<15:41,  1.38s/it, training_loss=0.108]
#
#
# Epoch 1:  45%|████▍     | 557/1238 [12:49<15:39,  1.38s/it, training_loss=0.108]
#
#
# Epoch 1:  45%|████▍     | 557/1238 [12:51<15:39,  1.38s/it, training_loss=0.216]
#
#
# Epoch 1:  45%|████▌     | 558/1238 [12:51<15:42,  1.39s/it, training_loss=0.216]
#
#
# Epoch 1:  45%|████▌     | 558/1238 [12:52<15:42,  1.39s/it, training_loss=0.359]
#
#
# Epoch 1:  45%|████▌     | 559/1238 [12:52<15:39,  1.38s/it, training_loss=0.359]
#
#
# Epoch 1:  45%|████▌     | 559/1238 [12:53<15:39,  1.38s/it, training_loss=0.164]
#
#
# Epoch 1:  45%|████▌     | 560/1238 [12:53<15:36,  1.38s/it, training_loss=0.164]
#
#
# Epoch 1:  45%|████▌     | 560/1238 [12:55<15:36,  1.38s/it, training_loss=0.354]
#
#
# Epoch 1:  45%|████▌     | 561/1238 [12:55<15:34,  1.38s/it, training_loss=0.354]
#
#
# Epoch 1:  45%|████▌     | 561/1238 [12:56<15:34,  1.38s/it, training_loss=0.207]
#
#
# Epoch 1:  45%|████▌     | 562/1238 [12:56<15:31,  1.38s/it, training_loss=0.207]
#
#
# Epoch 1:  45%|████▌     | 562/1238 [12:57<15:31,  1.38s/it, training_loss=0.178]
#
#
# Epoch 1:  45%|████▌     | 563/1238 [12:57<15:31,  1.38s/it, training_loss=0.178]
#
#
# Epoch 1:  45%|████▌     | 563/1238 [12:59<15:31,  1.38s/it, training_loss=0.106]
#
#
# Epoch 1:  46%|████▌     | 564/1238 [12:59<15:30,  1.38s/it, training_loss=0.106]
#
#
# Epoch 1:  46%|████▌     | 564/1238 [13:00<15:30,  1.38s/it, training_loss=0.251]
#
#
# Epoch 1:  46%|████▌     | 565/1238 [13:00<15:31,  1.38s/it, training_loss=0.251]
#
#
# Epoch 1:  46%|████▌     | 565/1238 [13:02<15:31,  1.38s/it, training_loss=0.152]
#
#
# Epoch 1:  46%|████▌     | 566/1238 [13:02<15:27,  1.38s/it, training_loss=0.152]
#
#
# Epoch 1:  46%|████▌     | 566/1238 [13:03<15:27,  1.38s/it, training_loss=0.250]
#
#
# Epoch 1:  46%|████▌     | 567/1238 [13:03<15:24,  1.38s/it, training_loss=0.250]
#
#
# Epoch 1:  46%|████▌     | 567/1238 [13:04<15:24,  1.38s/it, training_loss=0.269]
#
#
# Epoch 1:  46%|████▌     | 568/1238 [13:04<15:24,  1.38s/it, training_loss=0.269]
#
#
# Epoch 1:  46%|████▌     | 568/1238 [13:06<15:24,  1.38s/it, training_loss=0.195]
#
#
# Epoch 1:  46%|████▌     | 569/1238 [13:06<15:26,  1.38s/it, training_loss=0.195]
#
#
# Epoch 1:  46%|████▌     | 569/1238 [13:07<15:26,  1.38s/it, training_loss=0.139]
#
#
# Epoch 1:  46%|████▌     | 570/1238 [13:07<15:24,  1.38s/it, training_loss=0.139]
#
#
# Epoch 1:  46%|████▌     | 570/1238 [13:08<15:24,  1.38s/it, training_loss=0.170]
#
#
# Epoch 1:  46%|████▌     | 571/1238 [13:08<15:22,  1.38s/it, training_loss=0.170]
#
#
# Epoch 1:  46%|████▌     | 571/1238 [13:10<15:22,  1.38s/it, training_loss=0.159]
#
#
# Epoch 1:  46%|████▌     | 572/1238 [13:10<15:18,  1.38s/it, training_loss=0.159]
#
#
# Epoch 1:  46%|████▌     | 572/1238 [13:11<15:18,  1.38s/it, training_loss=0.220]
#
#
# Epoch 1:  46%|████▋     | 573/1238 [13:11<15:19,  1.38s/it, training_loss=0.220]
#
#
# Epoch 1:  46%|████▋     | 573/1238 [13:13<15:19,  1.38s/it, training_loss=0.189]
#
#
# Epoch 1:  46%|████▋     | 574/1238 [13:13<15:18,  1.38s/it, training_loss=0.189]
#
#
# Epoch 1:  46%|████▋     | 574/1238 [13:14<15:18,  1.38s/it, training_loss=0.178]
#
#
# Epoch 1:  46%|████▋     | 575/1238 [13:14<15:17,  1.38s/it, training_loss=0.178]
#
#
# Epoch 1:  46%|████▋     | 575/1238 [13:15<15:17,  1.38s/it, training_loss=0.162]
#
#
# Epoch 1:  47%|████▋     | 576/1238 [13:15<15:16,  1.38s/it, training_loss=0.162]
#
#
# Epoch 1:  47%|████▋     | 576/1238 [13:17<15:16,  1.38s/it, training_loss=0.163]
#
#
# Epoch 1:  47%|████▋     | 577/1238 [13:17<15:14,  1.38s/it, training_loss=0.163]
#
#
# Epoch 1:  47%|████▋     | 577/1238 [13:18<15:14,  1.38s/it, training_loss=0.077]
#
#
# Epoch 1:  47%|████▋     | 578/1238 [13:18<15:14,  1.39s/it, training_loss=0.077]
#
#
# Epoch 1:  47%|████▋     | 578/1238 [13:20<15:14,  1.39s/it, training_loss=0.405]
#
#
# Epoch 1:  47%|████▋     | 579/1238 [13:20<15:12,  1.38s/it, training_loss=0.405]
#
#
# Epoch 1:  47%|████▋     | 579/1238 [13:21<15:12,  1.38s/it, training_loss=0.182]
#
#
# Epoch 1:  47%|████▋     | 580/1238 [13:21<15:08,  1.38s/it, training_loss=0.182]
#
#
# Epoch 1:  47%|████▋     | 580/1238 [13:22<15:08,  1.38s/it, training_loss=0.261]
#
#
# Epoch 1:  47%|████▋     | 581/1238 [13:22<15:06,  1.38s/it, training_loss=0.261]
#
#
# Epoch 1:  47%|████▋     | 581/1238 [13:24<15:06,  1.38s/it, training_loss=0.137]
#
#
# Epoch 1:  47%|████▋     | 582/1238 [13:24<15:04,  1.38s/it, training_loss=0.137]
#
#
# Epoch 1:  47%|████▋     | 582/1238 [13:25<15:04,  1.38s/it, training_loss=0.199]
#
#
# Epoch 1:  47%|████▋     | 583/1238 [13:25<15:03,  1.38s/it, training_loss=0.199]
#
#
# Epoch 1:  47%|████▋     | 583/1238 [13:26<15:03,  1.38s/it, training_loss=0.112]
#
#
# Epoch 1:  47%|████▋     | 584/1238 [13:26<15:00,  1.38s/it, training_loss=0.112]
#
#
# Epoch 1:  47%|████▋     | 584/1238 [13:28<15:00,  1.38s/it, training_loss=0.094]
#
#
# Epoch 1:  47%|████▋     | 585/1238 [13:28<15:01,  1.38s/it, training_loss=0.094]
#
#
# Epoch 1:  47%|████▋     | 585/1238 [13:29<15:01,  1.38s/it, training_loss=0.087]
#
#
# Epoch 1:  47%|████▋     | 586/1238 [13:29<15:01,  1.38s/it, training_loss=0.087]
#
#
# Epoch 1:  47%|████▋     | 586/1238 [13:31<15:01,  1.38s/it, training_loss=0.124]
#
#
# Epoch 1:  47%|████▋     | 587/1238 [13:31<14:57,  1.38s/it, training_loss=0.124]
#
#
# Epoch 1:  47%|████▋     | 587/1238 [13:32<14:57,  1.38s/it, training_loss=0.124]
#
#
# Epoch 1:  47%|████▋     | 588/1238 [13:32<14:55,  1.38s/it, training_loss=0.124]
#
#
# Epoch 1:  47%|████▋     | 588/1238 [13:33<14:55,  1.38s/it, training_loss=0.190]
#
#
# Epoch 1:  48%|████▊     | 589/1238 [13:33<14:53,  1.38s/it, training_loss=0.190]
#
#
# Epoch 1:  48%|████▊     | 589/1238 [13:35<14:53,  1.38s/it, training_loss=0.129]
#
#
# Epoch 1:  48%|████▊     | 590/1238 [13:35<14:51,  1.38s/it, training_loss=0.129]
#
#
# Epoch 1:  48%|████▊     | 590/1238 [13:36<14:51,  1.38s/it, training_loss=0.114]
#
#
# Epoch 1:  48%|████▊     | 591/1238 [13:36<14:52,  1.38s/it, training_loss=0.114]
#
#
# Epoch 1:  48%|████▊     | 591/1238 [13:37<14:52,  1.38s/it, training_loss=0.223]
#
#
# Epoch 1:  48%|████▊     | 592/1238 [13:37<14:51,  1.38s/it, training_loss=0.223]
#
#
# Epoch 1:  48%|████▊     | 592/1238 [13:39<14:51,  1.38s/it, training_loss=0.110]
#
#
# Epoch 1:  48%|████▊     | 593/1238 [13:39<14:48,  1.38s/it, training_loss=0.110]
#
#
# Epoch 1:  48%|████▊     | 593/1238 [13:40<14:48,  1.38s/it, training_loss=0.255]
#
#
# Epoch 1:  48%|████▊     | 594/1238 [13:40<14:49,  1.38s/it, training_loss=0.255]
#
#
# Epoch 1:  48%|████▊     | 594/1238 [13:42<14:49,  1.38s/it, training_loss=0.067]
#
#
# Epoch 1:  48%|████▊     | 595/1238 [13:42<14:49,  1.38s/it, training_loss=0.067]
#
#
# Epoch 1:  48%|████▊     | 595/1238 [13:43<14:49,  1.38s/it, training_loss=0.359]
#
#
# Epoch 1:  48%|████▊     | 596/1238 [13:43<14:50,  1.39s/it, training_loss=0.359]
#
#
# Epoch 1:  48%|████▊     | 596/1238 [13:44<14:50,  1.39s/it, training_loss=0.154]
#
#
# Epoch 1:  48%|████▊     | 597/1238 [13:44<14:49,  1.39s/it, training_loss=0.154]
#
#
# Epoch 1:  48%|████▊     | 597/1238 [13:46<14:49,  1.39s/it, training_loss=0.327]
#
#
# Epoch 1:  48%|████▊     | 598/1238 [13:46<14:43,  1.38s/it, training_loss=0.327]
#
#
# Epoch 1:  48%|████▊     | 598/1238 [13:47<14:43,  1.38s/it, training_loss=0.195]
#
#
# Epoch 1:  48%|████▊     | 599/1238 [13:47<14:41,  1.38s/it, training_loss=0.195]
#
#
# Epoch 1:  48%|████▊     | 599/1238 [13:49<14:41,  1.38s/it, training_loss=0.098]
#
#
# Epoch 1:  48%|████▊     | 600/1238 [13:49<14:41,  1.38s/it, training_loss=0.098]
#
#
# Epoch 1:  48%|████▊     | 600/1238 [13:50<14:41,  1.38s/it, training_loss=0.174]
#
#
# Epoch 1:  49%|████▊     | 601/1238 [13:50<14:38,  1.38s/it, training_loss=0.174]
#
#
# Epoch 1:  49%|████▊     | 601/1238 [13:51<14:38,  1.38s/it, training_loss=0.114]
#
#
# Epoch 1:  49%|████▊     | 602/1238 [13:51<14:38,  1.38s/it, training_loss=0.114]
#
#
# Epoch 1:  49%|████▊     | 602/1238 [13:53<14:38,  1.38s/it, training_loss=0.221]
#
#
# Epoch 1:  49%|████▊     | 603/1238 [13:53<14:37,  1.38s/it, training_loss=0.221]
#
#
# Epoch 1:  49%|████▊     | 603/1238 [13:54<14:37,  1.38s/it, training_loss=0.173]
#
#
# Epoch 1:  49%|████▉     | 604/1238 [13:54<14:36,  1.38s/it, training_loss=0.173]
#
#
# Epoch 1:  49%|████▉     | 604/1238 [13:55<14:36,  1.38s/it, training_loss=0.256]
#
#
# Epoch 1:  49%|████▉     | 605/1238 [13:55<14:31,  1.38s/it, training_loss=0.256]
#
#
# Epoch 1:  49%|████▉     | 605/1238 [13:57<14:31,  1.38s/it, training_loss=0.131]
#
#
# Epoch 1:  49%|████▉     | 606/1238 [13:57<14:30,  1.38s/it, training_loss=0.131]
#
#
# Epoch 1:  49%|████▉     | 606/1238 [13:58<14:30,  1.38s/it, training_loss=0.184]
#
#
# Epoch 1:  49%|████▉     | 607/1238 [13:58<14:31,  1.38s/it, training_loss=0.184]
#
#
# Epoch 1:  49%|████▉     | 607/1238 [14:00<14:31,  1.38s/it, training_loss=0.184]
#
#
# Epoch 1:  49%|████▉     | 608/1238 [14:00<14:32,  1.38s/it, training_loss=0.184]
#
#
# Epoch 1:  49%|████▉     | 608/1238 [14:01<14:32,  1.38s/it, training_loss=0.191]
#
#
# Epoch 1:  49%|████▉     | 609/1238 [14:01<14:27,  1.38s/it, training_loss=0.191]
#
#
# Epoch 1:  49%|████▉     | 609/1238 [14:02<14:27,  1.38s/it, training_loss=0.145]
#
#
# Epoch 1:  49%|████▉     | 610/1238 [14:02<14:26,  1.38s/it, training_loss=0.145]
#
#
# Epoch 1:  49%|████▉     | 610/1238 [14:04<14:26,  1.38s/it, training_loss=0.151]
#
#
# Epoch 1:  49%|████▉     | 611/1238 [14:04<14:25,  1.38s/it, training_loss=0.151]
#
#
# Epoch 1:  49%|████▉     | 611/1238 [14:05<14:25,  1.38s/it, training_loss=0.149]
#
#
# Epoch 1:  49%|████▉     | 612/1238 [14:05<14:23,  1.38s/it, training_loss=0.149]
#
#
# Epoch 1:  49%|████▉     | 612/1238 [14:06<14:23,  1.38s/it, training_loss=0.242]
#
#
# Epoch 1:  50%|████▉     | 613/1238 [14:06<14:21,  1.38s/it, training_loss=0.242]
#
#
# Epoch 1:  50%|████▉     | 613/1238 [14:08<14:21,  1.38s/it, training_loss=0.192]
#
#
# Epoch 1:  50%|████▉     | 614/1238 [14:08<14:20,  1.38s/it, training_loss=0.192]
#
#
# Epoch 1:  50%|████▉     | 614/1238 [14:09<14:20,  1.38s/it, training_loss=0.136]
#
#
# Epoch 1:  50%|████▉     | 615/1238 [14:09<14:19,  1.38s/it, training_loss=0.136]
#
#
# Epoch 1:  50%|████▉     | 615/1238 [14:11<14:19,  1.38s/it, training_loss=0.090]
#
#
# Epoch 1:  50%|████▉     | 616/1238 [14:11<14:18,  1.38s/it, training_loss=0.090]
#
#
# Epoch 1:  50%|████▉     | 616/1238 [14:12<14:18,  1.38s/it, training_loss=0.081]
#
#
# Epoch 1:  50%|████▉     | 617/1238 [14:12<14:15,  1.38s/it, training_loss=0.081]
#
#
# Epoch 1:  50%|████▉     | 617/1238 [14:13<14:15,  1.38s/it, training_loss=0.275]
#
#
# Epoch 1:  50%|████▉     | 618/1238 [14:13<14:16,  1.38s/it, training_loss=0.275]
#
#
# Epoch 1:  50%|████▉     | 618/1238 [14:15<14:16,  1.38s/it, training_loss=0.186]
#
#
# Epoch 1:  50%|█████     | 619/1238 [14:15<14:15,  1.38s/it, training_loss=0.186]
#
#
# Epoch 1:  50%|█████     | 619/1238 [14:16<14:15,  1.38s/it, training_loss=0.150]
#
#
# Epoch 1:  50%|█████     | 620/1238 [14:16<14:12,  1.38s/it, training_loss=0.150]
#
#
# Epoch 1:  50%|█████     | 620/1238 [14:17<14:12,  1.38s/it, training_loss=0.090]
#
#
# Epoch 1:  50%|█████     | 621/1238 [14:18<14:12,  1.38s/it, training_loss=0.090]
#
#
# Epoch 1:  50%|█████     | 621/1238 [14:19<14:12,  1.38s/it, training_loss=0.074]
#
#
# Epoch 1:  50%|█████     | 622/1238 [14:19<14:09,  1.38s/it, training_loss=0.074]
#
#
# Epoch 1:  50%|█████     | 622/1238 [14:20<14:09,  1.38s/it, training_loss=0.152]
#
#
# Epoch 1:  50%|█████     | 623/1238 [14:20<14:06,  1.38s/it, training_loss=0.152]
#
#
# Epoch 1:  50%|█████     | 623/1238 [14:22<14:06,  1.38s/it, training_loss=0.097]
#
#
# Epoch 1:  50%|█████     | 624/1238 [14:22<14:04,  1.38s/it, training_loss=0.097]
#
#
# Epoch 1:  50%|█████     | 624/1238 [14:23<14:04,  1.38s/it, training_loss=0.166]
#
#
# Epoch 1:  50%|█████     | 625/1238 [14:23<14:03,  1.38s/it, training_loss=0.166]
#
#
# Epoch 1:  50%|█████     | 625/1238 [14:24<14:03,  1.38s/it, training_loss=0.042]
#
#
# Epoch 1:  51%|█████     | 626/1238 [14:24<14:01,  1.37s/it, training_loss=0.042]
#
#
# Epoch 1:  51%|█████     | 626/1238 [14:26<14:01,  1.37s/it, training_loss=0.157]
#
#
# Epoch 1:  51%|█████     | 627/1238 [14:26<14:00,  1.38s/it, training_loss=0.157]
#
#
# Epoch 1:  51%|█████     | 627/1238 [14:27<14:00,  1.38s/it, training_loss=0.229]
#
#
# Epoch 1:  51%|█████     | 628/1238 [14:27<14:00,  1.38s/it, training_loss=0.229]
#
#
# Epoch 1:  51%|█████     | 628/1238 [14:29<14:00,  1.38s/it, training_loss=0.211]
#
#
# Epoch 1:  51%|█████     | 629/1238 [14:29<14:02,  1.38s/it, training_loss=0.211]
#
#
# Epoch 1:  51%|█████     | 629/1238 [14:30<14:02,  1.38s/it, training_loss=0.088]
#
#
# Epoch 1:  51%|█████     | 630/1238 [14:30<13:59,  1.38s/it, training_loss=0.088]
#
#
# Epoch 1:  51%|█████     | 630/1238 [14:31<13:59,  1.38s/it, training_loss=0.081]
#
#
# Epoch 1:  51%|█████     | 631/1238 [14:31<13:58,  1.38s/it, training_loss=0.081]
#
#
# Epoch 1:  51%|█████     | 631/1238 [14:33<13:58,  1.38s/it, training_loss=0.236]
#
#
# Epoch 1:  51%|█████     | 632/1238 [14:33<13:56,  1.38s/it, training_loss=0.236]
#
#
# Epoch 1:  51%|█████     | 632/1238 [14:34<13:56,  1.38s/it, training_loss=0.221]
#
#
# Epoch 1:  51%|█████     | 633/1238 [14:34<13:55,  1.38s/it, training_loss=0.221]
#
#
# Epoch 1:  51%|█████     | 633/1238 [14:35<13:55,  1.38s/it, training_loss=0.096]
#
#
# Epoch 1:  51%|█████     | 634/1238 [14:35<13:53,  1.38s/it, training_loss=0.096]
#
#
# Epoch 1:  51%|█████     | 634/1238 [14:37<13:53,  1.38s/it, training_loss=0.276]
#
#
# Epoch 1:  51%|█████▏    | 635/1238 [14:37<13:50,  1.38s/it, training_loss=0.276]
#
#
# Epoch 1:  51%|█████▏    | 635/1238 [14:38<13:50,  1.38s/it, training_loss=0.116]
#
#
# Epoch 1:  51%|█████▏    | 636/1238 [14:38<13:49,  1.38s/it, training_loss=0.116]
#
#
# Epoch 1:  51%|█████▏    | 636/1238 [14:40<13:49,  1.38s/it, training_loss=0.115]
#
#
# Epoch 1:  51%|█████▏    | 637/1238 [14:40<13:44,  1.37s/it, training_loss=0.115]
#
#
# Epoch 1:  51%|█████▏    | 637/1238 [14:41<13:44,  1.37s/it, training_loss=0.066]
#
#
# Epoch 1:  52%|█████▏    | 638/1238 [14:41<13:44,  1.37s/it, training_loss=0.066]
#
#
# Epoch 1:  52%|█████▏    | 638/1238 [14:42<13:44,  1.37s/it, training_loss=0.142]
#
#
# Epoch 1:  52%|█████▏    | 639/1238 [14:42<13:44,  1.38s/it, training_loss=0.142]
#
#
# Epoch 1:  52%|█████▏    | 639/1238 [14:44<13:44,  1.38s/it, training_loss=0.141]
#
#
# Epoch 1:  52%|█████▏    | 640/1238 [14:44<13:43,  1.38s/it, training_loss=0.141]
#
#
# Epoch 1:  52%|█████▏    | 640/1238 [14:45<13:43,  1.38s/it, training_loss=0.271]
#
#
# Epoch 1:  52%|█████▏    | 641/1238 [14:45<13:41,  1.38s/it, training_loss=0.271]
#
#
# Epoch 1:  52%|█████▏    | 641/1238 [14:46<13:41,  1.38s/it, training_loss=0.429]
#
#
# Epoch 1:  52%|█████▏    | 642/1238 [14:46<13:41,  1.38s/it, training_loss=0.429]
#
#
# Epoch 1:  52%|█████▏    | 642/1238 [14:48<13:41,  1.38s/it, training_loss=0.103]
#
#
# Epoch 1:  52%|█████▏    | 643/1238 [14:48<13:43,  1.38s/it, training_loss=0.103]
#
#
# Epoch 1:  52%|█████▏    | 643/1238 [14:49<13:43,  1.38s/it, training_loss=0.143]
#
#
# Epoch 1:  52%|█████▏    | 644/1238 [14:49<13:40,  1.38s/it, training_loss=0.143]
#
#
# Epoch 1:  52%|█████▏    | 644/1238 [14:51<13:40,  1.38s/it, training_loss=0.200]
#
#
# Epoch 1:  52%|█████▏    | 645/1238 [14:51<13:38,  1.38s/it, training_loss=0.200]
#
#
# Epoch 1:  52%|█████▏    | 645/1238 [14:52<13:38,  1.38s/it, training_loss=0.121]
#
#
# Epoch 1:  52%|█████▏    | 646/1238 [14:52<13:37,  1.38s/it, training_loss=0.121]
#
#
# Epoch 1:  52%|█████▏    | 646/1238 [14:53<13:37,  1.38s/it, training_loss=0.132]
#
#
# Epoch 1:  52%|█████▏    | 647/1238 [14:53<13:35,  1.38s/it, training_loss=0.132]
#
#
# Epoch 1:  52%|█████▏    | 647/1238 [14:55<13:35,  1.38s/it, training_loss=0.127]
#
#
# Epoch 1:  52%|█████▏    | 648/1238 [14:55<13:35,  1.38s/it, training_loss=0.127]
#
#
# Epoch 1:  52%|█████▏    | 648/1238 [14:56<13:35,  1.38s/it, training_loss=0.159]
#
#
# Epoch 1:  52%|█████▏    | 649/1238 [14:56<13:33,  1.38s/it, training_loss=0.159]
#
#
# Epoch 1:  52%|█████▏    | 649/1238 [14:57<13:33,  1.38s/it, training_loss=0.156]
#
#
# Epoch 1:  53%|█████▎    | 650/1238 [14:57<13:31,  1.38s/it, training_loss=0.156]
#
#
# Epoch 1:  53%|█████▎    | 650/1238 [14:59<13:31,  1.38s/it, training_loss=0.062]
#
#
# Epoch 1:  53%|█████▎    | 651/1238 [14:59<13:28,  1.38s/it, training_loss=0.062]
#
#
# Epoch 1:  53%|█████▎    | 651/1238 [15:00<13:28,  1.38s/it, training_loss=0.199]
#
#
# Epoch 1:  53%|█████▎    | 652/1238 [15:00<13:28,  1.38s/it, training_loss=0.199]
#
#
# Epoch 1:  53%|█████▎    | 652/1238 [15:02<13:28,  1.38s/it, training_loss=0.147]
#
#
# Epoch 1:  53%|█████▎    | 653/1238 [15:02<13:27,  1.38s/it, training_loss=0.147]
#
#
# Epoch 1:  53%|█████▎    | 653/1238 [15:03<13:27,  1.38s/it, training_loss=0.140]
#
#
# Epoch 1:  53%|█████▎    | 654/1238 [15:03<13:24,  1.38s/it, training_loss=0.140]
#
#
# Epoch 1:  53%|█████▎    | 654/1238 [15:04<13:24,  1.38s/it, training_loss=0.186]
#
#
# Epoch 1:  53%|█████▎    | 655/1238 [15:04<13:22,  1.38s/it, training_loss=0.186]
#
#
# Epoch 1:  53%|█████▎    | 655/1238 [15:06<13:22,  1.38s/it, training_loss=0.094]
#
#
# Epoch 1:  53%|█████▎    | 656/1238 [15:06<13:23,  1.38s/it, training_loss=0.094]
#
#
# Epoch 1:  53%|█████▎    | 656/1238 [15:07<13:23,  1.38s/it, training_loss=0.186]
#
#
# Epoch 1:  53%|█████▎    | 657/1238 [15:07<13:22,  1.38s/it, training_loss=0.186]
#
#
# Epoch 1:  53%|█████▎    | 657/1238 [15:09<13:22,  1.38s/it, training_loss=0.070]
#
#
# Epoch 1:  53%|█████▎    | 658/1238 [15:09<13:23,  1.38s/it, training_loss=0.070]
#
#
# Epoch 1:  53%|█████▎    | 658/1238 [15:10<13:23,  1.38s/it, training_loss=0.087]
#
#
# Epoch 1:  53%|█████▎    | 659/1238 [15:10<13:20,  1.38s/it, training_loss=0.087]
#
#
# Epoch 1:  53%|█████▎    | 659/1238 [15:11<13:20,  1.38s/it, training_loss=0.163]
#
#
# Epoch 1:  53%|█████▎    | 660/1238 [15:11<13:15,  1.38s/it, training_loss=0.163]
#
#
# Epoch 1:  53%|█████▎    | 660/1238 [15:13<13:15,  1.38s/it, training_loss=0.304]
#
#
# Epoch 1:  53%|█████▎    | 661/1238 [15:13<13:12,  1.37s/it, training_loss=0.304]
#
#
# Epoch 1:  53%|█████▎    | 661/1238 [15:14<13:12,  1.37s/it, training_loss=0.057]
#
#
# Epoch 1:  53%|█████▎    | 662/1238 [15:14<13:12,  1.38s/it, training_loss=0.057]
#
#
# Epoch 1:  53%|█████▎    | 662/1238 [15:15<13:12,  1.38s/it, training_loss=0.098]
#
#
# Epoch 1:  54%|█████▎    | 663/1238 [15:15<13:10,  1.38s/it, training_loss=0.098]
#
#
# Epoch 1:  54%|█████▎    | 663/1238 [15:17<13:10,  1.38s/it, training_loss=0.155]
#
#
# Epoch 1:  54%|█████▎    | 664/1238 [15:17<13:09,  1.38s/it, training_loss=0.155]
#
#
# Epoch 1:  54%|█████▎    | 664/1238 [15:18<13:09,  1.38s/it, training_loss=0.149]
#
#
# Epoch 1:  54%|█████▎    | 665/1238 [15:18<13:07,  1.38s/it, training_loss=0.149]
#
#
# Epoch 1:  54%|█████▎    | 665/1238 [15:20<13:07,  1.38s/it, training_loss=0.233]
#
#
# Epoch 1:  54%|█████▍    | 666/1238 [15:20<13:06,  1.37s/it, training_loss=0.233]
#
#
# Epoch 1:  54%|█████▍    | 666/1238 [15:21<13:06,  1.37s/it, training_loss=0.113]
#
#
# Epoch 1:  54%|█████▍    | 667/1238 [15:21<13:09,  1.38s/it, training_loss=0.113]
#
#
# Epoch 1:  54%|█████▍    | 667/1238 [15:22<13:09,  1.38s/it, training_loss=0.441]
#
#
# Epoch 1:  54%|█████▍    | 668/1238 [15:22<13:08,  1.38s/it, training_loss=0.441]
#
#
# Epoch 1:  54%|█████▍    | 668/1238 [15:24<13:08,  1.38s/it, training_loss=0.055]
#
#
# Epoch 1:  54%|█████▍    | 669/1238 [15:24<13:06,  1.38s/it, training_loss=0.055]
#
#
# Epoch 1:  54%|█████▍    | 669/1238 [15:25<13:06,  1.38s/it, training_loss=0.221]
#
#
# Epoch 1:  54%|█████▍    | 670/1238 [15:25<13:03,  1.38s/it, training_loss=0.221]
#
#
# Epoch 1:  54%|█████▍    | 670/1238 [15:26<13:03,  1.38s/it, training_loss=0.343]
#
#
# Epoch 1:  54%|█████▍    | 671/1238 [15:26<13:01,  1.38s/it, training_loss=0.343]
#
#
# Epoch 1:  54%|█████▍    | 671/1238 [15:28<13:01,  1.38s/it, training_loss=0.197]
#
#
# Epoch 1:  54%|█████▍    | 672/1238 [15:28<12:58,  1.37s/it, training_loss=0.197]
#
#
# Epoch 1:  54%|█████▍    | 672/1238 [15:29<12:58,  1.37s/it, training_loss=0.104]
#
#
# Epoch 1:  54%|█████▍    | 673/1238 [15:29<12:58,  1.38s/it, training_loss=0.104]
#
#
# Epoch 1:  54%|█████▍    | 673/1238 [15:31<12:58,  1.38s/it, training_loss=0.080]
#
#
# Epoch 1:  54%|█████▍    | 674/1238 [15:31<12:57,  1.38s/it, training_loss=0.080]
#
#
# Epoch 1:  54%|█████▍    | 674/1238 [15:32<12:57,  1.38s/it, training_loss=0.074]
#
#
# Epoch 1:  55%|█████▍    | 675/1238 [15:32<12:56,  1.38s/it, training_loss=0.074]
#
#
# Epoch 1:  55%|█████▍    | 675/1238 [15:33<12:56,  1.38s/it, training_loss=0.176]
#
#
# Epoch 1:  55%|█████▍    | 676/1238 [15:33<12:54,  1.38s/it, training_loss=0.176]
#
#
# Epoch 1:  55%|█████▍    | 676/1238 [15:35<12:54,  1.38s/it, training_loss=0.143]
#
#
# Epoch 1:  55%|█████▍    | 677/1238 [15:35<12:54,  1.38s/it, training_loss=0.143]
#
#
# Epoch 1:  55%|█████▍    | 677/1238 [15:36<12:54,  1.38s/it, training_loss=0.101]
#
#
# Epoch 1:  55%|█████▍    | 678/1238 [15:36<12:51,  1.38s/it, training_loss=0.101]
#
#
# Epoch 1:  55%|█████▍    | 678/1238 [15:37<12:51,  1.38s/it, training_loss=0.101]
#
#
# Epoch 1:  55%|█████▍    | 679/1238 [15:37<12:49,  1.38s/it, training_loss=0.101]
#
#
# Epoch 1:  55%|█████▍    | 679/1238 [15:39<12:49,  1.38s/it, training_loss=0.118]
#
#
# Epoch 1:  55%|█████▍    | 680/1238 [15:39<12:47,  1.38s/it, training_loss=0.118]
#
#
# Epoch 1:  55%|█████▍    | 680/1238 [15:40<12:47,  1.38s/it, training_loss=0.314]
#
#
# Epoch 1:  55%|█████▌    | 681/1238 [15:40<12:49,  1.38s/it, training_loss=0.314]
#
#
# Epoch 1:  55%|█████▌    | 681/1238 [15:42<12:49,  1.38s/it, training_loss=0.170]
#
#
# Epoch 1:  55%|█████▌    | 682/1238 [15:42<12:45,  1.38s/it, training_loss=0.170]
#
#
# Epoch 1:  55%|█████▌    | 682/1238 [15:43<12:45,  1.38s/it, training_loss=0.192]
#
#
# Epoch 1:  55%|█████▌    | 683/1238 [15:43<12:46,  1.38s/it, training_loss=0.192]
#
#
# Epoch 1:  55%|█████▌    | 683/1238 [15:44<12:46,  1.38s/it, training_loss=0.192]
#
#
# Epoch 1:  55%|█████▌    | 684/1238 [15:44<12:44,  1.38s/it, training_loss=0.192]
#
#
# Epoch 1:  55%|█████▌    | 684/1238 [15:46<12:44,  1.38s/it, training_loss=0.207]
#
#
# Epoch 1:  55%|█████▌    | 685/1238 [15:46<12:40,  1.37s/it, training_loss=0.207]
#
#
# Epoch 1:  55%|█████▌    | 685/1238 [15:47<12:40,  1.37s/it, training_loss=0.177]
#
#
# Epoch 1:  55%|█████▌    | 686/1238 [15:47<12:37,  1.37s/it, training_loss=0.177]
#
#
# Epoch 1:  55%|█████▌    | 686/1238 [15:48<12:37,  1.37s/it, training_loss=0.151]
#
#
# Epoch 1:  55%|█████▌    | 687/1238 [15:48<12:38,  1.38s/it, training_loss=0.151]
#
#
# Epoch 1:  55%|█████▌    | 687/1238 [15:50<12:38,  1.38s/it, training_loss=0.204]
#
#
# Epoch 1:  56%|█████▌    | 688/1238 [15:50<12:36,  1.38s/it, training_loss=0.204]
#
#
# Epoch 1:  56%|█████▌    | 688/1238 [15:51<12:36,  1.38s/it, training_loss=0.148]
#
#
# Epoch 1:  56%|█████▌    | 689/1238 [15:51<12:35,  1.38s/it, training_loss=0.148]
#
#
# Epoch 1:  56%|█████▌    | 689/1238 [15:53<12:35,  1.38s/it, training_loss=0.129]
#
#
# Epoch 1:  56%|█████▌    | 690/1238 [15:53<12:36,  1.38s/it, training_loss=0.129]
#
#
# Epoch 1:  56%|█████▌    | 690/1238 [15:54<12:36,  1.38s/it, training_loss=0.075]
#
#
# Epoch 1:  56%|█████▌    | 691/1238 [15:54<12:36,  1.38s/it, training_loss=0.075]
#
#
# Epoch 1:  56%|█████▌    | 691/1238 [15:55<12:36,  1.38s/it, training_loss=0.140]
#
#
# Epoch 1:  56%|█████▌    | 692/1238 [15:55<12:35,  1.38s/it, training_loss=0.140]
#
#
# Epoch 1:  56%|█████▌    | 692/1238 [15:57<12:35,  1.38s/it, training_loss=0.175]
#
#
# Epoch 1:  56%|█████▌    | 693/1238 [15:57<12:34,  1.38s/it, training_loss=0.175]
#
#
# Epoch 1:  56%|█████▌    | 693/1238 [15:58<12:34,  1.38s/it, training_loss=0.345]
#
#
# Epoch 1:  56%|█████▌    | 694/1238 [15:58<12:34,  1.39s/it, training_loss=0.345]
#
#
# Epoch 1:  56%|█████▌    | 694/1238 [16:00<12:34,  1.39s/it, training_loss=0.187]
#
#
# Epoch 1:  56%|█████▌    | 695/1238 [16:00<12:30,  1.38s/it, training_loss=0.187]
#
#
# Epoch 1:  56%|█████▌    | 695/1238 [16:01<12:30,  1.38s/it, training_loss=0.198]
#
#
# ...
#
#
# Epoch 2:  93%|█████████▎| 1148/1238 [26:23<02:04,  1.38s/it, training_loss=0.018]
#
#
# Epoch 2:  93%|█████████▎| 1148/1238 [26:25<02:04,  1.38s/it, training_loss=0.019]
#
#
# Epoch 2:  93%|█████████▎| 1149/1238 [26:25<02:03,  1.38s/it, training_loss=0.019]
#
#
# Epoch 2:  93%|█████████▎| 1149/1238 [26:26<02:03,  1.38s/it, training_loss=0.096]
#
#
# Epoch 2:  93%|█████████▎| 1150/1238 [26:26<02:01,  1.38s/it, training_loss=0.096]
#
#
# Epoch 2:  93%|█████████▎| 1150/1238 [26:28<02:01,  1.38s/it, training_loss=0.046]
#
#
# Epoch 2:  93%|█████████▎| 1151/1238 [26:28<02:00,  1.38s/it, training_loss=0.046]
#
#
# Epoch 2:  93%|█████████▎| 1151/1238 [26:29<02:00,  1.38s/it, training_loss=0.108]
#
#
# Epoch 2:  93%|█████████▎| 1152/1238 [26:29<01:58,  1.38s/it, training_loss=0.108]
#
#
# Epoch 2:  93%|█████████▎| 1152/1238 [26:30<01:58,  1.38s/it, training_loss=0.189]
#
#
# Epoch 2:  93%|█████████▎| 1153/1238 [26:30<01:57,  1.38s/it, training_loss=0.189]
#
#
# Epoch 2:  93%|█████████▎| 1153/1238 [26:32<01:57,  1.38s/it, training_loss=0.190]
#
#
# Epoch 2:  93%|█████████▎| 1154/1238 [26:32<01:55,  1.38s/it, training_loss=0.190]
#
#
# Epoch 2:  93%|█████████▎| 1154/1238 [26:33<01:55,  1.38s/it, training_loss=0.059]
#
#
# Epoch 2:  93%|█████████▎| 1155/1238 [26:33<01:54,  1.38s/it, training_loss=0.059]
#
#
# Epoch 2:  93%|█████████▎| 1155/1238 [26:34<01:54,  1.38s/it, training_loss=0.120]
#
#
# Epoch 2:  93%|█████████▎| 1156/1238 [26:34<01:53,  1.38s/it, training_loss=0.120]
#
#
# Epoch 2:  93%|█████████▎| 1156/1238 [26:36<01:53,  1.38s/it, training_loss=0.008]
#
#
# Epoch 2:  93%|█████████▎| 1157/1238 [26:36<01:51,  1.38s/it, training_loss=0.008]
#
#
# Epoch 2:  93%|█████████▎| 1157/1238 [26:37<01:51,  1.38s/it, training_loss=0.106]
#
#
# Epoch 2:  94%|█████████▎| 1158/1238 [26:37<01:50,  1.38s/it, training_loss=0.106]
#
#
# Epoch 2:  94%|█████████▎| 1158/1238 [26:39<01:50,  1.38s/it, training_loss=0.011]
#
#
# Epoch 2:  94%|█████████▎| 1159/1238 [26:39<01:49,  1.38s/it, training_loss=0.011]
#
#
# Epoch 2:  94%|█████████▎| 1159/1238 [26:40<01:49,  1.38s/it, training_loss=0.132]
#
#
# Epoch 2:  94%|█████████▎| 1160/1238 [26:40<01:47,  1.38s/it, training_loss=0.132]
#
#
# Epoch 2:  94%|█████████▎| 1160/1238 [26:41<01:47,  1.38s/it, training_loss=0.125]
#
#
# Epoch 2:  94%|█████████▍| 1161/1238 [26:41<01:46,  1.38s/it, training_loss=0.125]
#
#
# Epoch 2:  94%|█████████▍| 1161/1238 [26:43<01:46,  1.38s/it, training_loss=0.407]
#
#
# Epoch 2:  94%|█████████▍| 1162/1238 [26:43<01:44,  1.38s/it, training_loss=0.407]
#
#
# Epoch 2:  94%|█████████▍| 1162/1238 [26:44<01:44,  1.38s/it, training_loss=0.190]
#
#
# Epoch 2:  94%|█████████▍| 1163/1238 [26:44<01:43,  1.38s/it, training_loss=0.190]
#
#
# Epoch 2:  94%|█████████▍| 1163/1238 [26:46<01:43,  1.38s/it, training_loss=0.134]
#
#
# Epoch 2:  94%|█████████▍| 1164/1238 [26:46<01:42,  1.38s/it, training_loss=0.134]
#
#
# Epoch 2:  94%|█████████▍| 1164/1238 [26:47<01:42,  1.38s/it, training_loss=0.167]
#
#
# Epoch 2:  94%|█████████▍| 1165/1238 [26:47<01:40,  1.38s/it, training_loss=0.167]
#
#
# Epoch 2:  94%|█████████▍| 1165/1238 [26:48<01:40,  1.38s/it, training_loss=0.079]
#
#
# Epoch 2:  94%|█████████▍| 1166/1238 [26:48<01:39,  1.38s/it, training_loss=0.079]
#
#
# Epoch 2:  94%|█████████▍| 1166/1238 [26:50<01:39,  1.38s/it, training_loss=0.357]
#
#
# Epoch 2:  94%|█████████▍| 1167/1238 [26:50<01:37,  1.38s/it, training_loss=0.357]
#
#
# Epoch 2:  94%|█████████▍| 1167/1238 [26:51<01:37,  1.38s/it, training_loss=0.020]
#
#
# Epoch 2:  94%|█████████▍| 1168/1238 [26:51<01:36,  1.38s/it, training_loss=0.020]
#
#
# Epoch 2:  94%|█████████▍| 1168/1238 [26:52<01:36,  1.38s/it, training_loss=0.314]
#
#
# Epoch 2:  94%|█████████▍| 1169/1238 [26:52<01:34,  1.38s/it, training_loss=0.314]
#
#
# Epoch 2:  94%|█████████▍| 1169/1238 [26:54<01:34,  1.38s/it, training_loss=0.046]
#
#
# Epoch 2:  95%|█████████▍| 1170/1238 [26:54<01:33,  1.37s/it, training_loss=0.046]
#
#
# Epoch 2:  95%|█████████▍| 1170/1238 [26:55<01:33,  1.37s/it, training_loss=0.103]
#
#
# Epoch 2:  95%|█████████▍| 1171/1238 [26:55<01:32,  1.37s/it, training_loss=0.103]
#
#
# Epoch 2:  95%|█████████▍| 1171/1238 [26:57<01:32,  1.37s/it, training_loss=0.062]
#
#
# Epoch 2:  95%|█████████▍| 1172/1238 [26:57<01:30,  1.37s/it, training_loss=0.062]
#
#
# Epoch 2:  95%|█████████▍| 1172/1238 [26:58<01:30,  1.37s/it, training_loss=0.238]
#
#
# Epoch 2:  95%|█████████▍| 1173/1238 [26:58<01:29,  1.37s/it, training_loss=0.238]
#
#
# Epoch 2:  95%|█████████▍| 1173/1238 [26:59<01:29,  1.37s/it, training_loss=0.008]
#
#
# Epoch 2:  95%|█████████▍| 1174/1238 [26:59<01:28,  1.38s/it, training_loss=0.008]
#
#
# Epoch 2:  95%|█████████▍| 1174/1238 [27:01<01:28,  1.38s/it, training_loss=0.085]
#
#
# Epoch 2:  95%|█████████▍| 1175/1238 [27:01<01:26,  1.37s/it, training_loss=0.085]
#
#
# Epoch 2:  95%|█████████▍| 1175/1238 [27:02<01:26,  1.37s/it, training_loss=0.078]
#
#
# Epoch 2:  95%|█████████▍| 1176/1238 [27:02<01:25,  1.38s/it, training_loss=0.078]
#
#
# Epoch 2:  95%|█████████▍| 1176/1238 [27:03<01:25,  1.38s/it, training_loss=0.020]
#
#
# Epoch 2:  95%|█████████▌| 1177/1238 [27:03<01:23,  1.38s/it, training_loss=0.020]
#
#
# Epoch 2:  95%|█████████▌| 1177/1238 [27:05<01:23,  1.38s/it, training_loss=0.049]
#
#
# Epoch 2:  95%|█████████▌| 1178/1238 [27:05<01:23,  1.39s/it, training_loss=0.049]
#
#
# Epoch 2:  95%|█████████▌| 1178/1238 [27:06<01:23,  1.39s/it, training_loss=0.031]
#
#
# Epoch 2:  95%|█████████▌| 1179/1238 [27:06<01:21,  1.38s/it, training_loss=0.031]
#
#
# Epoch 2:  95%|█████████▌| 1179/1238 [27:08<01:21,  1.38s/it, training_loss=0.033]
#
#
# Epoch 2:  95%|█████████▌| 1180/1238 [27:08<01:20,  1.38s/it, training_loss=0.033]
#
#
# Epoch 2:  95%|█████████▌| 1180/1238 [27:09<01:20,  1.38s/it, training_loss=0.130]
#
#
# Epoch 2:  95%|█████████▌| 1181/1238 [27:09<01:18,  1.38s/it, training_loss=0.130]
#
#
# Epoch 2:  95%|█████████▌| 1181/1238 [27:10<01:18,  1.38s/it, training_loss=0.108]
#
#
# Epoch 2:  95%|█████████▌| 1182/1238 [27:10<01:17,  1.38s/it, training_loss=0.108]
#
#
# Epoch 2:  95%|█████████▌| 1182/1238 [27:12<01:17,  1.38s/it, training_loss=0.093]
#
#
# Epoch 2:  96%|█████████▌| 1183/1238 [27:12<01:16,  1.38s/it, training_loss=0.093]
#
#
# Epoch 2:  96%|█████████▌| 1183/1238 [27:13<01:16,  1.38s/it, training_loss=0.009]
#
#
# Epoch 2:  96%|█████████▌| 1184/1238 [27:13<01:14,  1.38s/it, training_loss=0.009]
#
#
# Epoch 2:  96%|█████████▌| 1184/1238 [27:14<01:14,  1.38s/it, training_loss=0.062]
#
#
# Epoch 2:  96%|█████████▌| 1185/1238 [27:14<01:13,  1.38s/it, training_loss=0.062]
#
#
# Epoch 2:  96%|█████████▌| 1185/1238 [27:16<01:13,  1.38s/it, training_loss=0.082]
#
#
# Epoch 2:  96%|█████████▌| 1186/1238 [27:16<01:11,  1.38s/it, training_loss=0.082]
#
#
# Epoch 2:  96%|█████████▌| 1186/1238 [27:17<01:11,  1.38s/it, training_loss=0.174]
#
#
# Epoch 2:  96%|█████████▌| 1187/1238 [27:17<01:10,  1.38s/it, training_loss=0.174]
#
#
# Epoch 2:  96%|█████████▌| 1187/1238 [27:19<01:10,  1.38s/it, training_loss=0.063]
#
#
# Epoch 2:  96%|█████████▌| 1188/1238 [27:19<01:08,  1.38s/it, training_loss=0.063]
#
#
# Epoch 2:  96%|█████████▌| 1188/1238 [27:20<01:08,  1.38s/it, training_loss=0.123]
#
#
# Epoch 2:  96%|█████████▌| 1189/1238 [27:20<01:07,  1.38s/it, training_loss=0.123]
#
#
# Epoch 2:  96%|█████████▌| 1189/1238 [27:21<01:07,  1.38s/it, training_loss=0.056]
#
#
# Epoch 2:  96%|█████████▌| 1190/1238 [27:21<01:06,  1.38s/it, training_loss=0.056]
#
#
# Epoch 2:  96%|█████████▌| 1190/1238 [27:23<01:06,  1.38s/it, training_loss=0.125]
#
#
# Epoch 2:  96%|█████████▌| 1191/1238 [27:23<01:04,  1.38s/it, training_loss=0.125]
#
#
# Epoch 2:  96%|█████████▌| 1191/1238 [27:24<01:04,  1.38s/it, training_loss=0.195]
#
#
# Epoch 2:  96%|█████████▋| 1192/1238 [27:24<01:03,  1.38s/it, training_loss=0.195]
#
#
# Epoch 2:  96%|█████████▋| 1192/1238 [27:25<01:03,  1.38s/it, training_loss=0.008]
#
#
# Epoch 2:  96%|█████████▋| 1193/1238 [27:26<01:02,  1.38s/it, training_loss=0.008]
#
#
# Epoch 2:  96%|█████████▋| 1193/1238 [27:27<01:02,  1.38s/it, training_loss=0.088]
#
#
# Epoch 2:  96%|█████████▋| 1194/1238 [27:27<01:00,  1.38s/it, training_loss=0.088]
#
#
# Epoch 2:  96%|█████████▋| 1194/1238 [27:28<01:00,  1.38s/it, training_loss=0.158]
#
#
# Epoch 2:  97%|█████████▋| 1195/1238 [27:28<00:59,  1.38s/it, training_loss=0.158]
#
#
# Epoch 2:  97%|█████████▋| 1195/1238 [27:30<00:59,  1.38s/it, training_loss=0.022]
#
#
# Epoch 2:  97%|█████████▋| 1196/1238 [27:30<00:58,  1.38s/it, training_loss=0.022]
#
#
# Epoch 2:  97%|█████████▋| 1196/1238 [27:31<00:58,  1.38s/it, training_loss=0.031]
#
#
# Epoch 2:  97%|█████████▋| 1197/1238 [27:31<00:56,  1.38s/it, training_loss=0.031]
#
#
# Epoch 2:  97%|█████████▋| 1197/1238 [27:32<00:56,  1.38s/it, training_loss=0.124]
#
#
# Epoch 2:  97%|█████████▋| 1198/1238 [27:32<00:55,  1.39s/it, training_loss=0.124]
#
#
# Epoch 2:  97%|█████████▋| 1198/1238 [27:34<00:55,  1.39s/it, training_loss=0.027]
#
#
# Epoch 2:  97%|█████████▋| 1199/1238 [27:34<00:54,  1.39s/it, training_loss=0.027]
#
#
# Epoch 2:  97%|█████████▋| 1199/1238 [27:35<00:54,  1.39s/it, training_loss=0.225]
#
#
# Epoch 2:  97%|█████████▋| 1200/1238 [27:35<00:52,  1.38s/it, training_loss=0.225]
#
#
# Epoch 2:  97%|█████████▋| 1200/1238 [27:37<00:52,  1.38s/it, training_loss=0.203]
#
#
# Epoch 2:  97%|█████████▋| 1201/1238 [27:37<00:50,  1.38s/it, training_loss=0.203]
#
#
# Epoch 2:  97%|█████████▋| 1201/1238 [27:38<00:50,  1.38s/it, training_loss=0.145]
#
#
# Epoch 2:  97%|█████████▋| 1202/1238 [27:38<00:49,  1.37s/it, training_loss=0.145]
#
#
# Epoch 2:  97%|█████████▋| 1202/1238 [27:39<00:49,  1.37s/it, training_loss=0.076]
#
#
# Epoch 2:  97%|█████████▋| 1203/1238 [27:39<00:48,  1.38s/it, training_loss=0.076]
#
#
# Epoch 2:  97%|█████████▋| 1203/1238 [27:41<00:48,  1.38s/it, training_loss=0.123]
#
#
# Epoch 2:  97%|█████████▋| 1204/1238 [27:41<00:46,  1.38s/it, training_loss=0.123]
#
#
# Epoch 2:  97%|█████████▋| 1204/1238 [27:42<00:46,  1.38s/it, training_loss=0.096]
#
#
# Epoch 2:  97%|█████████▋| 1205/1238 [27:42<00:45,  1.38s/it, training_loss=0.096]
#
#
# Epoch 2:  97%|█████████▋| 1205/1238 [27:43<00:45,  1.38s/it, training_loss=0.129]
#
#
# Epoch 2:  97%|█████████▋| 1206/1238 [27:43<00:44,  1.38s/it, training_loss=0.129]
#
#
# Epoch 2:  97%|█████████▋| 1206/1238 [27:45<00:44,  1.38s/it, training_loss=0.054]
#
#
# Epoch 2:  97%|█████████▋| 1207/1238 [27:45<00:42,  1.38s/it, training_loss=0.054]
#
#
# Epoch 2:  97%|█████████▋| 1207/1238 [27:46<00:42,  1.38s/it, training_loss=0.115]
#
#
# Epoch 2:  98%|█████████▊| 1208/1238 [27:46<00:41,  1.38s/it, training_loss=0.115]
#
#
# Epoch 2:  98%|█████████▊| 1208/1238 [27:48<00:41,  1.38s/it, training_loss=0.125]
#
#
# Epoch 2:  98%|█████████▊| 1209/1238 [27:48<00:40,  1.38s/it, training_loss=0.125]
#
#
# Epoch 2:  98%|█████████▊| 1209/1238 [27:49<00:40,  1.38s/it, training_loss=0.039]
#
#
# Epoch 2:  98%|█████████▊| 1210/1238 [27:49<00:38,  1.38s/it, training_loss=0.039]
#
#
# Epoch 2:  98%|█████████▊| 1210/1238 [27:50<00:38,  1.38s/it, training_loss=0.044]
#
#
# Epoch 2:  98%|█████████▊| 1211/1238 [27:50<00:37,  1.38s/it, training_loss=0.044]
#
#
# Epoch 2:  98%|█████████▊| 1211/1238 [27:52<00:37,  1.38s/it, training_loss=0.106]
#
#
# Epoch 2:  98%|█████████▊| 1212/1238 [27:52<00:35,  1.38s/it, training_loss=0.106]
#
#
# Epoch 2:  98%|█████████▊| 1212/1238 [27:53<00:35,  1.38s/it, training_loss=0.136]
#
#
# Epoch 2:  98%|█████████▊| 1213/1238 [27:53<00:34,  1.38s/it, training_loss=0.136]
#
#
# Epoch 2:  98%|█████████▊| 1213/1238 [27:54<00:34,  1.38s/it, training_loss=0.077]
#
#
# Epoch 2:  98%|█████████▊| 1214/1238 [27:54<00:33,  1.38s/it, training_loss=0.077]
#
#
# Epoch 2:  98%|█████████▊| 1214/1238 [27:56<00:33,  1.38s/it, training_loss=0.058]
#
#
# Epoch 2:  98%|█████████▊| 1215/1238 [27:56<00:31,  1.38s/it, training_loss=0.058]
#
#
# Epoch 2:  98%|█████████▊| 1215/1238 [27:57<00:31,  1.38s/it, training_loss=0.055]
#
#
# Epoch 2:  98%|█████████▊| 1216/1238 [27:57<00:30,  1.38s/it, training_loss=0.055]
#
#
# Epoch 2:  98%|█████████▊| 1216/1238 [27:59<00:30,  1.38s/it, training_loss=0.135]
#
#
# Epoch 2:  98%|█████████▊| 1217/1238 [27:59<00:29,  1.38s/it, training_loss=0.135]
#
#
# Epoch 2:  98%|█████████▊| 1217/1238 [28:00<00:29,  1.38s/it, training_loss=0.202]
#
#
# Epoch 2:  98%|█████████▊| 1218/1238 [28:00<00:27,  1.38s/it, training_loss=0.202]
#
#
# Epoch 2:  98%|█████████▊| 1218/1238 [28:01<00:27,  1.38s/it, training_loss=0.159]
#
#
# Epoch 2:  98%|█████████▊| 1219/1238 [28:01<00:26,  1.38s/it, training_loss=0.159]
#
#
# Epoch 2:  98%|█████████▊| 1219/1238 [28:03<00:26,  1.38s/it, training_loss=0.030]
#
#
# Epoch 2:  99%|█████████▊| 1220/1238 [28:03<00:24,  1.38s/it, training_loss=0.030]
#
#
# Epoch 2:  99%|█████████▊| 1220/1238 [28:04<00:24,  1.38s/it, training_loss=0.109]
#
#
# Epoch 2:  99%|█████████▊| 1221/1238 [28:04<00:23,  1.38s/it, training_loss=0.109]
#
#
# Epoch 2:  99%|█████████▊| 1221/1238 [28:06<00:23,  1.38s/it, training_loss=0.044]
#
#
# Epoch 2:  99%|█████████▊| 1222/1238 [28:06<00:22,  1.38s/it, training_loss=0.044]
#
#
# Epoch 2:  99%|█████████▊| 1222/1238 [28:07<00:22,  1.38s/it, training_loss=0.079]
#
#
# Epoch 2:  99%|█████████▉| 1223/1238 [28:07<00:20,  1.38s/it, training_loss=0.079]
#
#
# Epoch 2:  99%|█████████▉| 1223/1238 [28:08<00:20,  1.38s/it, training_loss=0.231]
#
#
# Epoch 2:  99%|█████████▉| 1224/1238 [28:08<00:19,  1.38s/it, training_loss=0.231]
#
#
# Epoch 2:  99%|█████████▉| 1224/1238 [28:10<00:19,  1.38s/it, training_loss=0.020]
#
#
# Epoch 2:  99%|█████████▉| 1225/1238 [28:10<00:17,  1.38s/it, training_loss=0.020]
#
#
# Epoch 2:  99%|█████████▉| 1225/1238 [28:11<00:17,  1.38s/it, training_loss=0.243]
#
#
# Epoch 2:  99%|█████████▉| 1226/1238 [28:11<00:16,  1.38s/it, training_loss=0.243]
#
#
# Epoch 2:  99%|█████████▉| 1226/1238 [28:12<00:16,  1.38s/it, training_loss=0.173]
#
#
# Epoch 2:  99%|█████████▉| 1227/1238 [28:12<00:15,  1.38s/it, training_loss=0.173]
#
#
# Epoch 2:  99%|█████████▉| 1227/1238 [28:14<00:15,  1.38s/it, training_loss=0.111]
#
#
# Epoch 2:  99%|█████████▉| 1228/1238 [28:14<00:13,  1.38s/it, training_loss=0.111]
#
#
# Epoch 2:  99%|█████████▉| 1228/1238 [28:15<00:13,  1.38s/it, training_loss=0.157]
#
#
# Epoch 2:  99%|█████████▉| 1229/1238 [28:15<00:12,  1.38s/it, training_loss=0.157]
#
#
# Epoch 2:  99%|█████████▉| 1229/1238 [28:17<00:12,  1.38s/it, training_loss=0.035]
#
#
# Epoch 2:  99%|█████████▉| 1230/1238 [28:17<00:11,  1.38s/it, training_loss=0.035]
#
#
# Epoch 2:  99%|█████████▉| 1230/1238 [28:18<00:11,  1.38s/it, training_loss=0.161]
#
#
# Epoch 2:  99%|█████████▉| 1231/1238 [28:18<00:09,  1.38s/it, training_loss=0.161]
#
#
# Epoch 2:  99%|█████████▉| 1231/1238 [28:19<00:09,  1.38s/it, training_loss=0.171]
#
#
# Epoch 2: 100%|█████████▉| 1232/1238 [28:19<00:08,  1.38s/it, training_loss=0.171]
#
#
# Epoch 2: 100%|█████████▉| 1232/1238 [28:21<00:08,  1.38s/it, training_loss=0.260]
#
#
# Epoch 2: 100%|█████████▉| 1233/1238 [28:21<00:06,  1.38s/it, training_loss=0.260]
#
#
# Epoch 2: 100%|█████████▉| 1233/1238 [28:22<00:06,  1.38s/it, training_loss=0.207]
#
#
# Epoch 2: 100%|█████████▉| 1234/1238 [28:22<00:05,  1.38s/it, training_loss=0.207]
#
#
# Epoch 2: 100%|█████████▉| 1234/1238 [28:23<00:05,  1.38s/it, training_loss=0.112]
#
#
# Epoch 2: 100%|█████████▉| 1235/1238 [28:23<00:04,  1.38s/it, training_loss=0.112]
#
#
# Epoch 2: 100%|█████████▉| 1235/1238 [28:25<00:04,  1.38s/it, training_loss=0.120]
#
#
# Epoch 2: 100%|█████████▉| 1236/1238 [28:25<00:02,  1.38s/it, training_loss=0.120]
#
#
# Epoch 2: 100%|█████████▉| 1236/1238 [28:26<00:02,  1.38s/it, training_loss=0.189]
#
#
# Epoch 2: 100%|█████████▉| 1237/1238 [28:26<00:01,  1.38s/it, training_loss=0.189]
#
#
# Epoch 2: 100%|█████████▉| 1237/1238 [28:27<00:01,  1.38s/it, training_loss=0.007]
#
#
# Epoch 2: 100%|██████████| 1238/1238 [28:27<00:00,  1.08s/it, training_loss=0.007]
#
#
#
#
#
#   0%|          | 0/1 [1:54:37<?, ?it/s]
#
#  50%|█████     | 1/2 [1:00:28<31:59, 1919.15s/it]
#
#
#
#   0%|          | 0/1 [1:54:37<?, ?it/s]
#
#  50%|█████     | 1/2 [1:00:28<31:59, 1919.15s/it]
# Epoch 1:  51%|█████     | 10037/19795 [1:54:37<36:40,  4.43it/s, training_loss=1.225]
# Epoch 2
# Training loss: 0.3635261633082839
#   0%|          | 0/1 [1:58:05<?, ?it/s]
#
#  50%|█████     | 1/2 [1:03:56<31:59, 1919.15s/it]
#
#
#
#   0%|          | 0/1 [1:58:05<?, ?it/s]
#
#  50%|█████     | 1/2 [1:03:56<31:59, 1919.15s/it]
# Epoch 1:  51%|█████     | 10037/19795 [1:58:05<36:40,  4.43it/s, training_loss=1.225]
#
# 100%|██████████| 2/2 [1:03:56<00:00, 1918.10s/it]
# Validation loss: 0.49066849989189654
# F1 Score (Weighted): 0.8334374480214185

# %%
accuracy_per_class(predictions, true_vals)
# Out:
# Class: Yes
# Accuracy: 3113/3326 = 0.9359591100420926
#
# Class: No
# Accuracy: 1941/2566 = 0.7564302416212003
#
# Class: In the middle, neither yes nor no
# Accuracy: 37/190 = 0.19473684210526315
#
# Class: Yes, subject to some conditions
# Accuracy: 455/517 = 0.8800773694390716

# %%
print('Dev Accuracy:', end = ' ')
flat_accuracy(predictions, true_vals)
# Out:
# Dev Accuracy:
# 0.8404303682376117

# %%
encoded_data_test = tokenizer.batch_encode_plus(
    df[df.data_type=='test'].YN_r.values, 
    add_special_tokens=True, 
    return_attention_mask=True, 
    pad_to_max_length=True, 
    max_length=256, 
    return_tensors='pt'
)

input_ids_test = encoded_data_test['input_ids']
attention_masks_test = encoded_data_test['attention_mask']
labels_test = torch.tensor(df[df.data_type=='test'].relaxed.values)

dataset_test = TensorDataset(input_ids_test, attention_masks_test, labels_test)

dataloader_test = DataLoader(dataset_test, 
                                   sampler=SequentialSampler(dataset_test), 
                                   batch_size=batch_size)

test_loss, test_predictions, test_true_vals = evaluate(dataloader_test)
test_f1 = f1_score_func(test_predictions, test_true_vals)

# %%
accuracy_per_class(test_predictions, test_true_vals)
print('Test Accuracy:', end = ' ')
flat_accuracy(test_predictions, test_true_vals)
# Out:
# Class: Yes
# Accuracy: 3156/3326 = 0.9488875526157546
#
# Class: No
# Accuracy: 1941/2567 = 0.7561355668095052
#
# Class: In the middle, neither yes nor no
# Accuracy: 33/190 = 0.1736842105263158
#
# Class: Yes, subject to some conditions
# Accuracy: 442/516 = 0.8565891472868217
#
# Test Accuracy:
# 0.8443703591453251
