# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install transformers==2.5.1
# Out:
# Collecting transformers==2.5.1
#   Downloading https://files.pythonhosted.org/packages/13/33/ffb67897a6985a7b7d8e5e7878c3628678f553634bd3836404fef06ef19b/transformers-2.5.1-py3-none-any.whl (499kB)
#      |████████████████████████████████| 501kB 18.0MB/s
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers==2.5.1) (2019.12.20)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers==2.5.1) (4.41.1)
# Collecting boto3
#   Downloading https://files.pythonhosted.org/packages/57/a5/892ed5d2959b1fdf4f8aaccf96b299e57dd7f06db7072592901fbaa36d79/boto3-1.17.54-py2.py3-none-any.whl (131kB)
#      |████████████████████████████████| 133kB 53.1MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from transformers==2.5.1) (1.19.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers==2.5.1) (2.23.0)
# Collecting sacremoses
#   Downloading https://files.pythonhosted.org/packages/75/ee/67241dc87f266093c533a2d4d3d69438e57d7a90abb216fa076e7d475d4a/sacremoses-0.0.45-py3-none-any.whl (895kB)
#      |████████████████████████████████| 901kB 56.7MB/s
# Collecting tokenizers==0.5.2
#   Downloading https://files.pythonhosted.org/packages/d6/e3/5e49e9a83fb605aaa34a1c1173e607302fecae529428c28696fb18f1c2c9/tokenizers-0.5.2-cp37-cp37m-manylinux1_x86_64.whl (5.6MB)
#      |████████████████████████████████| 5.6MB 41.8MB/s
# Collecting sentencepiece
#   Downloading https://files.pythonhosted.org/packages/f5/99/e0808cb947ba10f575839c43e8fafc9cc44e4a7a2c8f79c60db48220a577/sentencepiece-0.1.95-cp37-cp37m-manylinux2014_x86_64.whl (1.2MB)
#      |████████████████████████████████| 1.2MB 55.3MB/s
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers==2.5.1) (3.0.12)
# Collecting jmespath<1.0.0,>=0.7.1
#   Downloading https://files.pythonhosted.org/packages/07/cb/5f001272b6faeb23c1c9e0acc04d48eaaf5c862c17709d20e3469c6e0139/jmespath-0.10.0-py2.py3-none-any.whl
# Collecting botocore<1.21.0,>=1.20.54
#   Downloading https://files.pythonhosted.org/packages/3c/e1/59cc39d22d44e64e96186db87d6e670e2119822d16299e18d0500198abb4/botocore-1.20.54-py2.py3-none-any.whl (7.4MB)
#      |████████████████████████████████| 7.4MB 41.6MB/s
# Collecting s3transfer<0.5.0,>=0.4.0
#   Downloading https://files.pythonhosted.org/packages/3e/50/ac379fa31377f5d316cad8967db9f73c50cd61b80153269bfd7d8b964fc8/s3transfer-0.4.0-py2.py3-none-any.whl (79kB)
#      |████████████████████████████████| 81kB 12.4MB/s
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==2.5.1) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==2.5.1) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==2.5.1) (2020.12.5)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==2.5.1) (1.24.3)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==2.5.1) (1.15.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==2.5.1) (1.0.1)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==2.5.1) (7.1.2)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.7/dist-packages (from botocore<1.21.0,>=1.20.54->boto3->transformers==2.5.1) (2.8.1)
# ERROR: botocore 1.20.54 has requirement urllib3<1.27,>=1.25.4, but you'll have urllib3 1.24.3 which is incompatible.
# Installing collected packages: jmespath, botocore, s3transfer, boto3, sacremoses, tokenizers, sentencepiece, transformers
# Successfully installed boto3-1.17.54 botocore-1.20.54 jmespath-0.10.0 s3transfer-0.4.0 sacremoses-0.0.45 sentencepiece-0.1.95 tokenizers-0.5.2 transformers-2.5.1

# %%
import torch
import torch.nn as nn 
from torch.utils.data import DataLoader, RandomSampler, SequentialSampler, TensorDataset
from transformers import AutoTokenizer, AutoModelForSequenceClassification, AdamW, get_linear_schedule_with_warmup
# from transformers import AutoTokenizer, BertTokenizer, EvalPrediction, BertPreTrainedModel, BertConfig, BertModel, BertForSequenceClassification, AdamW, get_linear_schedule_with_warmup

import random
import pandas as pd
import numpy as np
from tqdm import tqdm

from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score

# %%
cd '/content/drive/MyDrive/'
# Out:
# /content/drive/MyDrive

# %% [markdown]
# ## Data pre-processing

# %% [markdown]
# Relaxed-matched

# %%
circa_og = pd.read_csv('NLU_Project/circa-data.tsv', sep='\t', index_col='id')
circa_r = circa_og.drop(circa_og.loc[circa_og['goldstandard2']=='Other'].index)
circa_r = circa_r.drop(circa_r.loc[circa_r['goldstandard2'].isnull()].index)

# %%
YN_r = (circa_r['question-X'].map(str)+' '+circa_r['answer-Y']).apply(lambda row: row.strip())
relaxed_labels = circa_r['goldstandard2'].unique()
relaxed_label = circa_r['goldstandard2']
relaxed_dict = {}
for idx, label in enumerate(relaxed_labels):
    relaxed_dict[label] = idx
circa_r['relaxed'] = circa_r.goldstandard2.replace(relaxed_dict)
relaxed = circa_r['relaxed']

# %% [markdown]
# ## Modeling

# %%
import tensorflow as tf

# Get the GPU device name.
device_name = tf.test.gpu_device_name()
print(device_name)

if torch.cuda.is_available():    

    # Tell PyTorch to use the GPU.    
    device = torch.device("cuda")
# Out:
# /device:GPU:0

# %% [markdown]
# ### Relaxed

# %%
tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased") 

model = AutoModelForSequenceClassification.from_pretrained("bert-base-uncased")
saved = torch.load('DS-GA 1012/boolq.pth')
model.load_state_dict(saved['model'])
# optimizer = model['optimizer']
model.to(device) # Send the model to the GPU if we have one

learning_rate = 5e-5
optimizer = AdamW(model.parameters(), lr=learning_rate, eps=1e-8)
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=433.0, style=ProgressStyle(description_…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=231508.0, style=ProgressStyle(descripti…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=440473133.0, style=ProgressStyle(descri…

# %%
max_len = 0
for entry in YN_r.values:
    input_ids = tokenizer.encode(entry,  add_special_tokens=True)
    max_len = max(max_len, len(input_ids))
print(max_len)
# Out:
# 43

# %%
df = pd.concat([YN_r, relaxed_label, relaxed], axis=1).rename(columns={0:'YN_r'})
df
# Out:
#                                                     YN_r  ... relaxed
# id                                                        ...
# 0         Are you employed? I'm a veterinary technician.  ...       0
# 1        Are you a fan of Korean food? I wouldn't say so  ...       1
# 2      Are you bringing any pets into the flat? I do ...  ...       1
# 3      Would you like to get some fresh air in your f...  ...       0
# 4      Is your family still living in the neighborhoo...  ...       2
# ...                                                  ...  ...     ...
# 34263                  Do you like to drink? I am in AA.  ...       1
# 34264         Do you like pie? My favorite pie is pecan.  ...       0
# 34265  Want to go to a concert with me? I'd rather do...  ...       1
# 34266  Do you like hip/hop music? I can't dance to hi...  ...       1
# 34267  Do you see yourself raising a family in New Yo...  ...       1
#
# [32993 rows x 3 columns]

# %%
train_relaxed, val_relaxed, trainy_relaxed, valy_relaxed = train_test_split(df.index.values, df.relaxed.values, test_size=.4, stratify=df.relaxed.values)
test_relaxed, dev_relaxed, testy_relaxed, devy_relaxed = train_test_split(val_relaxed, valy_relaxed, test_size=.5, stratify=valy_relaxed)

# %%
df['data_type'] = ['not_set']*df.shape[0]
df.loc[train_relaxed,'data_type'] = 'train'
df.loc[dev_relaxed,'data_type'] = 'dev'
df.loc[test_relaxed,'data_type'] = 'test'

# %%
df.groupby(['goldstandard2','relaxed','data_type']).count()
# Out:
#                                                      YN_r
# goldstandard2                     relaxed data_type
# In the middle, neither yes nor no 2       dev         190
#                                           test        190
#                                           train       569
# No                                1       dev        2567
#                                           test       2566
#                                           train      7700
# Yes                               0       dev        3326
#                                           test       3326
#                                           train      9976
# Yes, subject to some conditions   3       dev         516
#                                           test        517
#                                           train      1550

# %%
encoded_data_train = tokenizer.batch_encode_plus(
    df[df.data_type=='train'].YN_r.values, 
    add_special_tokens=True, 
    return_attention_mask=True, 
    pad_to_max_length=True, 
    max_length=256, 
    return_tensors='pt'
)

encoded_data_dev = tokenizer.batch_encode_plus(
    df[df.data_type=='dev'].YN_r.values, 
    add_special_tokens=True, 
    return_attention_mask=True, 
    pad_to_max_length=True, 
    max_length=256, 
    return_tensors='pt'
)


input_ids_train = encoded_data_train['input_ids']
attention_masks_train = encoded_data_train['attention_mask']
labels_train = torch.tensor(df[df.data_type=='train'].relaxed.values)

input_ids_dev = encoded_data_dev['input_ids']
attention_masks_dev = encoded_data_dev['attention_mask']
labels_dev = torch.tensor(df[df.data_type=='dev'].relaxed.values)

# %%
dataset_train = TensorDataset(input_ids_train, attention_masks_train, labels_train)
dataset_dev = TensorDataset(input_ids_dev, attention_masks_dev, labels_dev)

# %%
len(dataset_train)
# Out:
# 19795

# %%
# model = BertForSequenceClassification.from_pretrained("bert-base-uncased",
#                                                       num_labels=len(relaxed_dict),
#                                                       output_attentions=False,
#                                                       output_hidden_states=False)

model.classifier = torch.nn.Linear(model.classifier.in_features, 4)
model.num_labels = 4
optimizer = AdamW(model.parameters(), lr=learning_rate, eps=1e-8)
model.to(device)
# Out:
# BertForSequenceClassification(
#   (bert): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(30522, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (1): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (2): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (3): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (4): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (5): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (6): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (7): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (8): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (9): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (10): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (11): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (dropout): Dropout(p=0.1, inplace=False)
#   (classifier): Linear(in_features=768, out_features=4, bias=True)
# )

# %%
batch_size = 32

dataloader_train = DataLoader(dataset_train, 
                              sampler=RandomSampler(dataset_train), 
                              batch_size=batch_size)

dataloader_validation = DataLoader(dataset_dev, 
                                   sampler=SequentialSampler(dataset_dev), 
                                   batch_size=batch_size)

optimizer = AdamW(model.parameters(),
                  lr = learning_rate,
                  eps = 1e-8)

# %%
epochs = 3
total_steps = len(dataloader_train) * epochs
scheduler = get_linear_schedule_with_warmup(optimizer, 
                                            num_warmup_steps = 0, 
                                            num_training_steps = total_steps)

# %%
def f1_score_func(preds, labels):
    preds_flat = np.argmax(preds, axis=1).flatten()
    labels_flat = labels.flatten()
    return f1_score(labels_flat, preds_flat, average='weighted')

def accuracy_per_class(preds, labels):
    label_dict_inverse = {v: k for k, v in relaxed_dict.items()}
    
    preds_flat = np.argmax(preds, axis=1).flatten()
    labels_flat = labels.flatten()

    for label in np.unique(labels_flat):
        y_preds = preds_flat[labels_flat==label]
        y_true = labels_flat[labels_flat==label]
        print(f'Class: {label_dict_inverse[label]}')
        print(f'Accuracy: {len(y_preds[y_preds==label])}/{len(y_true)} = {len(y_preds[y_preds==label])/len(y_true)}\n')

def flat_accuracy(preds, labels):
    pred_flat = np.argmax(preds, axis=1).flatten()
    labels_flat = labels.flatten()
    return np.sum(pred_flat == labels_flat) / len(labels_flat)

# %%
seed_val = 42

random.seed(seed_val)
np.random.seed(seed_val)
torch.manual_seed(seed_val)
torch.cuda.manual_seed_all(seed_val)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model.to(device)

print(device)
# Out:
# cuda

# %%
def evaluate(dataloader_val):

    model.eval()
    
    loss_val_total = 0
    predictions, true_vals = [], []
    
    for batch in dataloader_val:
        
        batch = tuple(b.to(device) for b in batch)
        
        inputs = {'input_ids':      batch[0],
                  'attention_mask': batch[1],
                  'labels':         batch[2],
                 }

        with torch.no_grad():        
            outputs = model(**inputs)
            
        loss = outputs[0]
        logits = outputs[1]
        loss_val_total += loss.item()

        logits = logits.detach().cpu().numpy()
        label_ids = inputs['labels'].cpu().numpy()
        predictions.append(logits)
        true_vals.append(label_ids)
    
    loss_val_avg = loss_val_total/len(dataloader_val) 
    
    predictions = np.concatenate(predictions, axis=0)
    true_vals = np.concatenate(true_vals, axis=0)
            
    return loss_val_avg, predictions, true_vals

# %%
for epoch in tqdm(range(1, epochs+1)):
    
    model.train()
    
    loss_train_total = 0

    progress_bar = tqdm(dataloader_train, desc='Epoch {:1d}'.format(epoch), leave=False, disable=False)
    for batch in progress_bar:

        model.zero_grad()
        
        batch = tuple(b.to(device) for b in batch)
        
        inputs = {'input_ids':      batch[0],
                  'attention_mask': batch[1],
                  'labels':         batch[2],
                 }       

        outputs = model(**inputs)
        
        loss = outputs[0]
        loss_train_total += loss.item()
        loss.backward()

        torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)

        optimizer.step()
        # scheduler.step()
        
        progress_bar.set_postfix({'training_loss': '{:.3f}'.format(loss.item()/len(batch))})
         
        
    torch.save(model.state_dict(), f'finetuned_BERT_relaxed_epoch_{epoch}.model')
        
    tqdm.write(f'\nEpoch {epoch}')
    
    loss_train_avg = loss_train_total/len(dataloader_train)            
    tqdm.write(f'Training loss: {loss_train_avg}')
    
    dev_loss, predictions, true_vals = evaluate(dataloader_validation)
    dev_f1 = f1_score_func(predictions, true_vals)
    tqdm.write(f'Validation loss: {dev_loss}')
    tqdm.write(f'F1 Score (Weighted): {dev_f1}')
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 1:   0%|          | 0/619 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/transformers/optimization.py:155: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# Consider using one of the following signatures instead:
# 	add_(Tensor other, *, Number alpha) (Triggered internally at  /pytorch/torch/csrc/utils/python_arg_parser.cpp:1005.)
#   exp_avg.mul_(beta1).add_(1.0 - beta1, grad)
#
# Epoch 1:   0%|          | 0/619 [00:01<?, ?it/s, training_loss=0.487]
# Epoch 1:   0%|          | 1/619 [00:01<15:28,  1.50s/it, training_loss=0.487]
# Epoch 1:   0%|          | 1/619 [00:02<15:28,  1.50s/it, training_loss=0.387]
# Epoch 1:   0%|          | 2/619 [00:02<14:34,  1.42s/it, training_loss=0.387]
# Epoch 1:   0%|          | 2/619 [00:03<14:34,  1.42s/it, training_loss=0.376]
# Epoch 1:   0%|          | 3/619 [00:03<13:57,  1.36s/it, training_loss=0.376]
# Epoch 1:   0%|          | 3/619 [00:05<13:57,  1.36s/it, training_loss=0.370]
# Epoch 1:   1%|          | 4/619 [00:05<13:31,  1.32s/it, training_loss=0.370]
# Epoch 1:   1%|          | 4/619 [00:06<13:31,  1.32s/it, training_loss=0.348]
# Epoch 1:   1%|          | 5/619 [00:06<13:13,  1.29s/it, training_loss=0.348]
# Epoch 1:   1%|          | 5/619 [00:07<13:13,  1.29s/it, training_loss=0.323]
# Epoch 1:   1%|          | 6/619 [00:07<13:01,  1.27s/it, training_loss=0.323]
# Epoch 1:   1%|          | 6/619 [00:08<13:01,  1.27s/it, training_loss=0.330]
# Epoch 1:   1%|          | 7/619 [00:08<12:50,  1.26s/it, training_loss=0.330]
# Epoch 1:   1%|          | 7/619 [00:10<12:50,  1.26s/it, training_loss=0.315]
# Epoch 1:   1%|▏         | 8/619 [00:10<12:45,  1.25s/it, training_loss=0.315]
# Epoch 1:   1%|▏         | 8/619 [00:11<12:45,  1.25s/it, training_loss=0.369]
# Epoch 1:   1%|▏         | 9/619 [00:11<12:42,  1.25s/it, training_loss=0.369]
# Epoch 1:   1%|▏         | 9/619 [00:12<12:42,  1.25s/it, training_loss=0.259]
# Epoch 1:   2%|▏         | 10/619 [00:12<12:38,  1.25s/it, training_loss=0.259]
# Epoch 1:   2%|▏         | 10/619 [00:13<12:38,  1.25s/it, training_loss=0.316]
# Epoch 1:   2%|▏         | 11/619 [00:13<12:32,  1.24s/it, training_loss=0.316]
# Epoch 1:   2%|▏         | 11/619 [00:15<12:32,  1.24s/it, training_loss=0.316]
# Epoch 1:   2%|▏         | 12/619 [00:15<12:31,  1.24s/it, training_loss=0.316]
# Epoch 1:   2%|▏         | 12/619 [00:16<12:31,  1.24s/it, training_loss=0.353]
# Epoch 1:   2%|▏         | 13/619 [00:16<12:30,  1.24s/it, training_loss=0.353]
# Epoch 1:   2%|▏         | 13/619 [00:17<12:30,  1.24s/it, training_loss=0.230]
# Epoch 1:   2%|▏         | 14/619 [00:17<12:28,  1.24s/it, training_loss=0.230]
# Epoch 1:   2%|▏         | 14/619 [00:18<12:28,  1.24s/it, training_loss=0.359]
# Epoch 1:   2%|▏         | 15/619 [00:18<12:28,  1.24s/it, training_loss=0.359]
# Epoch 1:   2%|▏         | 15/619 [00:19<12:28,  1.24s/it, training_loss=0.350]
# Epoch 1:   3%|▎         | 16/619 [00:19<12:27,  1.24s/it, training_loss=0.350]
# Epoch 1:   3%|▎         | 16/619 [00:21<12:27,  1.24s/it, training_loss=0.383]
# Epoch 1:   3%|▎         | 17/619 [00:21<12:27,  1.24s/it, training_loss=0.383]
# Epoch 1:   3%|▎         | 17/619 [00:22<12:27,  1.24s/it, training_loss=0.306]
# Epoch 1:   3%|▎         | 18/619 [00:22<12:25,  1.24s/it, training_loss=0.306]
# Epoch 1:   3%|▎         | 18/619 [00:23<12:25,  1.24s/it, training_loss=0.237]
# Epoch 1:   3%|▎         | 19/619 [00:23<12:24,  1.24s/it, training_loss=0.237]
# Epoch 1:   3%|▎         | 19/619 [00:24<12:24,  1.24s/it, training_loss=0.430]
# Epoch 1:   3%|▎         | 20/619 [00:24<12:22,  1.24s/it, training_loss=0.430]
# Epoch 1:   3%|▎         | 20/619 [00:26<12:22,  1.24s/it, training_loss=0.281]
# Epoch 1:   3%|▎         | 21/619 [00:26<12:21,  1.24s/it, training_loss=0.281]
# Epoch 1:   3%|▎         | 21/619 [00:27<12:21,  1.24s/it, training_loss=0.342]
# Epoch 1:   4%|▎         | 22/619 [00:27<12:21,  1.24s/it, training_loss=0.342]
# Epoch 1:   4%|▎         | 22/619 [00:28<12:21,  1.24s/it, training_loss=0.254]
# Epoch 1:   4%|▎         | 23/619 [00:28<12:24,  1.25s/it, training_loss=0.254]
# Epoch 1:   4%|▎         | 23/619 [00:29<12:24,  1.25s/it, training_loss=0.253]
# Epoch 1:   4%|▍         | 24/619 [00:29<12:24,  1.25s/it, training_loss=0.253]
# Epoch 1:   4%|▍         | 24/619 [00:31<12:24,  1.25s/it, training_loss=0.335]
# Epoch 1:   4%|▍         | 25/619 [00:31<12:25,  1.25s/it, training_loss=0.335]
# Epoch 1:   4%|▍         | 25/619 [00:32<12:25,  1.25s/it, training_loss=0.242]
# Epoch 1:   4%|▍         | 26/619 [00:32<12:27,  1.26s/it, training_loss=0.242]
# Epoch 1:   4%|▍         | 26/619 [00:33<12:27,  1.26s/it, training_loss=0.249]
# Epoch 1:   4%|▍         | 27/619 [00:33<12:25,  1.26s/it, training_loss=0.249]
# Epoch 1:   4%|▍         | 27/619 [00:35<12:25,  1.26s/it, training_loss=0.244]
# Epoch 1:   5%|▍         | 28/619 [00:35<12:26,  1.26s/it, training_loss=0.244]
# Epoch 1:   5%|▍         | 28/619 [00:36<12:26,  1.26s/it, training_loss=0.297]
# Epoch 1:   5%|▍         | 29/619 [00:36<12:27,  1.27s/it, training_loss=0.297]
# Epoch 1:   5%|▍         | 29/619 [00:37<12:27,  1.27s/it, training_loss=0.342]
# Epoch 1:   5%|▍         | 30/619 [00:37<12:27,  1.27s/it, training_loss=0.342]
# Epoch 1:   5%|▍         | 30/619 [00:38<12:27,  1.27s/it, training_loss=0.349]
# Epoch 1:   5%|▌         | 31/619 [00:38<12:26,  1.27s/it, training_loss=0.349]
# Epoch 1:   5%|▌         | 31/619 [00:40<12:26,  1.27s/it, training_loss=0.318]
# Epoch 1:   5%|▌         | 32/619 [00:40<12:27,  1.27s/it, training_loss=0.318]
# Epoch 1:   5%|▌         | 32/619 [00:41<12:27,  1.27s/it, training_loss=0.217]
# Epoch 1:   5%|▌         | 33/619 [00:41<12:24,  1.27s/it, training_loss=0.217]
# Epoch 1:   5%|▌         | 33/619 [00:42<12:24,  1.27s/it, training_loss=0.262]
# Epoch 1:   5%|▌         | 34/619 [00:42<12:24,  1.27s/it, training_loss=0.262]
# Epoch 1:   5%|▌         | 34/619 [00:43<12:24,  1.27s/it, training_loss=0.314]
# Epoch 1:   6%|▌         | 35/619 [00:43<12:24,  1.28s/it, training_loss=0.314]
# Epoch 1:   6%|▌         | 35/619 [00:45<12:24,  1.28s/it, training_loss=0.243]
# Epoch 1:   6%|▌         | 36/619 [00:45<12:23,  1.28s/it, training_loss=0.243]
# Epoch 1:   6%|▌         | 36/619 [00:46<12:23,  1.28s/it, training_loss=0.252]
# Epoch 1:   6%|▌         | 37/619 [00:46<12:22,  1.28s/it, training_loss=0.252]
# Epoch 1:   6%|▌         | 37/619 [00:47<12:22,  1.28s/it, training_loss=0.225]
# Epoch 1:   6%|▌         | 38/619 [00:47<12:22,  1.28s/it, training_loss=0.225]
# Epoch 1:   6%|▌         | 38/619 [00:49<12:22,  1.28s/it, training_loss=0.300]
# Epoch 1:   6%|▋         | 39/619 [00:49<12:21,  1.28s/it, training_loss=0.300]
# Epoch 1:   6%|▋         | 39/619 [00:50<12:21,  1.28s/it, training_loss=0.348]
# Epoch 1:   6%|▋         | 40/619 [00:50<12:20,  1.28s/it, training_loss=0.348]
# Epoch 1:   6%|▋         | 40/619 [00:51<12:20,  1.28s/it, training_loss=0.220]
# Epoch 1:   7%|▋         | 41/619 [00:51<12:18,  1.28s/it, training_loss=0.220]
# Epoch 1:   7%|▋         | 41/619 [00:52<12:18,  1.28s/it, training_loss=0.300]
# Epoch 1:   7%|▋         | 42/619 [00:52<12:18,  1.28s/it, training_loss=0.300]
# Epoch 1:   7%|▋         | 42/619 [00:54<12:18,  1.28s/it, training_loss=0.276]
# Epoch 1:   7%|▋         | 43/619 [00:54<12:17,  1.28s/it, training_loss=0.276]
# Epoch 1:   7%|▋         | 43/619 [00:55<12:17,  1.28s/it, training_loss=0.284]
# Epoch 1:   7%|▋         | 44/619 [00:55<12:16,  1.28s/it, training_loss=0.284]
# Epoch 1:   7%|▋         | 44/619 [00:56<12:16,  1.28s/it, training_loss=0.223]
# Epoch 1:   7%|▋         | 45/619 [00:56<12:15,  1.28s/it, training_loss=0.223]
# Epoch 1:   7%|▋         | 45/619 [00:58<12:15,  1.28s/it, training_loss=0.179]
# Epoch 1:   7%|▋         | 46/619 [00:58<12:14,  1.28s/it, training_loss=0.179]
# Epoch 1:   7%|▋         | 46/619 [00:59<12:14,  1.28s/it, training_loss=0.179]
# Epoch 1:   8%|▊         | 47/619 [00:59<12:14,  1.28s/it, training_loss=0.179]
# Epoch 1:   8%|▊         | 47/619 [01:00<12:14,  1.28s/it, training_loss=0.207]
# Epoch 1:   8%|▊         | 48/619 [01:00<12:14,  1.29s/it, training_loss=0.207]
# Epoch 1:   8%|▊         | 48/619 [01:01<12:14,  1.29s/it, training_loss=0.229]
# Epoch 1:   8%|▊         | 49/619 [01:01<12:16,  1.29s/it, training_loss=0.229]
# Epoch 1:   8%|▊         | 49/619 [01:03<12:16,  1.29s/it, training_loss=0.147]
# Epoch 1:   8%|▊         | 50/619 [01:03<12:17,  1.30s/it, training_loss=0.147]
# Epoch 1:   8%|▊         | 50/619 [01:04<12:17,  1.30s/it, training_loss=0.318]
# Epoch 1:   8%|▊         | 51/619 [01:04<12:16,  1.30s/it, training_loss=0.318]
# Epoch 1:   8%|▊         | 51/619 [01:05<12:16,  1.30s/it, training_loss=0.244]
# Epoch 1:   8%|▊         | 52/619 [01:05<12:13,  1.29s/it, training_loss=0.244]
# Epoch 1:   8%|▊         | 52/619 [01:07<12:13,  1.29s/it, training_loss=0.159]
# Epoch 1:   9%|▊         | 53/619 [01:07<12:13,  1.30s/it, training_loss=0.159]
# Epoch 1:   9%|▊         | 53/619 [01:08<12:13,  1.30s/it, training_loss=0.242]
# Epoch 1:   9%|▊         | 54/619 [01:08<12:12,  1.30s/it, training_loss=0.242]
# Epoch 1:   9%|▊         | 54/619 [01:09<12:12,  1.30s/it, training_loss=0.295]
# Epoch 1:   9%|▉         | 55/619 [01:09<12:11,  1.30s/it, training_loss=0.295]
# Epoch 1:   9%|▉         | 55/619 [01:11<12:11,  1.30s/it, training_loss=0.236]
# Epoch 1:   9%|▉         | 56/619 [01:11<12:10,  1.30s/it, training_loss=0.236]
# Epoch 1:   9%|▉         | 56/619 [01:12<12:10,  1.30s/it, training_loss=0.245]
# Epoch 1:   9%|▉         | 57/619 [01:12<12:11,  1.30s/it, training_loss=0.245]
# Epoch 1:   9%|▉         | 57/619 [01:13<12:11,  1.30s/it, training_loss=0.318]
# Epoch 1:   9%|▉         | 58/619 [01:13<12:11,  1.30s/it, training_loss=0.318]
# Epoch 1:   9%|▉         | 58/619 [01:14<12:11,  1.30s/it, training_loss=0.222]
# Epoch 1:  10%|▉         | 59/619 [01:14<12:11,  1.31s/it, training_loss=0.222]
# Epoch 1:  10%|▉         | 59/619 [01:16<12:11,  1.31s/it, training_loss=0.188]
# Epoch 1:  10%|▉         | 60/619 [01:16<12:10,  1.31s/it, training_loss=0.188]
# Epoch 1:  10%|▉         | 60/619 [01:17<12:10,  1.31s/it, training_loss=0.234]
# Epoch 1:  38%|███▊      | 235/619 [05:20<09:13,  1.44s/it, training_loss=0.255]
# Epoch 1:  38%|███▊      | 235/619 [05:22<09:13,  1.44s/it, training_loss=0.116]
# Epoch 1:  38%|███▊      | 236/619 [05:22<09:13,  1.44s/it, training_loss=0.116]
# Epoch 1:  38%|███▊      | 236/619 [05:23<09:13,  1.44s/it, training_loss=0.196]
# Epoch 1:  38%|███▊      | 237/619 [05:23<09:12,  1.45s/it, training_loss=0.196]
# Epoch 1:  38%|███▊      | 237/619 [05:25<09:12,  1.45s/it, training_loss=0.190]
# Epoch 1:  38%|███▊      | 238/619 [05:25<09:11,  1.45s/it, training_loss=0.190]
# Epoch 1:  38%|███▊      | 238/619 [05:26<09:11,  1.45s/it, training_loss=0.264]
# Epoch 1:  39%|███▊      | 239/619 [05:26<09:09,  1.45s/it, training_loss=0.264]
# Epoch 1:  39%|███▊      | 239/619 [05:28<09:09,  1.45s/it, training_loss=0.121]
# Epoch 1:  39%|███▉      | 240/619 [05:28<09:07,  1.45s/it, training_loss=0.121]
# Epoch 1:  39%|███▉      | 240/619 [05:29<09:07,  1.45s/it, training_loss=0.093]
# Epoch 1:  39%|███▉      | 241/619 [05:29<09:06,  1.45s/it, training_loss=0.093]
# Epoch 1:  39%|███▉      | 241/619 [05:31<09:06,  1.45s/it, training_loss=0.168]
# Epoch 1:  39%|███▉      | 242/619 [05:31<09:05,  1.45s/it, training_loss=0.168]
# Epoch 1:  39%|███▉      | 242/619 [05:32<09:05,  1.45s/it, training_loss=0.304]
# Epoch 1:  39%|███▉      | 243/619 [05:32<09:04,  1.45s/it, training_loss=0.304]
# Epoch 1:  39%|███▉      | 243/619 [05:33<09:04,  1.45s/it, training_loss=0.178]
# Epoch 1:  39%|███▉      | 244/619 [05:33<09:03,  1.45s/it, training_loss=0.178]
# Epoch 1:  39%|███▉      | 244/619 [05:35<09:03,  1.45s/it, training_loss=0.149]
# Epoch 1:  40%|███▉      | 245/619 [05:35<09:01,  1.45s/it, training_loss=0.149]
# Epoch 1:  40%|███▉      | 245/619 [05:36<09:01,  1.45s/it, training_loss=0.271]
# Epoch 1:  40%|███▉      | 246/619 [05:36<08:59,  1.45s/it, training_loss=0.271]
# Epoch 1:  40%|███▉      | 246/619 [05:38<08:59,  1.45s/it, training_loss=0.247]
# Epoch 1:  40%|███▉      | 247/619 [05:38<08:58,  1.45s/it, training_loss=0.247]
# Epoch 1:  40%|███▉      | 247/619 [05:39<08:58,  1.45s/it, training_loss=0.150]
# Epoch 1:  40%|████      | 248/619 [05:39<08:56,  1.45s/it, training_loss=0.150]
# Epoch 1:  40%|████      | 248/619 [05:41<08:56,  1.45s/it, training_loss=0.225]
# Epoch 1:  40%|████      | 249/619 [05:41<08:55,  1.45s/it, training_loss=0.225]
# Epoch 1:  40%|████      | 249/619 [05:42<08:55,  1.45s/it, training_loss=0.089]
# Epoch 1:  40%|████      | 250/619 [05:42<08:53,  1.45s/it, training_loss=0.089]
# Epoch 1:  40%|████      | 250/619 [05:44<08:53,  1.45s/it, training_loss=0.217]
# Epoch 1:  48%|████▊     | 298/619 [06:53<07:45,  1.45s/it, training_loss=0.098]
# ...
# Epoch 3:  84%|████████▍ | 521/619 [12:33<02:21,  1.44s/it, training_loss=0.044]
# Epoch 3:  84%|████████▍ | 521/619 [12:35<02:21,  1.44s/it, training_loss=0.065]
# Epoch 3:  84%|████████▍ | 522/619 [12:35<02:19,  1.44s/it, training_loss=0.065]
# Epoch 3:  84%|████████▍ | 522/619 [12:36<02:19,  1.44s/it, training_loss=0.013]
# Epoch 3:  84%|████████▍ | 523/619 [12:36<02:18,  1.44s/it, training_loss=0.013]
# Epoch 3:  84%|████████▍ | 523/619 [12:38<02:18,  1.44s/it, training_loss=0.008]
# Epoch 3:  85%|████████▍ | 524/619 [12:38<02:17,  1.45s/it, training_loss=0.008]
# Epoch 3:  85%|████████▍ | 524/619 [12:39<02:17,  1.45s/it, training_loss=0.083]
# Epoch 3:  85%|████████▍ | 525/619 [12:39<02:15,  1.45s/it, training_loss=0.083]
# Epoch 3:  85%|████████▍ | 525/619 [12:41<02:15,  1.45s/it, training_loss=0.061]
# Epoch 3:  85%|████████▍ | 526/619 [12:41<02:14,  1.44s/it, training_loss=0.061]
# Epoch 3:  85%|████████▍ | 526/619 [12:42<02:14,  1.44s/it, training_loss=0.076]
# Epoch 3:  85%|████████▌ | 527/619 [12:42<02:12,  1.44s/it, training_loss=0.076]
# Epoch 3:  85%|████████▌ | 527/619 [12:43<02:12,  1.44s/it, training_loss=0.015]
# Epoch 3:  85%|████████▌ | 528/619 [12:43<02:11,  1.44s/it, training_loss=0.015]
# Epoch 3:  85%|████████▌ | 528/619 [12:45<02:11,  1.44s/it, training_loss=0.172]
# Epoch 3:  85%|████████▌ | 529/619 [12:45<02:10,  1.45s/it, training_loss=0.172]
# Epoch 3:  85%|████████▌ | 529/619 [12:46<02:10,  1.45s/it, training_loss=0.018]
# Epoch 3:  86%|████████▌ | 530/619 [12:46<02:08,  1.44s/it, training_loss=0.018]
# Epoch 3:  86%|████████▌ | 530/619 [12:48<02:08,  1.44s/it, training_loss=0.107]
# Epoch 3:  86%|████████▌ | 531/619 [12:48<02:07,  1.45s/it, training_loss=0.107]
# Epoch 3:  86%|████████▌ | 531/619 [12:49<02:07,  1.45s/it, training_loss=0.010]
# Epoch 3:  86%|████████▌ | 532/619 [12:49<02:05,  1.44s/it, training_loss=0.010]
# Epoch 3:  86%|████████▌ | 532/619 [12:51<02:05,  1.44s/it, training_loss=0.114]
# Epoch 3:  86%|████████▌ | 533/619 [12:51<02:04,  1.44s/it, training_loss=0.114]
# Epoch 3:  86%|████████▌ | 533/619 [12:52<02:04,  1.44s/it, training_loss=0.043]
# Epoch 3:  86%|████████▋ | 534/619 [12:52<02:03,  1.45s/it, training_loss=0.043]
# Epoch 3:  86%|████████▋ | 534/619 [12:54<02:03,  1.45s/it, training_loss=0.139]
# Epoch 3:  86%|████████▋ | 535/619 [12:54<02:01,  1.44s/it, training_loss=0.139]
# Epoch 3:  86%|████████▋ | 535/619 [12:55<02:01,  1.44s/it, training_loss=0.073]
# Epoch 3:  87%|████████▋ | 536/619 [12:55<01:59,  1.44s/it, training_loss=0.073]
# Epoch 3:  87%|████████▋ | 536/619 [12:56<01:59,  1.44s/it, training_loss=0.044]
# Epoch 3:  87%|████████▋ | 537/619 [12:56<01:58,  1.44s/it, training_loss=0.044]
# Epoch 3:  87%|████████▋ | 537/619 [12:58<01:58,  1.44s/it, training_loss=0.065]
# Epoch 3:  87%|████████▋ | 538/619 [12:58<01:56,  1.44s/it, training_loss=0.065]
# Epoch 3:  87%|████████▋ | 538/619 [12:59<01:56,  1.44s/it, training_loss=0.182]
# Epoch 3:  87%|████████▋ | 539/619 [12:59<01:55,  1.44s/it, training_loss=0.182]
# Epoch 3:  87%|████████▋ | 539/619 [13:01<01:55,  1.44s/it, training_loss=0.040]
# Epoch 3:  87%|████████▋ | 540/619 [13:01<01:54,  1.44s/it, training_loss=0.040]
# Epoch 3:  87%|████████▋ | 540/619 [13:02<01:54,  1.44s/it, training_loss=0.051]
# Epoch 3:  87%|████████▋ | 541/619 [13:02<01:52,  1.45s/it, training_loss=0.051]
# Epoch 3:  87%|████████▋ | 541/619 [13:04<01:52,  1.45s/it, training_loss=0.019]
# Epoch 3:  88%|████████▊ | 542/619 [13:04<01:51,  1.45s/it, training_loss=0.019]
# Epoch 3:  88%|████████▊ | 542/619 [13:05<01:51,  1.45s/it, training_loss=0.078]
# Epoch 3:  88%|████████▊ | 543/619 [13:05<01:50,  1.45s/it, training_loss=0.078]
# Epoch 3:  88%|████████▊ | 543/619 [13:07<01:50,  1.45s/it, training_loss=0.057]
# Epoch 3:  88%|████████▊ | 544/619 [13:07<01:48,  1.45s/it, training_loss=0.057]
# Epoch 3:  88%|████████▊ | 544/619 [13:08<01:48,  1.45s/it, training_loss=0.184]
# Epoch 3:  88%|████████▊ | 545/619 [13:08<01:47,  1.45s/it, training_loss=0.184]
# Epoch 3:  88%|████████▊ | 545/619 [13:09<01:47,  1.45s/it, training_loss=0.108]
# Epoch 3:  88%|████████▊ | 546/619 [13:09<01:45,  1.45s/it, training_loss=0.108]
# Epoch 3:  88%|████████▊ | 546/619 [13:11<01:45,  1.45s/it, training_loss=0.062]
# Epoch 3:  88%|████████▊ | 547/619 [13:11<01:44,  1.45s/it, training_loss=0.062]
# Epoch 3:  88%|████████▊ | 547/619 [13:12<01:44,  1.45s/it, training_loss=0.052]
# Epoch 3:  89%|████████▊ | 548/619 [13:12<01:42,  1.45s/it, training_loss=0.052]
# Epoch 3:  89%|████████▊ | 548/619 [13:14<01:42,  1.45s/it, training_loss=0.132]
# Epoch 3:  89%|████████▊ | 549/619 [13:14<01:41,  1.45s/it, training_loss=0.132]
# Epoch 3:  89%|████████▊ | 549/619 [13:15<01:41,  1.45s/it, training_loss=0.074]
# Epoch 3:  89%|████████▉ | 550/619 [13:15<01:39,  1.45s/it, training_loss=0.074]
# Epoch 3:  89%|████████▉ | 550/619 [13:17<01:39,  1.45s/it, training_loss=0.037]
# Epoch 3:  89%|████████▉ | 551/619 [13:17<01:38,  1.45s/it, training_loss=0.037]
# Epoch 3:  89%|████████▉ | 551/619 [13:18<01:38,  1.45s/it, training_loss=0.108]
# Epoch 3:  89%|████████▉ | 552/619 [13:18<01:37,  1.45s/it, training_loss=0.108]
# Epoch 3:  89%|████████▉ | 552/619 [13:20<01:37,  1.45s/it, training_loss=0.025]
# Epoch 3:  89%|████████▉ | 553/619 [13:20<01:35,  1.45s/it, training_loss=0.025]
# Epoch 3:  89%|████████▉ | 553/619 [13:21<01:35,  1.45s/it, training_loss=0.047]
# Epoch 3:  89%|████████▉ | 554/619 [13:21<01:34,  1.45s/it, training_loss=0.047]
# Epoch 3:  89%|████████▉ | 554/619 [13:23<01:34,  1.45s/it, training_loss=0.074]
# Epoch 3:  90%|████████▉ | 555/619 [13:23<01:32,  1.44s/it, training_loss=0.074]
# Epoch 3:  90%|████████▉ | 555/619 [13:24<01:32,  1.44s/it, training_loss=0.166]
# Epoch 3:  90%|████████▉ | 556/619 [13:24<01:30,  1.44s/it, training_loss=0.166]
# Epoch 3:  90%|████████▉ | 556/619 [13:25<01:30,  1.44s/it, training_loss=0.087]
# Epoch 3:  90%|████████▉ | 557/619 [13:25<01:29,  1.44s/it, training_loss=0.087]
# Epoch 3:  90%|████████▉ | 557/619 [13:27<01:29,  1.44s/it, training_loss=0.045]
# Epoch 3:  90%|█████████ | 558/619 [13:27<01:27,  1.44s/it, training_loss=0.045]
# Epoch 3:  90%|█████████ | 558/619 [13:28<01:27,  1.44s/it, training_loss=0.074]
# Epoch 3:  90%|█████████ | 559/619 [13:28<01:26,  1.44s/it, training_loss=0.074]
# Epoch 3:  90%|█████████ | 559/619 [13:30<01:26,  1.44s/it, training_loss=0.096]
# Epoch 3:  90%|█████████ | 560/619 [13:30<01:25,  1.44s/it, training_loss=0.096]
# Epoch 3:  90%|█████████ | 560/619 [13:31<01:25,  1.44s/it, training_loss=0.050]
# Epoch 3:  91%|█████████ | 561/619 [13:31<01:23,  1.44s/it, training_loss=0.050]
# Epoch 3:  91%|█████████ | 561/619 [13:33<01:23,  1.44s/it, training_loss=0.129]
# Epoch 3:  91%|█████████ | 562/619 [13:33<01:22,  1.44s/it, training_loss=0.129]
# Epoch 3:  91%|█████████ | 562/619 [13:34<01:22,  1.44s/it, training_loss=0.038]
# Epoch 3:  91%|█████████ | 563/619 [13:34<01:20,  1.44s/it, training_loss=0.038]
# Epoch 3:  91%|█████████ | 563/619 [13:35<01:20,  1.44s/it, training_loss=0.109]
# Epoch 3:  91%|█████████ | 564/619 [13:36<01:19,  1.45s/it, training_loss=0.109]
# Epoch 3:  91%|█████████ | 564/619 [13:37<01:19,  1.45s/it, training_loss=0.036]
# Epoch 3:  91%|█████████▏| 565/619 [13:37<01:18,  1.45s/it, training_loss=0.036]
# Epoch 3:  91%|█████████▏| 565/619 [13:38<01:18,  1.45s/it, training_loss=0.026]
# Epoch 3:  91%|█████████▏| 566/619 [13:38<01:16,  1.45s/it, training_loss=0.026]
# Epoch 3:  91%|█████████▏| 566/619 [13:40<01:16,  1.45s/it, training_loss=0.195]
# Epoch 3:  92%|█████████▏| 567/619 [13:40<01:15,  1.45s/it, training_loss=0.195]
# Epoch 3:  92%|█████████▏| 567/619 [13:41<01:15,  1.45s/it, training_loss=0.076]
# Epoch 3:  92%|█████████▏| 568/619 [13:41<01:13,  1.45s/it, training_loss=0.076]
# Epoch 3:  92%|█████████▏| 568/619 [13:43<01:13,  1.45s/it, training_loss=0.161]
# Epoch 3:  92%|█████████▏| 569/619 [13:43<01:12,  1.45s/it, training_loss=0.161]
# Epoch 3:  92%|█████████▏| 569/619 [13:44<01:12,  1.45s/it, training_loss=0.065]
# Epoch 3:  92%|█████████▏| 570/619 [13:44<01:10,  1.45s/it, training_loss=0.065]
# Epoch 3:  92%|█████████▏| 570/619 [13:46<01:10,  1.45s/it, training_loss=0.028]
# Epoch 3:  92%|█████████▏| 571/619 [13:46<01:09,  1.45s/it, training_loss=0.028]
# Epoch 3:  92%|█████████▏| 571/619 [13:47<01:09,  1.45s/it, training_loss=0.062]
# Epoch 3:  92%|█████████▏| 572/619 [13:47<01:08,  1.45s/it, training_loss=0.062]
# Epoch 3:  92%|█████████▏| 572/619 [13:49<01:08,  1.45s/it, training_loss=0.089]
# Epoch 3:  93%|█████████▎| 573/619 [13:49<01:06,  1.45s/it, training_loss=0.089]
# Epoch 3:  93%|█████████▎| 573/619 [13:50<01:06,  1.45s/it, training_loss=0.098]
# Epoch 3:  93%|█████████▎| 574/619 [13:50<01:05,  1.45s/it, training_loss=0.098]
# Epoch 3:  93%|█████████▎| 574/619 [13:51<01:05,  1.45s/it, training_loss=0.067]
# Epoch 3:  93%|█████████▎| 575/619 [13:51<01:03,  1.45s/it, training_loss=0.067]
# Epoch 3:  93%|█████████▎| 575/619 [13:53<01:03,  1.45s/it, training_loss=0.054]
# Epoch 3:  93%|█████████▎| 576/619 [13:53<01:02,  1.45s/it, training_loss=0.054]
# Epoch 3:  93%|█████████▎| 576/619 [13:54<01:02,  1.45s/it, training_loss=0.151]
# Epoch 3:  93%|█████████▎| 577/619 [13:54<01:00,  1.45s/it, training_loss=0.151]
# Epoch 3:  93%|█████████▎| 577/619 [13:56<01:00,  1.45s/it, training_loss=0.044]
# Epoch 3:  93%|█████████▎| 578/619 [13:56<00:59,  1.45s/it, training_loss=0.044]
# Epoch 3:  93%|█████████▎| 578/619 [13:57<00:59,  1.45s/it, training_loss=0.064]
# Epoch 3:  94%|█████████▎| 579/619 [13:57<00:57,  1.44s/it, training_loss=0.064]
# Epoch 3:  94%|█████████▎| 579/619 [13:59<00:57,  1.44s/it, training_loss=0.036]
# Epoch 3:  94%|█████████▎| 580/619 [13:59<00:56,  1.45s/it, training_loss=0.036]
# Epoch 3:  94%|█████████▎| 580/619 [14:00<00:56,  1.45s/it, training_loss=0.202]
# Epoch 3:  94%|█████████▍| 581/619 [14:00<00:54,  1.45s/it, training_loss=0.202]
# Epoch 3:  94%|█████████▍| 581/619 [14:02<00:54,  1.45s/it, training_loss=0.149]
# Epoch 3:  94%|█████████▍| 582/619 [14:02<00:53,  1.45s/it, training_loss=0.149]
# Epoch 3:  94%|█████████▍| 582/619 [14:03<00:53,  1.45s/it, training_loss=0.080]
# Epoch 3:  94%|█████████▍| 583/619 [14:03<00:52,  1.45s/it, training_loss=0.080]
# Epoch 3:  94%|█████████▍| 583/619 [14:04<00:52,  1.45s/it, training_loss=0.034]
# Epoch 3:  94%|█████████▍| 584/619 [14:04<00:50,  1.45s/it, training_loss=0.034]
# Epoch 3:  94%|█████████▍| 584/619 [14:06<00:50,  1.45s/it, training_loss=0.154]
# Epoch 3:  95%|█████████▍| 585/619 [14:06<00:49,  1.45s/it, training_loss=0.154]
# Epoch 3:  95%|█████████▍| 585/619 [14:07<00:49,  1.45s/it, training_loss=0.026]
# Epoch 3:  95%|█████████▍| 586/619 [14:07<00:47,  1.45s/it, training_loss=0.026]
# Epoch 3:  95%|█████████▍| 586/619 [14:09<00:47,  1.45s/it, training_loss=0.095]
# Epoch 3:  95%|█████████▍| 587/619 [14:09<00:46,  1.45s/it, training_loss=0.095]
# Epoch 3:  95%|█████████▍| 587/619 [14:10<00:46,  1.45s/it, training_loss=0.174]
# Epoch 3:  95%|█████████▍| 588/619 [14:10<00:44,  1.45s/it, training_loss=0.174]
# Epoch 3:  95%|█████████▍| 588/619 [14:12<00:44,  1.45s/it, training_loss=0.038]
# Epoch 3:  95%|█████████▌| 589/619 [14:12<00:43,  1.45s/it, training_loss=0.038]
# Epoch 3:  95%|█████████▌| 589/619 [14:13<00:43,  1.45s/it, training_loss=0.042]
# Epoch 3:  95%|█████████▌| 590/619 [14:13<00:41,  1.45s/it, training_loss=0.042]
# Epoch 3:  95%|█████████▌| 590/619 [14:15<00:41,  1.45s/it, training_loss=0.072]
# Epoch 3:  95%|█████████▌| 591/619 [14:15<00:40,  1.45s/it, training_loss=0.072]
# Epoch 3:  95%|█████████▌| 591/619 [14:16<00:40,  1.45s/it, training_loss=0.102]
# Epoch 3:  96%|█████████▌| 592/619 [14:16<00:39,  1.45s/it, training_loss=0.102]
# Epoch 3:  96%|█████████▌| 592/619 [14:17<00:39,  1.45s/it, training_loss=0.015]
# Epoch 3:  96%|█████████▌| 593/619 [14:17<00:37,  1.45s/it, training_loss=0.015]
# Epoch 3:  96%|█████████▌| 593/619 [14:19<00:37,  1.45s/it, training_loss=0.056]
# Epoch 3:  96%|█████████▌| 594/619 [14:19<00:36,  1.45s/it, training_loss=0.056]
# Epoch 3:  96%|█████████▌| 594/619 [14:20<00:36,  1.45s/it, training_loss=0.115]
# Epoch 3:  96%|█████████▌| 595/619 [14:20<00:34,  1.45s/it, training_loss=0.115]
# Epoch 3:  96%|█████████▌| 595/619 [14:22<00:34,  1.45s/it, training_loss=0.064]
# Epoch 3:  96%|█████████▋| 596/619 [14:22<00:33,  1.45s/it, training_loss=0.064]
# Epoch 3:  96%|█████████▋| 596/619 [14:23<00:33,  1.45s/it, training_loss=0.093]
# Epoch 3:  96%|█████████▋| 597/619 [14:23<00:31,  1.45s/it, training_loss=0.093]
# Epoch 3:  96%|█████████▋| 597/619 [14:25<00:31,  1.45s/it, training_loss=0.141]
# Epoch 3:  97%|█████████▋| 598/619 [14:25<00:30,  1.45s/it, training_loss=0.141]
# Epoch 3:  97%|█████████▋| 598/619 [14:26<00:30,  1.45s/it, training_loss=0.084]
# Epoch 3:  97%|█████████▋| 599/619 [14:26<00:29,  1.45s/it, training_loss=0.084]
# Epoch 3:  97%|█████████▋| 599/619 [14:28<00:29,  1.45s/it, training_loss=0.123]
# Epoch 3:  97%|█████████▋| 600/619 [14:28<00:27,  1.45s/it, training_loss=0.123]
# Epoch 3:  97%|█████████▋| 600/619 [14:29<00:27,  1.45s/it, training_loss=0.053]
# Epoch 3:  97%|█████████▋| 601/619 [14:29<00:26,  1.45s/it, training_loss=0.053]
# Epoch 3:  97%|█████████▋| 601/619 [14:31<00:26,  1.45s/it, training_loss=0.051]
# Epoch 3:  97%|█████████▋| 602/619 [14:31<00:24,  1.45s/it, training_loss=0.051]
# Epoch 3:  97%|█████████▋| 602/619 [14:32<00:24,  1.45s/it, training_loss=0.082]
# Epoch 3:  97%|█████████▋| 603/619 [14:32<00:23,  1.45s/it, training_loss=0.082]
# Epoch 3:  97%|█████████▋| 603/619 [14:33<00:23,  1.45s/it, training_loss=0.137]
# Epoch 3:  98%|█████████▊| 604/619 [14:33<00:21,  1.45s/it, training_loss=0.137]
# Epoch 3:  98%|█████████▊| 604/619 [14:35<00:21,  1.45s/it, training_loss=0.112]
# Epoch 3:  98%|█████████▊| 605/619 [14:35<00:20,  1.45s/it, training_loss=0.112]
# Epoch 3:  98%|█████████▊| 605/619 [14:36<00:20,  1.45s/it, training_loss=0.027]
# Epoch 3:  98%|█████████▊| 606/619 [14:36<00:18,  1.45s/it, training_loss=0.027]
# Epoch 3:  98%|█████████▊| 606/619 [14:38<00:18,  1.45s/it, training_loss=0.171]
# Epoch 3:  98%|█████████▊| 607/619 [14:38<00:17,  1.45s/it, training_loss=0.171]
# Epoch 3:  98%|█████████▊| 607/619 [14:39<00:17,  1.45s/it, training_loss=0.069]
# Epoch 3:  98%|█████████▊| 608/619 [14:39<00:15,  1.45s/it, training_loss=0.069]
# Epoch 3:  98%|█████████▊| 608/619 [14:41<00:15,  1.45s/it, training_loss=0.130]
# Epoch 3:  98%|█████████▊| 609/619 [14:41<00:14,  1.45s/it, training_loss=0.130]
# Epoch 3:  98%|█████████▊| 609/619 [14:42<00:14,  1.45s/it, training_loss=0.104]
# Epoch 3:  99%|█████████▊| 610/619 [14:42<00:13,  1.45s/it, training_loss=0.104]
# Epoch 3:  99%|█████████▊| 610/619 [14:44<00:13,  1.45s/it, training_loss=0.084]
# Epoch 3:  99%|█████████▊| 611/619 [14:44<00:11,  1.45s/it, training_loss=0.084]
# Epoch 3:  99%|█████████▊| 611/619 [14:45<00:11,  1.45s/it, training_loss=0.163]
# Epoch 3:  99%|█████████▉| 612/619 [14:45<00:10,  1.45s/it, training_loss=0.163]
# Epoch 3:  99%|█████████▉| 612/619 [14:46<00:10,  1.45s/it, training_loss=0.069]
# Epoch 3:  99%|█████████▉| 613/619 [14:46<00:08,  1.45s/it, training_loss=0.069]
# Epoch 3:  99%|█████████▉| 613/619 [14:48<00:08,  1.45s/it, training_loss=0.081]
# Epoch 3:  99%|█████████▉| 614/619 [14:48<00:07,  1.45s/it, training_loss=0.081]
# Epoch 3:  99%|█████████▉| 614/619 [14:49<00:07,  1.45s/it, training_loss=0.193]
# Epoch 3:  99%|█████████▉| 615/619 [14:49<00:05,  1.45s/it, training_loss=0.193]
# Epoch 3:  99%|█████████▉| 615/619 [14:51<00:05,  1.45s/it, training_loss=0.105]
# Epoch 3: 100%|█████████▉| 616/619 [14:51<00:04,  1.45s/it, training_loss=0.105]
# Epoch 3: 100%|█████████▉| 616/619 [14:52<00:04,  1.45s/it, training_loss=0.158]
# Epoch 3: 100%|█████████▉| 617/619 [14:52<00:02,  1.44s/it, training_loss=0.158]
# Epoch 3: 100%|█████████▉| 617/619 [14:54<00:02,  1.44s/it, training_loss=0.133]
# Epoch 3: 100%|█████████▉| 618/619 [14:54<00:01,  1.45s/it, training_loss=0.133]
# Epoch 3: 100%|█████████▉| 618/619 [14:55<00:01,  1.45s/it, training_loss=0.138]
# Epoch 3: 100%|██████████| 619/619 [14:55<00:00,  1.28s/it, training_loss=0.138]
#  67%|██████▋   | 2/3 [48:36<16:43, 1003.55s/it]
# Epoch 3
# Training loss: 0.22066833620653253
# 100%|██████████| 3/3 [50:29<00:00, 1009.96s/it]
# Validation loss: 0.43640579412812774
# F1 Score (Weighted): 0.8533916048425736

# %%
accuracy_per_class(predictions, true_vals)
# Out:
# Class: Yes
# Accuracy: 3051/3326 = 0.9173180998196031
#
# Class: No
# Accuracy: 2083/2567 = 0.8114530580444098
#
# Class: In the middle, neither yes nor no
# Accuracy: 68/190 = 0.35789473684210527
#
# Class: Yes, subject to some conditions
# Accuracy: 445/516 = 0.8624031007751938

# %%
print('Dev Accuracy:', end = ' ')
flat_accuracy(predictions, true_vals)
# Out:
# Dev Accuracy:
# 0.8557357175329595

# %%
encoded_data_test = tokenizer.batch_encode_plus(
    df[df.data_type=='test'].YN_r.values, 
    add_special_tokens=True, 
    return_attention_mask=True, 
    pad_to_max_length=True, 
    max_length=256, 
    return_tensors='pt'
)

input_ids_test = encoded_data_test['input_ids']
attention_masks_test = encoded_data_test['attention_mask']
labels_test = torch.tensor(df[df.data_type=='test'].relaxed.values)

dataset_test = TensorDataset(input_ids_test, attention_masks_test, labels_test)

dataloader_test = DataLoader(dataset_test, 
                                   sampler=SequentialSampler(dataset_test), 
                                   batch_size=batch_size)

test_loss, test_predictions, test_true_vals = evaluate(dataloader_test)
test_f1 = f1_score_func(test_predictions, test_true_vals)
print(test_f1)
# Out:
# 0.8551599146117593

# %%
accuracy_per_class(test_predictions, test_true_vals)
print('Test Accuracy:', end = ' ')
flat_accuracy(test_predictions, test_true_vals)
# Out:
# Class: Yes
# Accuracy: 3021/3326 = 0.9082982561635599
#
# Class: No
# Accuracy: 2118/2566 = 0.8254091971940763
#
# Class: In the middle, neither yes nor no
# Accuracy: 70/190 = 0.3684210526315789
#
# Class: Yes, subject to some conditions
# Accuracy: 444/517 = 0.8588007736943907
#
# Test Accuracy:
# 0.8566449462039702
