# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd '/content/drive/MyDrive/NYU_class/NLU/Project'
# Out:
# /content/drive/MyDrive/NYU_class/NLU/Project

# %%
# !pip install transformers
# Out:
# Collecting transformers
#   Downloading https://files.pythonhosted.org/packages/81/91/61d69d58a1af1bd81d9ca9d62c90a6de3ab80d77f27c5df65d9a2c1f5626/transformers-4.5.0-py3-none-any.whl (2.1MB)
#      |████████████████████████████████| 2.2MB 17.9MB/s
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.19.5)
# Collecting tokenizers<0.11,>=0.10.1
#   Downloading https://files.pythonhosted.org/packages/ae/04/5b870f26a858552025a62f1649c20d29d2672c02ff3c3fb4c688ca46467a/tokenizers-0.10.2-cp37-cp37m-manylinux2010_x86_64.whl (3.3MB)
#      |████████████████████████████████| 3.3MB 27.9MB/s
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.41.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from transformers) (3.8.1)
# Collecting sacremoses
#   Downloading https://files.pythonhosted.org/packages/08/cd/342e584ee544d044fb573ae697404ce22ede086c9e87ce5960772084cad0/sacremoses-0.0.44.tar.gz (862kB)
#      |████████████████████████████████| 870kB 47.3MB/s
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from transformers) (20.9)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.0.12)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2019.12.20)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->transformers) (3.4.1)
# Requirement already satisfied: typing-extensions>=3.6.4; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->transformers) (3.7.4.3)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.15.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.0.1)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->transformers) (2.4.7)
# Building wheels for collected packages: sacremoses
#   Building wheel for sacremoses (setup.py) ... done
#   Created wheel for sacremoses: filename=sacremoses-0.0.44-cp37-none-any.whl size=886084 sha256=2d4202345abe49d0358f8702ab24a4df2b5cd6c0f25d65d7f1ea697aa2b8b46e
#   Stored in directory: /root/.cache/pip/wheels/3e/fb/c0/13ab4d63d537658f448366744654323077c4d90069b6512f3c
# Successfully built sacremoses
# Installing collected packages: tokenizers, sacremoses, transformers
# Successfully installed sacremoses-0.0.44 tokenizers-0.10.2 transformers-4.5.0

# %%
import torch
import torch.nn as nn 
from torch.utils.data import DataLoader, RandomSampler, SequentialSampler, TensorDataset

from transformers import AutoTokenizer, BertTokenizer, EvalPrediction, BertPreTrainedModel, BertConfig, BertModel, BertForSequenceClassification, AdamW, get_linear_schedule_with_warmup

import random
import pandas as pd
import numpy as np
from tqdm import tqdm

from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score

# %% [markdown]
# ## Data pre-processing

# %% [markdown]
# Relaxed-matched

# %%
circa_og = pd.read_csv('circa-data.tsv', sep='\t', index_col='id')
circa_r = circa_og.drop(circa_og.loc[circa_og['goldstandard2']=='Other'].index)
circa_r = circa_r.drop(circa_r.loc[circa_r['goldstandard2'].isnull()].index)

# %%
YN_r = (circa_r['question-X'].map(str)+' '+circa_r['answer-Y']).apply(lambda row: row.strip())
relaxed_labels = circa_r['goldstandard2'].unique()
relaxed_label = circa_r['goldstandard2']
relaxed_dict = {}
for idx, label in enumerate(relaxed_labels):
    relaxed_dict[label] = idx
circa_r['relaxed'] = circa_r.goldstandard2.replace(relaxed_dict)
relaxed = circa_r['relaxed']

# %% [markdown]
# ## Modeling

# %%
import tensorflow as tf

# Get the GPU device name.
device_name = tf.test.gpu_device_name()
print(device_name)

if torch.cuda.is_available():    

    # Tell PyTorch to use the GPU.    
    device = torch.device("cuda")
# Out:
# /device:GPU:0

# %% [markdown]
# ### Strict

# %%
model_name = 'bert-large-uncased'
model = BertForSequenceClassification.from_pretrained(model_name, num_labels=len(relaxed_dict),output_attentions = False, output_hidden_states = False,)
tokenizer = BertTokenizer.from_pretrained(model_name, do_lower_case=True)
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=434.0, style=ProgressStyle(description_…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=1344997306.0, style=ProgressStyle(descr…
# Some weights of the model checkpoint at bert-large-uncased were not used when initializing BertForSequenceClassification: ['cls.predictions.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.decoder.weight', 'cls.seq_relationship.weight', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-large-uncased and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=231508.0, style=ProgressStyle(descripti…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=28.0, style=ProgressStyle(description_w…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=466062.0, style=ProgressStyle(descripti…

# %%
max_len = 0
for entry in YN_r.values:
    input_ids = tokenizer.encode(entry,  add_special_tokens=True)
    max_len = max(max_len, len(input_ids))
print(max_len)
# Out:
# 43

# %%
df = pd.concat([YN_r, relaxed_label, relaxed], axis=1).rename(columns={0:'YN_r'})
df
# Out:
#                                                     YN_r  ... relaxed
# id                                                        ...
# 0         Are you employed? I'm a veterinary technician.  ...       0
# 1        Are you a fan of Korean food? I wouldn't say so  ...       1
# 2      Are you bringing any pets into the flat? I do ...  ...       1
# 3      Would you like to get some fresh air in your f...  ...       0
# 4      Is your family still living in the neighborhoo...  ...       2
# ...                                                  ...  ...     ...
# 34263                  Do you like to drink? I am in AA.  ...       1
# 34264         Do you like pie? My favorite pie is pecan.  ...       0
# 34265  Want to go to a concert with me? I'd rather do...  ...       1
# 34266  Do you like hip/hop music? I can't dance to hi...  ...       1
# 34267  Do you see yourself raising a family in New Yo...  ...       1
#
# [32993 rows x 3 columns]

# %%
train_relaxed, val_relaxed, trainy_relaxed, valy_relaxed = train_test_split(df.index.values, df.relaxed.values, test_size=.4, stratify=df.relaxed.values)
test_relaxed, dev_relaxed, testy_relaxed, devy_relaxed = train_test_split(val_relaxed, valy_relaxed, test_size=.5, stratify=valy_relaxed)

# %%
df['data_type'] = ['not_set']*df.shape[0]
df.loc[train_relaxed,'data_type'] = 'train'
df.loc[dev_relaxed,'data_type'] = 'dev'
df.loc[test_relaxed,'data_type'] = 'test'

# %%
df.groupby(['goldstandard2','relaxed','data_type']).count()
# Out:
#                                                      YN_r
# goldstandard2                     relaxed data_type
# In the middle, neither yes nor no 2       dev         190
#                                           test        190
#                                           train       569
# No                                1       dev        2566
#                                           test       2567
#                                           train      7700
# Yes                               0       dev        3326
#                                           test       3326
#                                           train      9976
# Yes, subject to some conditions   3       dev         517
#                                           test        516
#                                           train      1550

# %%
encoded_data_train = tokenizer.batch_encode_plus(
    df[df.data_type=='train'].YN_r.values, 
    add_special_tokens=True, 
    return_attention_mask=True, 
    pad_to_max_length=True, 
    max_length=256, 
    return_tensors='pt'
)

encoded_data_dev = tokenizer.batch_encode_plus(
    df[df.data_type=='dev'].YN_r.values, 
    add_special_tokens=True, 
    return_attention_mask=True, 
    pad_to_max_length=True, 
    max_length=256, 
    return_tensors='pt'
)


input_ids_train = encoded_data_train['input_ids']
attention_masks_train = encoded_data_train['attention_mask']
labels_train = torch.tensor(df[df.data_type=='train'].relaxed.values)

input_ids_dev = encoded_data_dev['input_ids']
attention_masks_dev = encoded_data_dev['attention_mask']
labels_dev = torch.tensor(df[df.data_type=='dev'].relaxed.values)
# Out:
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2079: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   FutureWarning,

# %%
dataset_train = TensorDataset(input_ids_train, attention_masks_train, labels_train)
dataset_dev = TensorDataset(input_ids_dev, attention_masks_dev, labels_dev)

# %%
len(dataset_train)
# Out:
# 19795

# %%
model = BertForSequenceClassification.from_pretrained("bert-base-uncased",
                                                      num_labels=len(relaxed_dict),
                                                      output_attentions=False,
                                                      output_hidden_states=False)
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=433.0, style=ProgressStyle(description_…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=440473133.0, style=ProgressStyle(descri…
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForSequenceClassification: ['cls.predictions.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.decoder.weight', 'cls.seq_relationship.weight', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
batch_size = 32

dataloader_train = DataLoader(dataset_train, 
                              sampler=RandomSampler(dataset_train), 
                              batch_size=batch_size)

dataloader_validation = DataLoader(dataset_dev, 
                                   sampler=SequentialSampler(dataset_dev), 
                                   batch_size=batch_size)

optimizer = AdamW(model.parameters(),
                  lr = 3e-5,
                  eps = 1e-8)

# %%
epochs = 3
total_steps = len(dataloader_train) * epochs
scheduler = get_linear_schedule_with_warmup(optimizer, 
                                            num_warmup_steps = 0, 
                                            num_training_steps = total_steps)

# %%
def f1_score_func(preds, labels):
    preds_flat = np.argmax(preds, axis=1).flatten()
    labels_flat = labels.flatten()
    return f1_score(labels_flat, preds_flat, average='weighted')

def accuracy_per_class(preds, labels):
    label_dict_inverse = {v: k for k, v in relaxed_dict.items()}
    
    preds_flat = np.argmax(preds, axis=1).flatten()
    labels_flat = labels.flatten()

    for label in np.unique(labels_flat):
        y_preds = preds_flat[labels_flat==label]
        y_true = labels_flat[labels_flat==label]
        print(f'Class: {label_dict_inverse[label]}')
        print(f'Accuracy: {len(y_preds[y_preds==label])}/{len(y_true)}\n')

def flat_accuracy(preds, labels):
    pred_flat = np.argmax(preds, axis=1).flatten()
    labels_flat = labels.flatten()
    return np.sum(pred_flat == labels_flat) / len(labels_flat)

# %%
seed_val = 42

random.seed(seed_val)
np.random.seed(seed_val)
torch.manual_seed(seed_val)
torch.cuda.manual_seed_all(seed_val)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model.to(device)

print(device)
# Out:
# cuda

# %%
def evaluate(dataloader_val):

    model.eval()
    
    loss_val_total = 0
    predictions, true_vals = [], []
    
    for batch in dataloader_val:
        
        batch = tuple(b.to(device) for b in batch)
        
        inputs = {'input_ids':      batch[0],
                  'attention_mask': batch[1],
                  'labels':         batch[2],
                 }

        with torch.no_grad():        
            outputs = model(**inputs)
            
        loss = outputs[0]
        logits = outputs[1]
        loss_val_total += loss.item()

        logits = logits.detach().cpu().numpy()
        label_ids = inputs['labels'].cpu().numpy()
        predictions.append(logits)
        true_vals.append(label_ids)
    
    loss_val_avg = loss_val_total/len(dataloader_val) 
    
    predictions = np.concatenate(predictions, axis=0)
    true_vals = np.concatenate(true_vals, axis=0)
            
    return loss_val_avg, predictions, true_vals

# %%
for epoch in tqdm(range(1, epochs+1)):
    
    model.train()
    
    loss_train_total = 0

    progress_bar = tqdm(dataloader_train, desc='Epoch {:1d}'.format(epoch), leave=False, disable=False)
    for batch in progress_bar:

        model.zero_grad()
        
        batch = tuple(b.to(device) for b in batch)
        
        inputs = {'input_ids':      batch[0],
                  'attention_mask': batch[1],
                  'labels':         batch[2],
                 }       

        outputs = model(**inputs)
        
        loss = outputs[0]
        loss_train_total += loss.item()
        loss.backward()

        torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)

        optimizer.step()
        scheduler.step()
        
        progress_bar.set_postfix({'training_loss': '{:.3f}'.format(loss.item()/len(batch))})
         
        
    torch.save(model.state_dict(), f'finetuned_BERT_relaxed_epoch_{epoch}.model')
        
    tqdm.write(f'\nEpoch {epoch}')
    
    loss_train_avg = loss_train_total/len(dataloader_train)            
    tqdm.write(f'Training loss: {loss_train_avg}')
    
    dev_loss, predictions, true_vals = evaluate(dataloader_validation)
    dev_f1 = f1_score_func(predictions, true_vals)
    tqdm.write(f'Validation loss: {dev_loss}')
    tqdm.write(f'F1 Score (Weighted): {dev_f1}')
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 1:   0%|          | 0/619 [00:00<?, ?it/s]
# Epoch 1:   0%|          | 0/619 [00:01<?, ?it/s, training_loss=0.465]
# Epoch 1:   0%|          | 1/619 [00:01<15:03,  1.46s/it, training_loss=0.465]
# Epoch 1:   0%|          | 1/619 [00:02<15:03,  1.46s/it, training_loss=0.441]
# Epoch 1:   0%|          | 2/619 [00:02<14:28,  1.41s/it, training_loss=0.441]
# Epoch 1:   0%|          | 2/619 [00:04<14:28,  1.41s/it, training_loss=0.418]
# Epoch 1:   0%|          | 3/619 [00:04<14:04,  1.37s/it, training_loss=0.418]
# Epoch 1:   0%|          | 3/619 [00:05<14:04,  1.37s/it, training_loss=0.392]
# Epoch 1:   1%|          | 4/619 [00:05<13:46,  1.34s/it, training_loss=0.392]
# Epoch 1:   1%|          | 4/619 [00:06<13:46,  1.34s/it, training_loss=0.393]
# Epoch 1:   1%|          | 5/619 [00:06<13:35,  1.33s/it, training_loss=0.393]
# Epoch 1:   1%|          | 5/619 [00:07<13:35,  1.33s/it, training_loss=0.393]
# Epoch 1:   1%|          | 6/619 [00:07<13:27,  1.32s/it, training_loss=0.393]
# Epoch 1:   1%|          | 6/619 [00:09<13:27,  1.32s/it, training_loss=0.337]
# Epoch 1:   1%|          | 7/619 [00:09<13:23,  1.31s/it, training_loss=0.337]
# Epoch 1:   1%|          | 7/619 [00:10<13:23,  1.31s/it, training_loss=0.365]
# Epoch 1:   1%|▏         | 8/619 [00:10<13:19,  1.31s/it, training_loss=0.365]
# Epoch 1:   1%|▏         | 8/619 [00:11<13:19,  1.31s/it, training_loss=0.365]
# Epoch 1:   1%|▏         | 9/619 [00:11<13:16,  1.31s/it, training_loss=0.365]
# Epoch 1:   1%|▏         | 9/619 [00:13<13:16,  1.31s/it, training_loss=0.356]
# Epoch 1:   2%|▏         | 10/619 [00:13<13:13,  1.30s/it, training_loss=0.356]
# Epoch 1:   2%|▏         | 10/619 [00:14<13:13,  1.30s/it, training_loss=0.311]
# Epoch 1:   2%|▏         | 11/619 [00:14<13:11,  1.30s/it, training_loss=0.311]
# Epoch 1:   2%|▏         | 11/619 [00:15<13:11,  1.30s/it, training_loss=0.327]
# Epoch 1:   2%|▏         | 12/619 [00:15<13:13,  1.31s/it, training_loss=0.327]
# Epoch 1:   2%|▏         | 12/619 [00:17<13:13,  1.31s/it, training_loss=0.312]
# Epoch 1:   2%|▏         | 13/619 [00:17<13:14,  1.31s/it, training_loss=0.312]
# Epoch 1:   2%|▏         | 13/619 [00:18<13:14,  1.31s/it, training_loss=0.321]
# Epoch 1:   2%|▏         | 14/619 [00:18<13:15,  1.32s/it, training_loss=0.321]
# Epoch 1:   2%|▏         | 14/619 [00:19<13:15,  1.32s/it, training_loss=0.319]
# Epoch 1:   2%|▏         | 15/619 [00:19<13:14,  1.32s/it, training_loss=0.319]
# Epoch 1:   2%|▏         | 15/619 [00:20<13:14,  1.32s/it, training_loss=0.327]
# Epoch 1:   3%|▎         | 16/619 [00:20<13:13,  1.32s/it, training_loss=0.327]
# Epoch 1:   3%|▎         | 16/619 [00:22<13:13,  1.32s/it, training_loss=0.317]
# Epoch 1:   3%|▎         | 17/619 [00:22<13:13,  1.32s/it, training_loss=0.317]
# Epoch 1:   3%|▎         | 17/619 [00:23<13:13,  1.32s/it, training_loss=0.322]
# Epoch 1:   3%|▎         | 18/619 [00:23<13:14,  1.32s/it, training_loss=0.322]
# Epoch 1:   3%|▎         | 18/619 [00:24<13:14,  1.32s/it, training_loss=0.337]
# Epoch 1:   3%|▎         | 19/619 [00:24<13:16,  1.33s/it, training_loss=0.337]
# Epoch 1:   3%|▎         | 19/619 [00:26<13:16,  1.33s/it, training_loss=0.367]
# Epoch 1:   3%|▎         | 20/619 [00:26<13:19,  1.33s/it, training_loss=0.367]
# Epoch 1:   3%|▎         | 20/619 [00:27<13:19,  1.33s/it, training_loss=0.355]
# Epoch 1:   3%|▎         | 21/619 [00:27<13:18,  1.34s/it, training_loss=0.355]
# Epoch 1:   3%|▎         | 21/619 [00:28<13:18,  1.34s/it, training_loss=0.287]
# Epoch 1:   4%|▎         | 22/619 [00:29<13:16,  1.33s/it, training_loss=0.287]
# Epoch 1:   4%|▎         | 22/619 [00:30<13:16,  1.33s/it, training_loss=0.331]
# Epoch 1:   4%|▎         | 23/619 [00:30<13:15,  1.33s/it, training_loss=0.331]
# Epoch 1:   4%|▎         | 23/619 [00:31<13:15,  1.33s/it, training_loss=0.282]
# Epoch 1:   4%|▍         | 24/619 [00:31<13:14,  1.34s/it, training_loss=0.282]
# Epoch 1:   4%|▍         | 24/619 [00:33<13:14,  1.34s/it, training_loss=0.253]
# Epoch 1:   4%|▍         | 25/619 [00:33<13:15,  1.34s/it, training_loss=0.253]
# Epoch 1:   4%|▍         | 25/619 [00:34<13:15,  1.34s/it, training_loss=0.315]
# Epoch 1:   4%|▍         | 26/619 [00:34<13:14,  1.34s/it, training_loss=0.315]
# Epoch 1:   4%|▍         | 26/619 [00:35<13:14,  1.34s/it, training_loss=0.274]
# Epoch 1:   4%|▍         | 27/619 [00:35<13:17,  1.35s/it, training_loss=0.274]
# Epoch 1:   4%|▍         | 27/619 [00:37<13:17,  1.35s/it, training_loss=0.371]
# Epoch 1:   5%|▍         | 28/619 [00:37<13:20,  1.35s/it, training_loss=0.371]
# Epoch 1:   5%|▍         | 28/619 [00:38<13:20,  1.35s/it, training_loss=0.284]
# Epoch 1:   5%|▍         | 29/619 [00:38<13:20,  1.36s/it, training_loss=0.284]
# Epoch 1:   5%|▍         | 29/619 [00:39<13:20,  1.36s/it, training_loss=0.371]
# Epoch 1:   5%|▍         | 30/619 [00:39<13:20,  1.36s/it, training_loss=0.371]
# Epoch 1:   5%|▍         | 30/619 [00:41<13:20,  1.36s/it, training_loss=0.304]
# Epoch 1:   5%|▌         | 31/619 [00:41<13:19,  1.36s/it, training_loss=0.304]
# Epoch 1:   5%|▌         | 31/619 [00:42<13:19,  1.36s/it, training_loss=0.295]
# Epoch 1:   5%|▌         | 32/619 [00:42<13:19,  1.36s/it, training_loss=0.295]
# Epoch 1:   5%|▌         | 32/619 [00:43<13:19,  1.36s/it, training_loss=0.262]
# Epoch 1:   5%|▌         | 33/619 [00:43<13:17,  1.36s/it, training_loss=0.262]
# Epoch 1:   5%|▌         | 33/619 [00:45<13:17,  1.36s/it, training_loss=0.280]
# Epoch 1:   5%|▌         | 34/619 [00:45<13:17,  1.36s/it, training_loss=0.280]
# Epoch 1:   5%|▌         | 34/619 [00:46<13:17,  1.36s/it, training_loss=0.250]
# Epoch 1:   6%|▌         | 35/619 [00:46<13:19,  1.37s/it, training_loss=0.250]
# Epoch 1:   6%|▌         | 35/619 [00:48<13:19,  1.37s/it, training_loss=0.230]
# Epoch 1:   6%|▌         | 36/619 [00:48<13:20,  1.37s/it, training_loss=0.230]
# Epoch 1:   6%|▌         | 36/619 [00:49<13:20,  1.37s/it, training_loss=0.331]
# Epoch 1:   6%|▌         | 37/619 [00:49<13:20,  1.38s/it, training_loss=0.331]
# Epoch 1:   6%|▌         | 37/619 [00:50<13:20,  1.38s/it, training_loss=0.267]
# Epoch 1:   6%|▌         | 38/619 [00:50<13:21,  1.38s/it, training_loss=0.267]
# Epoch 1:   6%|▌         | 38/619 [00:52<13:21,  1.38s/it, training_loss=0.217]
# Epoch 1:   6%|▋         | 39/619 [00:52<13:22,  1.38s/it, training_loss=0.217]
# Epoch 1:   6%|▋         | 39/619 [00:53<13:22,  1.38s/it, training_loss=0.239]
# Epoch 1:   6%|▋         | 40/619 [00:53<13:23,  1.39s/it, training_loss=0.239]
# Epoch 1:   6%|▋         | 40/619 [00:55<13:23,  1.39s/it, training_loss=0.252]
# Epoch 1:   7%|▋         | 41/619 [00:55<13:23,  1.39s/it, training_loss=0.252]
# Epoch 1:   7%|▋         | 41/619 [00:56<13:23,  1.39s/it, training_loss=0.240]
# Epoch 1:   7%|▋         | 42/619 [00:56<13:24,  1.39s/it, training_loss=0.240]
# Epoch 1:   7%|▋         | 42/619 [00:57<13:24,  1.39s/it, training_loss=0.218]
# Epoch 1:   7%|▋         | 43/619 [00:57<13:26,  1.40s/it, training_loss=0.218]
# Epoch 1:   7%|▋         | 43/619 [00:59<13:26,  1.40s/it, training_loss=0.228]
# Epoch 1:   7%|▋         | 44/619 [00:59<13:27,  1.40s/it, training_loss=0.228]
# Epoch 1:   7%|▋         | 44/619 [01:00<13:27,  1.40s/it, training_loss=0.243]
# Epoch 1:   7%|▋         | 45/619 [01:00<13:28,  1.41s/it, training_loss=0.243]
# Epoch 1:   7%|▋         | 45/619 [01:02<13:28,  1.41s/it, training_loss=0.255]
# Epoch 1:   7%|▋         | 46/619 [01:02<13:29,  1.41s/it, training_loss=0.255]
# Epoch 1:   7%|▋         | 46/619 [01:03<13:29,  1.41s/it, training_loss=0.292]
# Epoch 1:   8%|▊         | 47/619 [01:03<13:29,  1.42s/it, training_loss=0.292]
# Epoch 1:   8%|▊         | 47/619 [01:04<13:29,  1.42s/it, training_loss=0.232]
# Epoch 1:   8%|▊         | 48/619 [01:04<13:28,  1.42s/it, training_loss=0.232]
# Epoch 1:   8%|▊         | 48/619 [01:06<13:28,  1.42s/it, training_loss=0.198]
# Epoch 1:   8%|▊         | 49/619 [01:06<13:28,  1.42s/it, training_loss=0.198]
# Epoch 1:   8%|▊         | 49/619 [01:07<13:28,  1.42s/it, training_loss=0.321]
# Epoch 1:   8%|▊         | 50/619 [01:07<13:28,  1.42s/it, training_loss=0.321]
# Epoch 1:   8%|▊         | 50/619 [01:09<13:28,  1.42s/it, training_loss=0.299]
# Epoch 1:   8%|▊         | 51/619 [01:09<13:28,  1.42s/it, training_loss=0.299]
# Epoch 1:   8%|▊         | 51/619 [01:10<13:28,  1.42s/it, training_loss=0.223]
# Epoch 1:   8%|▊         | 52/619 [01:10<13:27,  1.42s/it, training_loss=0.223]
# Epoch 1:   8%|▊         | 52/619 [01:12<13:27,  1.42s/it, training_loss=0.293]
# Epoch 1:   9%|▊         | 53/619 [01:12<13:25,  1.42s/it, training_loss=0.293]
# Epoch 1:   9%|▊         | 53/619 [01:13<13:25,  1.42s/it, training_loss=0.223]
# Epoch 1:   9%|▊         | 54/619 [01:13<13:24,  1.42s/it, training_loss=0.223]
# Epoch 1:   9%|▊         | 54/619 [01:14<13:24,  1.42s/it, training_loss=0.212]
# Epoch 1:   9%|▉         | 55/619 [01:14<13:23,  1.42s/it, training_loss=0.212]
# Epoch 1:   9%|▉         | 55/619 [01:16<13:23,  1.42s/it, training_loss=0.331]
# Epoch 1:   9%|▉         | 56/619 [01:16<13:21,  1.42s/it, training_loss=0.331]
# Epoch 1:   9%|▉         | 56/619 [01:17<13:21,  1.42s/it, training_loss=0.213]
# Epoch 1:   9%|▉         | 57/619 [01:17<13:16,  1.42s/it, training_loss=0.213]
# Epoch 1:   9%|▉         | 57/619 [01:19<13:16,  1.42s/it, training_loss=0.325]
# Epoch 1:   9%|▉         | 58/619 [01:19<13:12,  1.41s/it, training_loss=0.325]
# Epoch 1:   9%|▉         | 58/619 [01:20<13:12,  1.41s/it, training_loss=0.182]
# Epoch 1:  10%|▉         | 59/619 [01:20<13:10,  1.41s/it, training_loss=0.182]
# Epoch 1:  10%|▉         | 59/619 [01:21<13:10,  1.41s/it, training_loss=0.235]
# Epoch 1:  10%|▉         | 60/619 [01:21<13:06,  1.41s/it, training_loss=0.235]
# Epoch 1:  10%|▉         | 60/619 [01:23<13:06,  1.41s/it, training_loss=0.221]
# Epoch 1:  10%|▉         | 61/619 [01:23<13:03,  1.40s/it, training_loss=0.221]
# Epoch 1:  10%|▉         | 61/619 [01:24<13:03,  1.40s/it, training_loss=0.218]
# Epoch 1:  10%|█         | 62/619 [01:24<13:01,  1.40s/it, training_loss=0.218]
# Epoch 1:  10%|█         | 62/619 [01:26<13:01,  1.40s/it, training_loss=0.267]
# Epoch 1:  10%|█         | 63/619 [01:26<12:59,  1.40s/it, training_loss=0.267]
# Epoch 1:  10%|█         | 63/619 [01:27<12:59,  1.40s/it, training_loss=0.203]
# Epoch 1:  10%|█         | 64/619 [01:27<12:56,  1.40s/it, training_loss=0.203]
# Epoch 1:  10%|█         | 64/619 [01:28<12:56,  1.40s/it, training_loss=0.176]
# Epoch 1:  11%|█         | 65/619 [01:28<12:53,  1.40s/it, training_loss=0.176]
# Epoch 1:  11%|█         | 65/619 [01:30<12:53,  1.40s/it, training_loss=0.201]
# Epoch 1:  11%|█         | 66/619 [01:30<12:51,  1.40s/it, training_loss=0.201]
# Epoch 1:  11%|█         | 66/619 [01:31<12:51,  1.40s/it, training_loss=0.210]
# Epoch 1:  11%|█         | 67/619 [01:31<12:48,  1.39s/it, training_loss=0.210]
# Epoch 1:  11%|█         | 67/619 [01:33<12:48,  1.39s/it, training_loss=0.307]
# Epoch 1:  11%|█         | 68/619 [01:33<12:46,  1.39s/it, training_loss=0.307]
# Epoch 1:  11%|█         | 68/619 [01:34<12:46,  1.39s/it, training_loss=0.212]
# Epoch 1:  47%|████▋     | 293/619 [06:46<07:34,  1.39s/it, training_loss=0.111]
# Epoch 1:  47%|████▋     | 293/619 [06:47<07:34,  1.39s/it, training_loss=0.178]
# Epoch 1:  47%|████▋     | 294/619 [06:47<07:31,  1.39s/it, training_loss=0.178]
# Epoch 1:  47%|████▋     | 294/619 [06:48<07:31,  1.39s/it, training_loss=0.164]
# Epoch 1:  48%|████▊     | 295/619 [06:48<07:30,  1.39s/it, training_loss=0.164]
# Epoch 1:  48%|████▊     | 295/619 [06:50<07:30,  1.39s/it, training_loss=0.162]
# Epoch 1:  48%|████▊     | 296/619 [06:50<07:28,  1.39s/it, training_loss=0.162]
# Epoch 1:  48%|████▊     | 296/619 [06:51<07:28,  1.39s/it, training_loss=0.258]
# Epoch 1:  48%|████▊     | 297/619 [06:51<07:28,  1.39s/it, training_loss=0.258]
# Epoch 1:  48%|████▊     | 297/619 [06:53<07:28,  1.39s/it, training_loss=0.075]
# Epoch 1:  48%|████▊     | 298/619 [06:53<07:28,  1.40s/it, training_loss=0.075]
# Epoch 1:  48%|████▊     | 298/619 [06:54<07:28,  1.40s/it, training_loss=0.121]
# Epoch 1:  48%|████▊     | 299/619 [06:54<07:26,  1.39s/it, training_loss=0.121]
# Epoch 1:  48%|████▊     | 299/619 [06:55<07:26,  1.39s/it, training_loss=0.235]
# Epoch 1:  48%|████▊     | 300/619 [06:55<07:24,  1.39s/it, training_loss=0.235]
# Epoch 1:  48%|████▊     | 300/619 [06:57<07:24,  1.39s/it, training_loss=0.188]
# ...
# Epoch 3:  84%|████████▍ | 521/619 [12:04<02:16,  1.39s/it, training_loss=0.024]
# Epoch 3:  84%|████████▍ | 521/619 [12:06<02:16,  1.39s/it, training_loss=0.047]
# Epoch 3:  84%|████████▍ | 522/619 [12:06<02:15,  1.39s/it, training_loss=0.047]
# Epoch 3:  84%|████████▍ | 522/619 [12:07<02:15,  1.39s/it, training_loss=0.037]
# Epoch 3:  84%|████████▍ | 523/619 [12:07<02:13,  1.39s/it, training_loss=0.037]
# Epoch 3:  84%|████████▍ | 523/619 [12:09<02:13,  1.39s/it, training_loss=0.077]
# Epoch 3:  85%|████████▍ | 524/619 [12:09<02:12,  1.39s/it, training_loss=0.077]
# Epoch 3:  85%|████████▍ | 524/619 [12:10<02:12,  1.39s/it, training_loss=0.147]
# Epoch 3:  85%|████████▍ | 525/619 [12:10<02:10,  1.39s/it, training_loss=0.147]
# Epoch 3:  85%|████████▍ | 525/619 [12:11<02:10,  1.39s/it, training_loss=0.078]
# Epoch 3:  85%|████████▍ | 526/619 [12:11<02:09,  1.39s/it, training_loss=0.078]
# Epoch 3:  85%|████████▍ | 526/619 [12:13<02:09,  1.39s/it, training_loss=0.024]
# Epoch 3:  85%|████████▌ | 527/619 [12:13<02:08,  1.39s/it, training_loss=0.024]
# Epoch 3:  85%|████████▌ | 527/619 [12:14<02:08,  1.39s/it, training_loss=0.043]
# Epoch 3:  85%|████████▌ | 528/619 [12:14<02:06,  1.39s/it, training_loss=0.043]
# Epoch 3:  85%|████████▌ | 528/619 [12:16<02:06,  1.39s/it, training_loss=0.083]
# Epoch 3:  85%|████████▌ | 529/619 [12:16<02:05,  1.40s/it, training_loss=0.083]
# Epoch 3:  85%|████████▌ | 529/619 [12:17<02:05,  1.40s/it, training_loss=0.053]
# Epoch 3:  86%|████████▌ | 530/619 [12:17<02:04,  1.40s/it, training_loss=0.053]
# Epoch 3:  86%|████████▌ | 530/619 [12:18<02:04,  1.40s/it, training_loss=0.023]
# Epoch 3:  86%|████████▌ | 531/619 [12:18<02:02,  1.40s/it, training_loss=0.023]
# Epoch 3:  86%|████████▌ | 531/619 [12:20<02:02,  1.40s/it, training_loss=0.083]
# Epoch 3:  86%|████████▌ | 532/619 [12:20<02:01,  1.39s/it, training_loss=0.083]
# Epoch 3:  86%|████████▌ | 532/619 [12:21<02:01,  1.39s/it, training_loss=0.082]
# Epoch 3:  86%|████████▌ | 533/619 [12:21<01:59,  1.39s/it, training_loss=0.082]
# Epoch 3:  86%|████████▌ | 533/619 [12:23<01:59,  1.39s/it, training_loss=0.060]
# Epoch 3:  86%|████████▋ | 534/619 [12:23<01:58,  1.39s/it, training_loss=0.060]
# Epoch 3:  86%|████████▋ | 534/619 [12:24<01:58,  1.39s/it, training_loss=0.108]
# Epoch 3:  86%|████████▋ | 535/619 [12:24<01:57,  1.39s/it, training_loss=0.108]
# Epoch 3:  86%|████████▋ | 535/619 [12:25<01:57,  1.39s/it, training_loss=0.064]
# Epoch 3:  87%|████████▋ | 536/619 [12:25<01:55,  1.40s/it, training_loss=0.064]
# Epoch 3:  87%|████████▋ | 536/619 [12:27<01:55,  1.40s/it, training_loss=0.063]
# Epoch 3:  87%|████████▋ | 537/619 [12:27<01:54,  1.40s/it, training_loss=0.063]
# Epoch 3:  87%|████████▋ | 537/619 [12:28<01:54,  1.40s/it, training_loss=0.128]
# Epoch 3:  87%|████████▋ | 538/619 [12:28<01:52,  1.39s/it, training_loss=0.128]
# Epoch 3:  87%|████████▋ | 538/619 [12:30<01:52,  1.39s/it, training_loss=0.077]
# Epoch 3:  87%|████████▋ | 539/619 [12:30<01:51,  1.39s/it, training_loss=0.077]
# Epoch 3:  87%|████████▋ | 539/619 [12:31<01:51,  1.39s/it, training_loss=0.072]
# Epoch 3:  87%|████████▋ | 540/619 [12:31<01:50,  1.39s/it, training_loss=0.072]
# Epoch 3:  87%|████████▋ | 540/619 [12:32<01:50,  1.39s/it, training_loss=0.088]
# Epoch 3:  87%|████████▋ | 541/619 [12:32<01:48,  1.39s/it, training_loss=0.088]
# Epoch 3:  87%|████████▋ | 541/619 [12:34<01:48,  1.39s/it, training_loss=0.060]
# Epoch 3:  88%|████████▊ | 542/619 [12:34<01:47,  1.39s/it, training_loss=0.060]
# Epoch 3:  88%|████████▊ | 542/619 [12:35<01:47,  1.39s/it, training_loss=0.095]
# Epoch 3:  88%|████████▊ | 543/619 [12:35<01:46,  1.40s/it, training_loss=0.095]
# Epoch 3:  88%|████████▊ | 543/619 [12:37<01:46,  1.40s/it, training_loss=0.083]
# Epoch 3:  88%|████████▊ | 544/619 [12:37<01:44,  1.40s/it, training_loss=0.083]
# Epoch 3:  88%|████████▊ | 544/619 [12:38<01:44,  1.40s/it, training_loss=0.061]
# Epoch 3:  88%|████████▊ | 545/619 [12:38<01:43,  1.40s/it, training_loss=0.061]
# Epoch 3:  88%|████████▊ | 545/619 [12:39<01:43,  1.40s/it, training_loss=0.025]
# Epoch 3:  88%|████████▊ | 546/619 [12:39<01:41,  1.39s/it, training_loss=0.025]
# Epoch 3:  88%|████████▊ | 546/619 [12:41<01:41,  1.39s/it, training_loss=0.057]
# Epoch 3:  88%|████████▊ | 547/619 [12:41<01:40,  1.39s/it, training_loss=0.057]
# Epoch 3:  88%|████████▊ | 547/619 [12:42<01:40,  1.39s/it, training_loss=0.089]
# Epoch 3:  89%|████████▊ | 548/619 [12:42<01:38,  1.39s/it, training_loss=0.089]
# Epoch 3:  89%|████████▊ | 548/619 [12:44<01:38,  1.39s/it, training_loss=0.107]
# Epoch 3:  89%|████████▊ | 549/619 [12:44<01:37,  1.39s/it, training_loss=0.107]
# Epoch 3:  89%|████████▊ | 549/619 [12:45<01:37,  1.39s/it, training_loss=0.038]
# Epoch 3:  89%|████████▉ | 550/619 [12:45<01:35,  1.39s/it, training_loss=0.038]
# Epoch 3:  89%|████████▉ | 550/619 [12:46<01:35,  1.39s/it, training_loss=0.038]
# Epoch 3:  89%|████████▉ | 551/619 [12:46<01:34,  1.39s/it, training_loss=0.038]
# Epoch 3:  89%|████████▉ | 551/619 [12:48<01:34,  1.39s/it, training_loss=0.039]
# Epoch 3:  89%|████████▉ | 552/619 [12:48<01:32,  1.39s/it, training_loss=0.039]
# Epoch 3:  89%|████████▉ | 552/619 [12:49<01:32,  1.39s/it, training_loss=0.050]
# Epoch 3:  89%|████████▉ | 553/619 [12:49<01:31,  1.39s/it, training_loss=0.050]
# Epoch 3:  89%|████████▉ | 553/619 [12:50<01:31,  1.39s/it, training_loss=0.009]
# Epoch 3:  89%|████████▉ | 554/619 [12:50<01:30,  1.39s/it, training_loss=0.009]
# Epoch 3:  89%|████████▉ | 554/619 [12:52<01:30,  1.39s/it, training_loss=0.137]
# Epoch 3:  90%|████████▉ | 555/619 [12:52<01:28,  1.39s/it, training_loss=0.137]
# Epoch 3:  90%|████████▉ | 555/619 [12:53<01:28,  1.39s/it, training_loss=0.013]
# Epoch 3:  90%|████████▉ | 556/619 [12:53<01:27,  1.39s/it, training_loss=0.013]
# Epoch 3:  90%|████████▉ | 556/619 [12:55<01:27,  1.39s/it, training_loss=0.095]
# Epoch 3:  90%|████████▉ | 557/619 [12:55<01:26,  1.39s/it, training_loss=0.095]
# Epoch 3:  90%|████████▉ | 557/619 [12:56<01:26,  1.39s/it, training_loss=0.225]
# Epoch 3:  90%|█████████ | 558/619 [12:56<01:24,  1.39s/it, training_loss=0.225]
# Epoch 3:  90%|█████████ | 558/619 [12:57<01:24,  1.39s/it, training_loss=0.029]
# Epoch 3:  90%|█████████ | 559/619 [12:57<01:23,  1.39s/it, training_loss=0.029]
# Epoch 3:  90%|█████████ | 559/619 [12:59<01:23,  1.39s/it, training_loss=0.009]
# Epoch 3:  90%|█████████ | 560/619 [12:59<01:22,  1.39s/it, training_loss=0.009]
# Epoch 3:  90%|█████████ | 560/619 [13:00<01:22,  1.39s/it, training_loss=0.071]
# Epoch 3:  91%|█████████ | 561/619 [13:00<01:20,  1.39s/it, training_loss=0.071]
# Epoch 3:  91%|█████████ | 561/619 [13:02<01:20,  1.39s/it, training_loss=0.061]
# Epoch 3:  91%|█████████ | 562/619 [13:02<01:19,  1.39s/it, training_loss=0.061]
# Epoch 3:  91%|█████████ | 562/619 [13:03<01:19,  1.39s/it, training_loss=0.070]
# Epoch 3:  91%|█████████ | 563/619 [13:03<01:18,  1.39s/it, training_loss=0.070]
# Epoch 3:  91%|█████████ | 563/619 [13:04<01:18,  1.39s/it, training_loss=0.053]
# Epoch 3:  91%|█████████ | 564/619 [13:04<01:16,  1.39s/it, training_loss=0.053]
# Epoch 3:  91%|█████████ | 564/619 [13:06<01:16,  1.39s/it, training_loss=0.072]
# Epoch 3:  91%|█████████▏| 565/619 [13:06<01:15,  1.40s/it, training_loss=0.072]
# Epoch 3:  91%|█████████▏| 565/619 [13:07<01:15,  1.40s/it, training_loss=0.068]
# Epoch 3:  91%|█████████▏| 566/619 [13:07<01:13,  1.40s/it, training_loss=0.068]
# Epoch 3:  91%|█████████▏| 566/619 [13:09<01:13,  1.40s/it, training_loss=0.015]
# Epoch 3:  92%|█████████▏| 567/619 [13:09<01:12,  1.40s/it, training_loss=0.015]
# Epoch 3:  92%|█████████▏| 567/619 [13:10<01:12,  1.40s/it, training_loss=0.049]
# Epoch 3:  92%|█████████▏| 568/619 [13:10<01:11,  1.39s/it, training_loss=0.049]
# Epoch 3:  92%|█████████▏| 568/619 [13:11<01:11,  1.39s/it, training_loss=0.049]
# Epoch 3:  92%|█████████▏| 569/619 [13:11<01:09,  1.39s/it, training_loss=0.049]
# Epoch 3:  92%|█████████▏| 569/619 [13:13<01:09,  1.39s/it, training_loss=0.117]
# Epoch 3:  92%|█████████▏| 570/619 [13:13<01:08,  1.40s/it, training_loss=0.117]
# Epoch 3:  92%|█████████▏| 570/619 [13:14<01:08,  1.40s/it, training_loss=0.049]
# Epoch 3:  92%|█████████▏| 571/619 [13:14<01:07,  1.40s/it, training_loss=0.049]
# Epoch 3:  92%|█████████▏| 571/619 [13:16<01:07,  1.40s/it, training_loss=0.111]
# Epoch 3:  92%|█████████▏| 572/619 [13:16<01:05,  1.39s/it, training_loss=0.111]
# Epoch 3:  92%|█████████▏| 572/619 [13:17<01:05,  1.39s/it, training_loss=0.044]
# Epoch 3:  93%|█████████▎| 573/619 [13:17<01:04,  1.39s/it, training_loss=0.044]
# Epoch 3:  93%|█████████▎| 573/619 [13:18<01:04,  1.39s/it, training_loss=0.119]
# Epoch 3:  93%|█████████▎| 574/619 [13:18<01:02,  1.40s/it, training_loss=0.119]
# Epoch 3:  93%|█████████▎| 574/619 [13:20<01:02,  1.40s/it, training_loss=0.069]
# Epoch 3:  93%|█████████▎| 575/619 [13:20<01:01,  1.40s/it, training_loss=0.069]
# Epoch 3:  93%|█████████▎| 575/619 [13:21<01:01,  1.40s/it, training_loss=0.093]
# Epoch 3:  93%|█████████▎| 576/619 [13:21<01:00,  1.40s/it, training_loss=0.093]
# Epoch 3:  93%|█████████▎| 576/619 [13:23<01:00,  1.40s/it, training_loss=0.104]
# Epoch 3:  93%|█████████▎| 577/619 [13:23<00:58,  1.39s/it, training_loss=0.104]
# Epoch 3:  93%|█████████▎| 577/619 [13:24<00:58,  1.39s/it, training_loss=0.033]
# Epoch 3:  93%|█████████▎| 578/619 [13:24<00:57,  1.39s/it, training_loss=0.033]
# Epoch 3:  93%|█████████▎| 578/619 [13:25<00:57,  1.39s/it, training_loss=0.032]
# Epoch 3:  94%|█████████▎| 579/619 [13:25<00:55,  1.39s/it, training_loss=0.032]
# Epoch 3:  94%|█████████▎| 579/619 [13:27<00:55,  1.39s/it, training_loss=0.101]
# Epoch 3:  94%|█████████▎| 580/619 [13:27<00:54,  1.39s/it, training_loss=0.101]
# Epoch 3:  94%|█████████▎| 580/619 [13:28<00:54,  1.39s/it, training_loss=0.079]
# Epoch 3:  94%|█████████▍| 581/619 [13:28<00:52,  1.39s/it, training_loss=0.079]
# Epoch 3:  94%|█████████▍| 581/619 [13:29<00:52,  1.39s/it, training_loss=0.030]
# Epoch 3:  94%|█████████▍| 582/619 [13:30<00:51,  1.40s/it, training_loss=0.030]
# Epoch 3:  94%|█████████▍| 582/619 [13:31<00:51,  1.40s/it, training_loss=0.093]
# Epoch 3:  94%|█████████▍| 583/619 [13:31<00:50,  1.40s/it, training_loss=0.093]
# Epoch 3:  94%|█████████▍| 583/619 [13:32<00:50,  1.40s/it, training_loss=0.114]
# Epoch 3:  94%|█████████▍| 584/619 [13:32<00:48,  1.40s/it, training_loss=0.114]
# Epoch 3:  94%|█████████▍| 584/619 [13:34<00:48,  1.40s/it, training_loss=0.040]
# Epoch 3:  95%|█████████▍| 585/619 [13:34<00:47,  1.40s/it, training_loss=0.040]
# Epoch 3:  95%|█████████▍| 585/619 [13:35<00:47,  1.40s/it, training_loss=0.069]
# Epoch 3:  95%|█████████▍| 586/619 [13:35<00:46,  1.40s/it, training_loss=0.069]
# Epoch 3:  95%|█████████▍| 586/619 [13:36<00:46,  1.40s/it, training_loss=0.036]
# Epoch 3:  95%|█████████▍| 587/619 [13:36<00:44,  1.39s/it, training_loss=0.036]
# Epoch 3:  95%|█████████▍| 587/619 [13:38<00:44,  1.39s/it, training_loss=0.040]
# Epoch 3:  95%|█████████▍| 588/619 [13:38<00:43,  1.39s/it, training_loss=0.040]
# Epoch 3:  95%|█████████▍| 588/619 [13:39<00:43,  1.39s/it, training_loss=0.078]
# Epoch 3:  95%|█████████▌| 589/619 [13:39<00:41,  1.39s/it, training_loss=0.078]
# Epoch 3:  95%|█████████▌| 589/619 [13:41<00:41,  1.39s/it, training_loss=0.056]
# Epoch 3:  95%|█████████▌| 590/619 [13:41<00:40,  1.40s/it, training_loss=0.056]
# Epoch 3:  95%|█████████▌| 590/619 [13:42<00:40,  1.40s/it, training_loss=0.093]
# Epoch 3:  95%|█████████▌| 591/619 [13:42<00:39,  1.40s/it, training_loss=0.093]
# Epoch 3:  95%|█████████▌| 591/619 [13:43<00:39,  1.40s/it, training_loss=0.006]
# Epoch 3:  96%|█████████▌| 592/619 [13:43<00:37,  1.40s/it, training_loss=0.006]
# Epoch 3:  96%|█████████▌| 592/619 [13:45<00:37,  1.40s/it, training_loss=0.054]
# Epoch 3:  96%|█████████▌| 593/619 [13:45<00:36,  1.40s/it, training_loss=0.054]
# Epoch 3:  96%|█████████▌| 593/619 [13:46<00:36,  1.40s/it, training_loss=0.114]
# Epoch 3:  96%|█████████▌| 594/619 [13:46<00:34,  1.39s/it, training_loss=0.114]
# Epoch 3:  96%|█████████▌| 594/619 [13:48<00:34,  1.39s/it, training_loss=0.010]
# Epoch 3:  96%|█████████▌| 595/619 [13:48<00:33,  1.39s/it, training_loss=0.010]
# Epoch 3:  96%|█████████▌| 595/619 [13:49<00:33,  1.39s/it, training_loss=0.087]
# Epoch 3:  96%|█████████▋| 596/619 [13:49<00:32,  1.40s/it, training_loss=0.087]
# Epoch 3:  96%|█████████▋| 596/619 [13:50<00:32,  1.40s/it, training_loss=0.131]
# Epoch 3:  96%|█████████▋| 597/619 [13:50<00:30,  1.40s/it, training_loss=0.131]
# Epoch 3:  96%|█████████▋| 597/619 [13:52<00:30,  1.40s/it, training_loss=0.068]
# Epoch 3:  97%|█████████▋| 598/619 [13:52<00:29,  1.40s/it, training_loss=0.068]
# Epoch 3:  97%|█████████▋| 598/619 [13:53<00:29,  1.40s/it, training_loss=0.139]
# Epoch 3:  97%|█████████▋| 599/619 [13:53<00:27,  1.40s/it, training_loss=0.139]
# Epoch 3:  97%|█████████▋| 599/619 [13:55<00:27,  1.40s/it, training_loss=0.012]
# Epoch 3:  97%|█████████▋| 600/619 [13:55<00:26,  1.39s/it, training_loss=0.012]
# Epoch 3:  97%|█████████▋| 600/619 [13:56<00:26,  1.39s/it, training_loss=0.050]
# Epoch 3:  97%|█████████▋| 601/619 [13:56<00:25,  1.39s/it, training_loss=0.050]
# Epoch 3:  97%|█████████▋| 601/619 [13:57<00:25,  1.39s/it, training_loss=0.054]
# Epoch 3:  97%|█████████▋| 602/619 [13:57<00:23,  1.40s/it, training_loss=0.054]
# Epoch 3:  97%|█████████▋| 602/619 [13:59<00:23,  1.40s/it, training_loss=0.068]
# Epoch 3:  97%|█████████▋| 603/619 [13:59<00:22,  1.39s/it, training_loss=0.068]
# Epoch 3:  97%|█████████▋| 603/619 [14:00<00:22,  1.39s/it, training_loss=0.012]
# Epoch 3:  98%|█████████▊| 604/619 [14:00<00:20,  1.39s/it, training_loss=0.012]
# Epoch 3:  98%|█████████▊| 604/619 [14:02<00:20,  1.39s/it, training_loss=0.068]
# Epoch 3:  98%|█████████▊| 605/619 [14:02<00:19,  1.40s/it, training_loss=0.068]
# Epoch 3:  98%|█████████▊| 605/619 [14:03<00:19,  1.40s/it, training_loss=0.028]
# Epoch 3:  98%|█████████▊| 606/619 [14:03<00:18,  1.40s/it, training_loss=0.028]
# Epoch 3:  98%|█████████▊| 606/619 [14:04<00:18,  1.40s/it, training_loss=0.071]
# Epoch 3:  98%|█████████▊| 607/619 [14:04<00:16,  1.40s/it, training_loss=0.071]
# Epoch 3:  98%|█████████▊| 607/619 [14:06<00:16,  1.40s/it, training_loss=0.058]
# Epoch 3:  98%|█████████▊| 608/619 [14:06<00:15,  1.39s/it, training_loss=0.058]
# Epoch 3:  98%|█████████▊| 608/619 [14:07<00:15,  1.39s/it, training_loss=0.030]
# Epoch 3:  98%|█████████▊| 609/619 [14:07<00:13,  1.40s/it, training_loss=0.030]
# Epoch 3:  98%|█████████▊| 609/619 [14:09<00:13,  1.40s/it, training_loss=0.119]
# Epoch 3:  99%|█████████▊| 610/619 [14:09<00:12,  1.39s/it, training_loss=0.119]
# Epoch 3:  99%|█████████▊| 610/619 [14:10<00:12,  1.39s/it, training_loss=0.041]
# Epoch 3:  99%|█████████▊| 611/619 [14:10<00:11,  1.39s/it, training_loss=0.041]
# Epoch 3:  99%|█████████▊| 611/619 [14:11<00:11,  1.39s/it, training_loss=0.071]
# Epoch 3:  99%|█████████▉| 612/619 [14:11<00:09,  1.39s/it, training_loss=0.071]
# Epoch 3:  99%|█████████▉| 612/619 [14:13<00:09,  1.39s/it, training_loss=0.031]
# Epoch 3:  99%|█████████▉| 613/619 [14:13<00:08,  1.40s/it, training_loss=0.031]
# Epoch 3:  99%|█████████▉| 613/619 [14:14<00:08,  1.40s/it, training_loss=0.118]
# Epoch 3:  99%|█████████▉| 614/619 [14:14<00:06,  1.40s/it, training_loss=0.118]
# Epoch 3:  99%|█████████▉| 614/619 [14:16<00:06,  1.40s/it, training_loss=0.149]
# Epoch 3:  99%|█████████▉| 615/619 [14:16<00:05,  1.39s/it, training_loss=0.149]
# Epoch 3:  99%|█████████▉| 615/619 [14:17<00:05,  1.39s/it, training_loss=0.081]
# Epoch 3: 100%|█████████▉| 616/619 [14:17<00:04,  1.40s/it, training_loss=0.081]
# Epoch 3: 100%|█████████▉| 616/619 [14:18<00:04,  1.40s/it, training_loss=0.102]
# Epoch 3: 100%|█████████▉| 617/619 [14:18<00:02,  1.39s/it, training_loss=0.102]
# Epoch 3: 100%|█████████▉| 617/619 [14:20<00:02,  1.39s/it, training_loss=0.025]
# Epoch 3: 100%|█████████▉| 618/619 [14:20<00:01,  1.39s/it, training_loss=0.025]
# Epoch 3: 100%|█████████▉| 618/619 [14:21<00:01,  1.39s/it, training_loss=0.009]
# Epoch 3: 100%|██████████| 619/619 [14:21<00:00,  1.23s/it, training_loss=0.009]
#  67%|██████▋   | 2/3 [46:37<16:06, 966.76s/it]
# Epoch 3
# Training loss: 0.1955140264846252
# 100%|██████████| 3/3 [48:22<00:00, 967.49s/it]
# Validation loss: 0.4384958445665917
# F1 Score (Weighted): 0.8694837818841014

# %%
accuracy_per_class(predictions, true_vals)
# Out:
# Class: Yes
# Accuracy: 2992/3326
#
# Class: No
# Accuracy: 2256/2566
#
# Class: In the middle, neither yes nor no
# Accuracy: 52/190
#
# Class: Yes, subject to some conditions
# Accuracy: 461/517

# %%
flat_accuracy(predictions, true_vals)
# Out:
# 0.873011062282164
