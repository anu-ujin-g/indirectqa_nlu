# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install transformers==2.5.1
# Out:
# Collecting transformers==2.5.1
#   Downloading https://files.pythonhosted.org/packages/13/33/ffb67897a6985a7b7d8e5e7878c3628678f553634bd3836404fef06ef19b/transformers-2.5.1-py3-none-any.whl (499kB)
#      |████████████████████████████████| 501kB 11.1MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers==2.5.1) (2.23.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers==2.5.1) (4.41.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers==2.5.1) (3.0.12)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from transformers==2.5.1) (1.19.5)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers==2.5.1) (2019.12.20)
# Collecting tokenizers==0.5.2
#   Downloading https://files.pythonhosted.org/packages/d6/e3/5e49e9a83fb605aaa34a1c1173e607302fecae529428c28696fb18f1c2c9/tokenizers-0.5.2-cp37-cp37m-manylinux1_x86_64.whl (5.6MB)
#      |████████████████████████████████| 5.6MB 26.1MB/s
# Collecting sacremoses
#   Downloading https://files.pythonhosted.org/packages/75/ee/67241dc87f266093c533a2d4d3d69438e57d7a90abb216fa076e7d475d4a/sacremoses-0.0.45-py3-none-any.whl (895kB)
#      |████████████████████████████████| 901kB 47.5MB/s
# Collecting sentencepiece
#   Downloading https://files.pythonhosted.org/packages/f5/99/e0808cb947ba10f575839c43e8fafc9cc44e4a7a2c8f79c60db48220a577/sentencepiece-0.1.95-cp37-cp37m-manylinux2014_x86_64.whl (1.2MB)
#      |████████████████████████████████| 1.2MB 48.5MB/s
# Collecting boto3
#   Downloading https://files.pythonhosted.org/packages/57/a5/892ed5d2959b1fdf4f8aaccf96b299e57dd7f06db7072592901fbaa36d79/boto3-1.17.54-py2.py3-none-any.whl (131kB)
#      |████████████████████████████████| 133kB 60.0MB/s
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==2.5.1) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==2.5.1) (2020.12.5)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==2.5.1) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==2.5.1) (2.10)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==2.5.1) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==2.5.1) (1.0.1)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==2.5.1) (1.15.0)
# Collecting s3transfer<0.5.0,>=0.4.0
#   Downloading https://files.pythonhosted.org/packages/3e/50/ac379fa31377f5d316cad8967db9f73c50cd61b80153269bfd7d8b964fc8/s3transfer-0.4.0-py2.py3-none-any.whl (79kB)
#      |████████████████████████████████| 81kB 10.2MB/s
# Collecting botocore<1.21.0,>=1.20.54
#   Downloading https://files.pythonhosted.org/packages/3c/e1/59cc39d22d44e64e96186db87d6e670e2119822d16299e18d0500198abb4/botocore-1.20.54-py2.py3-none-any.whl (7.4MB)
#      |████████████████████████████████| 7.4MB 33.6MB/s
# Collecting jmespath<1.0.0,>=0.7.1
#   Downloading https://files.pythonhosted.org/packages/07/cb/5f001272b6faeb23c1c9e0acc04d48eaaf5c862c17709d20e3469c6e0139/jmespath-0.10.0-py2.py3-none-any.whl
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.7/dist-packages (from botocore<1.21.0,>=1.20.54->boto3->transformers==2.5.1) (2.8.1)
# ERROR: botocore 1.20.54 has requirement urllib3<1.27,>=1.25.4, but you'll have urllib3 1.24.3 which is incompatible.
# Installing collected packages: tokenizers, sacremoses, sentencepiece, jmespath, botocore, s3transfer, boto3, transformers
# Successfully installed boto3-1.17.54 botocore-1.20.54 jmespath-0.10.0 s3transfer-0.4.0 sacremoses-0.0.45 sentencepiece-0.1.95 tokenizers-0.5.2 transformers-2.5.1

# %%
import torch
import torch.nn as nn 
from torch.utils.data import DataLoader, RandomSampler, SequentialSampler, TensorDataset
from transformers import AutoTokenizer, AutoModelForSequenceClassification, AdamW, get_linear_schedule_with_warmup
# from transformers import AutoTokenizer, BertTokenizer, EvalPrediction, BertPreTrainedModel, BertConfig, BertModel, BertForSequenceClassification, AdamW, get_linear_schedule_with_warmup

import random
import pandas as pd
import numpy as np
from tqdm import tqdm

from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score

# %%
    import torch
    torch.cuda.empty_cache()

# %%
cd '/content/drive/MyDrive/'
# Out:
# /content/drive/MyDrive

# %% [markdown]
# ## Data pre-processing

# %% [markdown]
# Relaxed-matched

# %%
# circa_og = pd.read_csv('NLU_Project/circa-data.tsv', sep='\t', index_col='id')
circa_og = pd.read_csv('/content/drive/MyDrive/AMBER_TENG_NYU_DRIVE_TO_BROWN/NYU_SPRING2021/NLU/NLU_Project/circa-data.tsv', sep='\t', index_col='id')
circa_r = circa_og.drop(circa_og.loc[circa_og['goldstandard2']=='Other'].index)
circa_r = circa_r.drop(circa_r.loc[circa_r['goldstandard2'].isnull()].index)

# %%
YN_r = (circa_r['question-X'].map(str)+' '+circa_r['answer-Y']).apply(lambda row: row.strip())
relaxed_labels = circa_r['goldstandard2'].unique()
relaxed_label = circa_r['goldstandard2']
relaxed_dict = {}
for idx, label in enumerate(relaxed_labels):
    relaxed_dict[label] = idx
circa_r['relaxed'] = circa_r.goldstandard2.replace(relaxed_dict)
relaxed = circa_r['relaxed']

# %% [markdown]
# ## Modeling

# %%
import tensorflow as tf

# Get the GPU device name.
device_name = tf.test.gpu_device_name()
print(device_name)

if torch.cuda.is_available():    

    # Tell PyTorch to use the GPU.    
    device = torch.device("cuda")
# Out:
# /device:GPU:0

# %% [markdown]
# ### Relaxed

# %%
from transformers import PreTrainedModel
from transformers import BertConfig, BertModel
from transformers.modeling_tf_bert import TFBertForSequenceClassification
from transformers import BertForSequenceClassification

# %% [markdown]
# ## Model Specs
# - BERT-MNLI-YN Relaxed learning rate: 5e-5
# - MNLI learning rate: 2e-5 ; 3 epochs; batch size 16 vs 32
#   - https://huggingface.co/ishan/bert-base-uncased-mnli
#   - The training parameters were kept the same as Devlin et al., 2019 (learning rate = 2e-5, training epochs = 3, max_sequence_len = 128 and batch_size = 32).
# - BERT-MNLI-YN Strict learning rate: 2e-5

# %%
# tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased") 
tokenizer = AutoTokenizer.from_pretrained('ishan/bert-base-uncased-mnli') 
model = BertForSequenceClassification.from_pretrained(
    "bert-base-uncased", # Use the 12-layer BERT model, with an uncased vocab.
    num_labels = 3, # The number of output labels--2 for binary classification.
                    # You can increase this for multi-class tasks.   
    output_attentions = False, # Whether the model returns attentions weights.
    output_hidden_states = False, # Whether the model returns all hidden-states.
)
# device = torch.device("cpu")
# Tell pytorch to run this model on the GPU.
# model.cuda()
model.to(device)

learning_rate = 5e-5
optimizer = AdamW(model.parameters(), lr=learning_rate, eps=1e-8)
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=665.0, style=ProgressStyle(description_…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=231508.0, style=ProgressStyle(descripti…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=112.0, style=ProgressStyle(description_…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=48.0, style=ProgressStyle(description_w…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=433.0, style=ProgressStyle(description_…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=440473133.0, style=ProgressStyle(descri…

# %%
torch.cuda.memory_summary(device=None, abbreviated=False)
# Out:
# '|===========================================================================|\n|                  PyTorch CUDA memory summary, device ID 0                 |\n|---------------------------------------------------------------------------|\n|            CUDA OOMs: 0            |        cudaMalloc retries: 0         |\n|===========================================================================|\n|        Metric         | Cur Usage  | Peak Usage | Tot Alloc  | Tot Freed  |\n|---------------------------------------------------------------------------|\n| Allocated memory      |  428780 KB |  428780 KB |  428780 KB |       0 B  |\n|       from large pool |  428288 KB |  428288 KB |  428288 KB |       0 B  |\n|       from small pool |     492 KB |     492 KB |     492 KB |       0 B  |\n|---------------------------------------------------------------------------|\n| Active memory         |  428780 KB |  428780 KB |  428780 KB |       0 B  |\n|       from large pool |  428288 KB |  428288 KB |  428288 KB |       0 B  |\n|       from small pool |     492 KB |     492 KB |     492 KB |       0 B  |\n|---------------------------------------------------------------------------|\n| GPU reserved memory   |  483328 KB |  483328 KB |  483328 KB |       0 B  |\n|       from large pool |  481280 KB |  481280 KB |  481280 KB |       0 B  |\n|       from small pool |    2048 KB |    2048 KB |    2048 KB |       0 B  |\n|---------------------------------------------------------------------------|\n| Non-releasable memory |   54547 KB |   54560 KB |  265210 KB |  210662 KB |\n|       from large pool |   52992 KB |   52992 KB |  263168 KB |  210176 KB |\n|       from small pool |    1555 KB |    2042 KB |    2042 KB |     486 KB |\n|---------------------------------------------------------------------------|\n| Allocations           |     201    |     201    |     201    |       0    |\n|       from large pool |      75    |      75    |      75    |       0    |\n|       from small pool |     126    |     126    |     126    |       0    |\n|---------------------------------------------------------------------------|\n| Active allocs         |     201    |     201    |     201    |       0    |\n|       from large pool |      75    |      75    |      75    |       0    |\n|       from small pool |     126    |     126    |     126    |       0    |\n|---------------------------------------------------------------------------|\n| GPU reserved segments |      21    |      21    |      21    |       0    |\n|       from large pool |      20    |      20    |      20    |       0    |\n|       from small pool |       1    |       1    |       1    |       0    |\n|---------------------------------------------------------------------------|\n| Non-releasable allocs |      19    |      19    |      20    |       1    |\n|       from large pool |      18    |      18    |      19    |       1    |\n|       from small pool |       1    |       1    |       1    |       0    |\n|===========================================================================|\n'

# %%
max_len = 0
for entry in YN_r.values:
    input_ids = tokenizer.encode(entry,  add_special_tokens=True)
    max_len = max(max_len, len(input_ids))
print(max_len)
# Out:
# 43

# %%
df = pd.concat([YN_r, relaxed_label, relaxed], axis=1).rename(columns={0:'YN_r'})
df
# Out:
#                                                     YN_r  ... relaxed
# id                                                        ...
# 0         Are you employed? I'm a veterinary technician.  ...       0
# 1        Are you a fan of Korean food? I wouldn't say so  ...       1
# 2      Are you bringing any pets into the flat? I do ...  ...       1
# 3      Would you like to get some fresh air in your f...  ...       0
# 4      Is your family still living in the neighborhoo...  ...       2
# ...                                                  ...  ...     ...
# 34263                  Do you like to drink? I am in AA.  ...       1
# 34264         Do you like pie? My favorite pie is pecan.  ...       0
# 34265  Want to go to a concert with me? I'd rather do...  ...       1
# 34266  Do you like hip/hop music? I can't dance to hi...  ...       1
# 34267  Do you see yourself raising a family in New Yo...  ...       1
#
# [32993 rows x 3 columns]

# %%
train_relaxed, val_relaxed, trainy_relaxed, valy_relaxed = train_test_split(df.index.values, df.relaxed.values, test_size=.4, stratify=df.relaxed.values)
test_relaxed, dev_relaxed, testy_relaxed, devy_relaxed = train_test_split(val_relaxed, valy_relaxed, test_size=.5, stratify=valy_relaxed)

# %%
df['data_type'] = ['not_set']*df.shape[0]
df.loc[train_relaxed,'data_type'] = 'train'
df.loc[dev_relaxed,'data_type'] = 'dev'
df.loc[test_relaxed,'data_type'] = 'test'

# %%
df.groupby(['goldstandard2','relaxed','data_type']).count()
# Out:
#                                                      YN_r
# goldstandard2                     relaxed data_type
# In the middle, neither yes nor no 2       dev         190
#                                           test        190
#                                           train       569
# No                                1       dev        2566
#                                           test       2567
#                                           train      7700
# Yes                               0       dev        3326
#                                           test       3326
#                                           train      9976
# Yes, subject to some conditions   3       dev         517
#                                           test        516
#                                           train      1550

# %%
encoded_data_train = tokenizer.batch_encode_plus(
    df[df.data_type=='train'].YN_r.values, 
    add_special_tokens=True, 
    return_attention_mask=True, 
    pad_to_max_length=True, 
    max_length=256, 
    return_tensors='pt'
)

encoded_data_dev = tokenizer.batch_encode_plus(
    df[df.data_type=='dev'].YN_r.values, 
    add_special_tokens=True, 
    return_attention_mask=True, 
    pad_to_max_length=True, 
    max_length=256, 
    return_tensors='pt'
)


input_ids_train = encoded_data_train['input_ids']
attention_masks_train = encoded_data_train['attention_mask']
labels_train = torch.tensor(df[df.data_type=='train'].relaxed.values)

input_ids_dev = encoded_data_dev['input_ids']
attention_masks_dev = encoded_data_dev['attention_mask']
labels_dev = torch.tensor(df[df.data_type=='dev'].relaxed.values)

# %%
dataset_train = TensorDataset(input_ids_train, attention_masks_train, labels_train)
dataset_dev = TensorDataset(input_ids_dev, attention_masks_dev, labels_dev)

# %%
len(dataset_train)
# Out:
# 19795

# %%
# model
# relaxed_dict
len(relaxed_dict)
# Out:
# 4

# %%
model.classifier
# Out:
# Linear(in_features=768, out_features=3, bias=True)

# %%
# model

# %%
# model = BertForSequenceClassification.from_pretrained("bert-base-uncased",
#                                                       num_labels=len(relaxed_dict),
#                                                       output_attentions=False,
#                                                       output_hidden_states=False)

# model = BertForSequenceClassification.from_pretrained('ishan/bert-base-uncased-mnli',
#                                                       num_labels=4,
#                                                       # num_labels=len(relaxed_dict),
#                                                       output_attentions=False,
#                                                       output_hidden_states=False)
model.classifier = torch.nn.Linear(model.classifier.in_features, 4)
model.num_labels = 4
optimizer = AdamW(model.parameters(), lr=learning_rate, eps=1e-8)
model.to(device)
# Out:
# BertForSequenceClassification(
#   (bert): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(30522, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (1): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (2): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (3): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (4): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (5): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (6): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (7): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (8): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (9): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (10): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (11): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (dropout): Dropout(p=0.1, inplace=False)
#   (classifier): Linear(in_features=768, out_features=4, bias=True)
# )

# %%
batch_size = 32
# batch_size = 16

dataloader_train = DataLoader(dataset_train, 
                              sampler=RandomSampler(dataset_train), 
                              batch_size=batch_size)

dataloader_validation = DataLoader(dataset_dev, 
                                   sampler=SequentialSampler(dataset_dev), 
                                   batch_size=batch_size)

optimizer = AdamW(model.parameters(),
                  lr = learning_rate,
                  eps = 1e-8)

# %%
epochs = 3
# epochs = 2
total_steps = len(dataloader_train) * epochs
scheduler = get_linear_schedule_with_warmup(optimizer, 
                                            num_warmup_steps = 0, 
                                            num_training_steps = total_steps)

# %%
def f1_score_func(preds, labels):
    preds_flat = np.argmax(preds, axis=1).flatten()
    labels_flat = labels.flatten()
    return f1_score(labels_flat, preds_flat, average='weighted')

def accuracy_per_class(preds, labels):
    label_dict_inverse = {v: k for k, v in relaxed_dict.items()}
    
    preds_flat = np.argmax(preds, axis=1).flatten()
    labels_flat = labels.flatten()

    for label in np.unique(labels_flat):
        y_preds = preds_flat[labels_flat==label]
        y_true = labels_flat[labels_flat==label]
        print(f'Class: {label_dict_inverse[label]}')
        print(f'Accuracy: {len(y_preds[y_preds==label])}/{len(y_true)} = {len(y_preds[y_preds==label])/len(y_true)}\n')

def flat_accuracy(preds, labels):
    pred_flat = np.argmax(preds, axis=1).flatten()
    labels_flat = labels.flatten()
    return np.sum(pred_flat == labels_flat) / len(labels_flat)

# %%
seed_val = 42

random.seed(seed_val)
np.random.seed(seed_val)
torch.manual_seed(seed_val)
torch.cuda.manual_seed_all(seed_val)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# device = torch.device('cpu')
model.to(device)

print(device)
# Out:
# cuda

# %%
def evaluate(dataloader_val):

    model.eval()
    
    loss_val_total = 0
    predictions, true_vals = [], []
    
    for batch in dataloader_val:
        
        batch = tuple(b.to(device) for b in batch)
        
        inputs = {'input_ids':      batch[0],
                  'attention_mask': batch[1],
                  'labels':         batch[2],
                 }

        with torch.no_grad():        
            outputs = model(**inputs)
            
        loss = outputs[0]
        logits = outputs[1]
        loss_val_total += loss.item()

        logits = logits.detach().cpu().numpy()
        label_ids = inputs['labels'].cpu().numpy()
        predictions.append(logits)
        true_vals.append(label_ids)
    
    loss_val_avg = loss_val_total/len(dataloader_val) 
    
    predictions = np.concatenate(predictions, axis=0)
    true_vals = np.concatenate(true_vals, axis=0)
            
    return loss_val_avg, predictions, true_vals

# %%
for epoch in tqdm(range(1, epochs+1)):
    
    model.train()
    
    loss_train_total = 0

    progress_bar = tqdm(dataloader_train, desc='Epoch {:1d}'.format(epoch), leave=False, disable=False)
    for batch in progress_bar:

        model.zero_grad()
        
        batch = tuple(b.to(device) for b in batch)
        
        inputs = {'input_ids':      batch[0],
                  'attention_mask': batch[1],
                  'labels':         batch[2],
                 }       

        outputs = model(**inputs)
        
        loss = outputs[0]
        loss_train_total += loss.item()
        loss.backward()

        torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)

        optimizer.step()
        # scheduler.step()
        
        progress_bar.set_postfix({'training_loss': '{:.3f}'.format(loss.item()/len(batch))})
         
        
    torch.save(model.state_dict(), f'finetuned_BERT_relaxed_epoch_{epoch}.model')
        
    tqdm.write(f'\nEpoch {epoch}')
    
    loss_train_avg = loss_train_total/len(dataloader_train)            
    tqdm.write(f'Training loss: {loss_train_avg}')
    
    dev_loss, predictions, true_vals = evaluate(dataloader_validation)
    dev_f1 = f1_score_func(predictions, true_vals)
    tqdm.write(f'Validation loss: {dev_loss}')
    tqdm.write(f'F1 Score (Weighted): {dev_f1}')
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 1:   0%|          | 0/619 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/transformers/optimization.py:155: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# Consider using one of the following signatures instead:
# 	add_(Tensor other, *, Number alpha) (Triggered internally at  /pytorch/torch/csrc/utils/python_arg_parser.cpp:1005.)
#   exp_avg.mul_(beta1).add_(1.0 - beta1, grad)
#
# Epoch 1:   0%|          | 0/619 [00:01<?, ?it/s, training_loss=0.371]
# Epoch 1:   0%|          | 1/619 [00:01<15:08,  1.47s/it, training_loss=0.371]
# Epoch 1:   0%|          | 1/619 [00:02<15:08,  1.47s/it, training_loss=0.367]
# Epoch 1:   0%|          | 2/619 [00:02<14:22,  1.40s/it, training_loss=0.367]
# Epoch 1:   0%|          | 2/619 [00:03<14:22,  1.40s/it, training_loss=0.312]
# Epoch 1:   0%|          | 3/619 [00:03<13:49,  1.35s/it, training_loss=0.312]
# Epoch 1:   0%|          | 3/619 [00:05<13:49,  1.35s/it, training_loss=0.382]
# Epoch 1:   1%|          | 4/619 [00:05<13:25,  1.31s/it, training_loss=0.382]
# Epoch 1:   1%|          | 4/619 [00:06<13:25,  1.31s/it, training_loss=0.424]
# Epoch 1:   1%|          | 5/619 [00:06<13:09,  1.29s/it, training_loss=0.424]
# Epoch 1:   1%|          | 5/619 [00:07<13:09,  1.29s/it, training_loss=0.312]
# Epoch 1:   1%|          | 6/619 [00:07<12:57,  1.27s/it, training_loss=0.312]
# Epoch 1:   1%|          | 6/619 [00:08<12:57,  1.27s/it, training_loss=0.324]
# Epoch 1:   1%|          | 7/619 [00:08<12:49,  1.26s/it, training_loss=0.324]
# Epoch 1:   1%|          | 7/619 [00:10<12:49,  1.26s/it, training_loss=0.305]
# Epoch 1:   1%|▏         | 8/619 [00:10<12:44,  1.25s/it, training_loss=0.305]
# Epoch 1:   1%|▏         | 8/619 [00:11<12:44,  1.25s/it, training_loss=0.385]
# Epoch 1:   1%|▏         | 9/619 [00:11<12:41,  1.25s/it, training_loss=0.385]
# Epoch 1:   1%|▏         | 9/619 [00:12<12:41,  1.25s/it, training_loss=0.346]
# Epoch 1:   2%|▏         | 10/619 [00:12<12:38,  1.25s/it, training_loss=0.346]
# Epoch 1:   2%|▏         | 10/619 [00:13<12:38,  1.25s/it, training_loss=0.332]
# Epoch 1:   2%|▏         | 11/619 [00:13<12:36,  1.24s/it, training_loss=0.332]
# Epoch 1:   2%|▏         | 11/619 [00:15<12:36,  1.24s/it, training_loss=0.350]
# Epoch 1:   2%|▏         | 12/619 [00:15<12:33,  1.24s/it, training_loss=0.350]
# Epoch 1:   2%|▏         | 12/619 [00:16<12:33,  1.24s/it, training_loss=0.263]
# Epoch 1:   2%|▏         | 13/619 [00:16<12:31,  1.24s/it, training_loss=0.263]
# Epoch 1:   2%|▏         | 13/619 [00:17<12:31,  1.24s/it, training_loss=0.331]
# Epoch 1:   2%|▏         | 14/619 [00:17<12:30,  1.24s/it, training_loss=0.331]
# Epoch 1:   2%|▏         | 14/619 [00:18<12:30,  1.24s/it, training_loss=0.365]
# Epoch 1:   2%|▏         | 15/619 [00:18<12:30,  1.24s/it, training_loss=0.365]
# Epoch 1:   2%|▏         | 15/619 [00:19<12:30,  1.24s/it, training_loss=0.331]
# Epoch 1:   3%|▎         | 16/619 [00:20<12:28,  1.24s/it, training_loss=0.331]
# Epoch 1:   3%|▎         | 16/619 [00:21<12:28,  1.24s/it, training_loss=0.355]
# Epoch 1:   3%|▎         | 17/619 [00:21<12:27,  1.24s/it, training_loss=0.355]
# Epoch 1:   3%|▎         | 17/619 [00:22<12:27,  1.24s/it, training_loss=0.201]
# Epoch 1:   3%|▎         | 18/619 [00:22<12:25,  1.24s/it, training_loss=0.201]
# Epoch 1:   3%|▎         | 18/619 [00:23<12:25,  1.24s/it, training_loss=0.330]
# Epoch 1:   3%|▎         | 19/619 [00:23<12:24,  1.24s/it, training_loss=0.330]
# Epoch 1:   3%|▎         | 19/619 [00:24<12:24,  1.24s/it, training_loss=0.330]
# Epoch 1:   3%|▎         | 20/619 [00:24<12:25,  1.25s/it, training_loss=0.330]
# Epoch 1:   3%|▎         | 20/619 [00:26<12:25,  1.25s/it, training_loss=0.317]
# Epoch 1:   3%|▎         | 21/619 [00:26<12:24,  1.25s/it, training_loss=0.317]
# Epoch 1:   3%|▎         | 21/619 [00:27<12:24,  1.25s/it, training_loss=0.346]
# Epoch 1:   4%|▎         | 22/619 [00:27<12:25,  1.25s/it, training_loss=0.346]
# Epoch 1:   4%|▎         | 22/619 [00:28<12:25,  1.25s/it, training_loss=0.290]
# Epoch 1:   4%|▎         | 23/619 [00:28<12:23,  1.25s/it, training_loss=0.290]
# Epoch 1:   4%|▎         | 23/619 [00:29<12:23,  1.25s/it, training_loss=0.233]
# Epoch 1:   4%|▍         | 24/619 [00:29<12:23,  1.25s/it, training_loss=0.233]
# Epoch 1:   4%|▍         | 24/619 [00:31<12:23,  1.25s/it, training_loss=0.391]
# Epoch 1:   4%|▍         | 25/619 [00:31<12:23,  1.25s/it, training_loss=0.391]
# Epoch 1:   4%|▍         | 25/619 [00:32<12:23,  1.25s/it, training_loss=0.273]
# Epoch 1:   4%|▍         | 26/619 [00:32<12:23,  1.25s/it, training_loss=0.273]
# Epoch 1:   4%|▍         | 26/619 [00:33<12:23,  1.25s/it, training_loss=0.250]
# Epoch 1:   4%|▍         | 27/619 [00:33<12:23,  1.26s/it, training_loss=0.250]
# Epoch 1:   4%|▍         | 27/619 [00:35<12:23,  1.26s/it, training_loss=0.368]
# Epoch 1:   5%|▍         | 28/619 [00:35<12:21,  1.26s/it, training_loss=0.368]
# Epoch 1:   5%|▍         | 28/619 [00:36<12:21,  1.26s/it, training_loss=0.240]
# Epoch 1:   5%|▍         | 29/619 [00:36<12:20,  1.25s/it, training_loss=0.240]
# Epoch 1:   5%|▍         | 29/619 [00:37<12:20,  1.25s/it, training_loss=0.271]
# Epoch 1:   5%|▍         | 30/619 [00:37<12:19,  1.26s/it, training_loss=0.271]
# Epoch 1:   5%|▍         | 30/619 [00:38<12:19,  1.26s/it, training_loss=0.261]
# Epoch 1:   5%|▌         | 31/619 [00:38<12:19,  1.26s/it, training_loss=0.261]
# Epoch 1:   5%|▌         | 31/619 [00:40<12:19,  1.26s/it, training_loss=0.208]
# Epoch 1:   5%|▌         | 32/619 [00:40<12:17,  1.26s/it, training_loss=0.208]
# Epoch 1:   5%|▌         | 32/619 [00:41<12:17,  1.26s/it, training_loss=0.193]
# Epoch 1:   5%|▌         | 33/619 [00:41<12:18,  1.26s/it, training_loss=0.193]
# Epoch 1:   5%|▌         | 33/619 [00:42<12:18,  1.26s/it, training_loss=0.216]
# Epoch 1:   5%|▌         | 34/619 [00:42<12:17,  1.26s/it, training_loss=0.216]
# Epoch 1:   5%|▌         | 34/619 [00:43<12:17,  1.26s/it, training_loss=0.278]
# Epoch 1:   6%|▌         | 35/619 [00:43<12:16,  1.26s/it, training_loss=0.278]
# Epoch 1:   6%|▌         | 35/619 [00:45<12:16,  1.26s/it, training_loss=0.310]
# Epoch 1:   6%|▌         | 36/619 [00:45<12:17,  1.26s/it, training_loss=0.310]
# Epoch 1:   6%|▌         | 36/619 [00:46<12:17,  1.26s/it, training_loss=0.279]
# Epoch 1:   6%|▌         | 37/619 [00:46<12:16,  1.26s/it, training_loss=0.279]
# Epoch 1:   6%|▌         | 37/619 [00:47<12:16,  1.26s/it, training_loss=0.231]
# Epoch 1:   6%|▌         | 38/619 [00:47<12:15,  1.27s/it, training_loss=0.231]
# Epoch 1:   6%|▌         | 38/619 [00:48<12:15,  1.27s/it, training_loss=0.151]
# Epoch 1:   6%|▋         | 39/619 [00:48<12:15,  1.27s/it, training_loss=0.151]
# Epoch 1:   6%|▋         | 39/619 [00:50<12:15,  1.27s/it, training_loss=0.229]
# Epoch 1:   6%|▋         | 40/619 [00:50<12:14,  1.27s/it, training_loss=0.229]
# Epoch 1:   6%|▋         | 40/619 [00:51<12:14,  1.27s/it, training_loss=0.160]
# Epoch 1:   7%|▋         | 41/619 [00:51<12:14,  1.27s/it, training_loss=0.160]
# Epoch 1:   7%|▋         | 41/619 [00:52<12:14,  1.27s/it, training_loss=0.155]
# Epoch 1:   7%|▋         | 42/619 [00:52<12:13,  1.27s/it, training_loss=0.155]
# Epoch 1:   7%|▋         | 42/619 [00:54<12:13,  1.27s/it, training_loss=0.263]
# Epoch 1:   7%|▋         | 43/619 [00:54<12:13,  1.27s/it, training_loss=0.263]
# Epoch 1:   7%|▋         | 43/619 [00:55<12:13,  1.27s/it, training_loss=0.122]
# Epoch 1:   7%|▋         | 44/619 [00:55<12:12,  1.27s/it, training_loss=0.122]
# Epoch 1:   7%|▋         | 44/619 [00:56<12:12,  1.27s/it, training_loss=0.140]
# Epoch 1:   7%|▋         | 45/619 [00:56<12:10,  1.27s/it, training_loss=0.140]
# Epoch 1:   7%|▋         | 45/619 [00:57<12:10,  1.27s/it, training_loss=0.235]
# Epoch 1:   7%|▋         | 46/619 [00:57<12:09,  1.27s/it, training_loss=0.235]
# Epoch 1:   7%|▋         | 46/619 [00:59<12:09,  1.27s/it, training_loss=0.303]
# Epoch 1:   8%|▊         | 47/619 [00:59<12:08,  1.27s/it, training_loss=0.303]
# Epoch 1:   8%|▊         | 47/619 [01:00<12:08,  1.27s/it, training_loss=0.259]
# Epoch 1:   8%|▊         | 48/619 [01:00<12:07,  1.27s/it, training_loss=0.259]
# Epoch 1:   8%|▊         | 48/619 [01:01<12:07,  1.27s/it, training_loss=0.142]
# Epoch 1:   8%|▊         | 49/619 [01:01<12:06,  1.27s/it, training_loss=0.142]
# Epoch 1:   8%|▊         | 49/619 [01:02<12:06,  1.27s/it, training_loss=0.225]
# Epoch 1:   8%|▊         | 50/619 [01:02<12:07,  1.28s/it, training_loss=0.225]
# Epoch 1:   8%|▊         | 50/619 [01:04<12:07,  1.28s/it, training_loss=0.241]
# Epoch 1:   8%|▊         | 51/619 [01:04<12:06,  1.28s/it, training_loss=0.241]
# Epoch 1:   8%|▊         | 51/619 [01:05<12:06,  1.28s/it, training_loss=0.280]
# Epoch 1:   8%|▊         | 52/619 [01:05<12:06,  1.28s/it, training_loss=0.280]
# Epoch 1:   8%|▊         | 52/619 [01:06<12:06,  1.28s/it, training_loss=0.212]
# Epoch 1:   9%|▊         | 53/619 [01:06<12:06,  1.28s/it, training_loss=0.212]
# Epoch 1:   9%|▊         | 53/619 [01:08<12:06,  1.28s/it, training_loss=0.211]
# Epoch 1:   9%|▊         | 54/619 [01:08<12:04,  1.28s/it, training_loss=0.211]
# Epoch 1:   9%|▊         | 54/619 [01:09<12:04,  1.28s/it, training_loss=0.294]
# Epoch 1:   9%|▉         | 55/619 [01:09<12:04,  1.28s/it, training_loss=0.294]
# Epoch 1:   9%|▉         | 55/619 [01:10<12:04,  1.28s/it, training_loss=0.230]
# Epoch 1:   9%|▉         | 56/619 [01:10<12:04,  1.29s/it, training_loss=0.230]
# Epoch 1:   9%|▉         | 56/619 [01:11<12:04,  1.29s/it, training_loss=0.194]
# Epoch 1:   9%|▉         | 57/619 [01:11<12:04,  1.29s/it, training_loss=0.194]
# Epoch 1:   9%|▉         | 57/619 [01:13<12:04,  1.29s/it, training_loss=0.148]
# Epoch 1:   9%|▉         | 58/619 [01:13<12:03,  1.29s/it, training_loss=0.148]
# Epoch 1:   9%|▉         | 58/619 [01:14<12:03,  1.29s/it, training_loss=0.105]
# Epoch 1:  10%|▉         | 59/619 [01:14<12:00,  1.29s/it, training_loss=0.105]
# Epoch 1:  10%|▉         | 59/619 [01:15<12:00,  1.29s/it, training_loss=0.221]
# Epoch 1:  10%|▉         | 60/619 [01:15<12:00,  1.29s/it, training_loss=0.221]
# Epoch 1:  10%|▉         | 60/619 [01:17<12:00,  1.29s/it, training_loss=0.240]
# Epoch 1:  10%|▉         | 61/619 [01:17<12:00,  1.29s/it, training_loss=0.240]
# Epoch 1:  10%|▉         | 61/619 [01:18<12:00,  1.29s/it, training_loss=0.151]
# Epoch 1:  10%|█         | 62/619 [01:18<11:59,  1.29s/it, training_loss=0.151]
# Epoch 1:  10%|█         | 62/619 [01:19<11:59,  1.29s/it, training_loss=0.145]
# Epoch 1:  10%|█         | 63/619 [01:19<11:58,  1.29s/it, training_loss=0.145]
# Epoch 1:  10%|█         | 63/619 [01:20<11:58,  1.29s/it, training_loss=0.216]
# Epoch 1:  10%|█         | 64/619 [01:20<11:57,  1.29s/it, training_loss=0.216]
# Epoch 1:  10%|█         | 64/619 [01:22<11:57,  1.29s/it, training_loss=0.298]
# Epoch 1:  11%|█         | 65/619 [01:22<11:57,  1.29s/it, training_loss=0.298]
# Epoch 1:  11%|█         | 65/619 [01:23<11:57,  1.29s/it, training_loss=0.246]
# Epoch 1:  11%|█         | 66/619 [01:23<11:55,  1.29s/it, training_loss=0.246]
# Epoch 1:  11%|█         | 66/619 [01:24<11:55,  1.29s/it, training_loss=0.269]
# Epoch 1:  11%|█         | 67/619 [01:24<11:55,  1.30s/it, training_loss=0.269]
# Epoch 1:  11%|█         | 67/619 [01:26<11:55,  1.30s/it, training_loss=0.252]
# Epoch 1:  11%|█         | 68/619 [01:26<11:53,  1.30s/it, training_loss=0.252]
# Epoch 1:  11%|█         | 68/619 [01:27<11:53,  1.30s/it, training_loss=0.273]
# Epoch 1:  11%|█         | 69/619 [01:27<11:51,  1.29s/it, training_loss=0.273]
# Epoch 1:  11%|█         | 69/619 [01:28<11:51,  1.29s/it, training_loss=0.309]
# Epoch 1:  11%|█▏        | 70/619 [01:28<11:52,  1.30s/it, training_loss=0.309]
# Epoch 1:  11%|█▏        | 70/619 [01:30<11:52,  1.30s/it, training_loss=0.295]
# Epoch 1:  11%|█▏        | 71/619 [01:30<11:55,  1.31s/it, training_loss=0.295]
# Epoch 1:  11%|█▏        | 71/619 [01:31<11:55,  1.31s/it, training_loss=0.154]
# Epoch 1:  12%|█▏        | 72/619 [01:31<11:53,  1.30s/it, training_loss=0.154]
# Epoch 1:  12%|█▏        | 72/619 [01:32<11:53,  1.30s/it, training_loss=0.212]
# Epoch 1:  12%|█▏        | 73/619 [01:32<11:52,  1.30s/it, training_loss=0.212]
# Epoch 1:  12%|█▏        | 73/619 [01:34<11:52,  1.30s/it, training_loss=0.184]
# Epoch 1:  12%|█▏        | 74/619 [01:34<11:51,  1.30s/it, training_loss=0.184]
# Epoch 1:  12%|█▏        | 74/619 [01:35<11:51,  1.30s/it, training_loss=0.224]
# Epoch 1:  12%|█▏        | 75/619 [01:35<11:52,  1.31s/it, training_loss=0.224]
# Epoch 1:  12%|█▏        | 75/619 [01:36<11:52,  1.31s/it, training_loss=0.229]
# Epoch 1:  12%|█▏        | 76/619 [01:36<11:51,  1.31s/it, training_loss=0.229]
# Epoch 1:  12%|█▏        | 76/619 [01:37<11:51,  1.31s/it, training_loss=0.236]
# Epoch 1:  12%|█▏        | 77/619 [01:37<11:49,  1.31s/it, training_loss=0.236]
# Epoch 1:  12%|█▏        | 77/619 [01:39<11:49,  1.31s/it, training_loss=0.194]
# Epoch 1:  13%|█▎        | 78/619 [01:39<11:48,  1.31s/it, training_loss=0.194]
# Epoch 1:  13%|█▎        | 78/619 [01:40<11:48,  1.31s/it, training_loss=0.144]
# Epoch 1:  13%|█▎        | 79/619 [01:40<11:46,  1.31s/it, training_loss=0.144]
# Epoch 1:  13%|█▎        | 79/619 [01:41<11:46,  1.31s/it, training_loss=0.170]
# Epoch 1:  13%|█▎        | 80/619 [01:41<11:45,  1.31s/it, training_loss=0.170]
# Epoch 1:  13%|█▎        | 80/619 [01:43<11:45,  1.31s/it, training_loss=0.185]
# Epoch 1:  13%|█▎        | 81/619 [01:43<11:44,  1.31s/it, training_loss=0.185]
# Epoch 1:  13%|█▎        | 81/619 [01:44<11:44,  1.31s/it, training_loss=0.216]
# Epoch 1:  13%|█▎        | 82/619 [01:44<11:51,  1.32s/it, training_loss=0.216]
# Epoch 1:  13%|█▎        | 82/619 [01:45<11:51,  1.32s/it, training_loss=0.130]
# Epoch 1:  13%|█▎        | 83/619 [01:45<11:47,  1.32s/it, training_loss=0.130]
# Epoch 1:  13%|█▎        | 83/619 [01:47<11:47,  1.32s/it, training_loss=0.176]
# Epoch 1:  14%|█▎        | 84/619 [01:47<11:44,  1.32s/it, training_loss=0.176]
# Epoch 1:  14%|█▎        | 84/619 [01:48<11:44,  1.32s/it, training_loss=0.149]
# Epoch 1:  14%|█▎        | 85/619 [01:48<11:41,  1.31s/it, training_loss=0.149]
# Epoch 1:  14%|█▎        | 85/619 [01:49<11:41,  1.31s/it, training_loss=0.286]
# Epoch 1:  14%|█▍        | 86/619 [01:49<11:39,  1.31s/it, training_loss=0.286]
# Epoch 1:  14%|█▍        | 86/619 [01:51<11:39,  1.31s/it, training_loss=0.182]
# Epoch 1:  14%|█▍        | 87/619 [01:51<11:38,  1.31s/it, training_loss=0.182]
# Epoch 1:  14%|█▍        | 87/619 [01:52<11:38,  1.31s/it, training_loss=0.161]
# Epoch 1:  14%|█▍        | 88/619 [01:52<11:37,  1.31s/it, training_loss=0.161]
# Epoch 1:  14%|█▍        | 88/619 [01:53<11:37,  1.31s/it, training_loss=0.125]
# Epoch 1:  14%|█▍        | 89/619 [01:53<11:34,  1.31s/it, training_loss=0.125]
# Epoch 1:  14%|█▍        | 89/619 [01:55<11:34,  1.31s/it, training_loss=0.201]
# Epoch 1:  15%|█▍        | 90/619 [01:55<11:34,  1.31s/it, training_loss=0.201]
# Epoch 1:  15%|█▍        | 90/619 [01:56<11:34,  1.31s/it, training_loss=0.163]
# Epoch 1:  15%|█▍        | 91/619 [01:56<11:33,  1.31s/it, training_loss=0.163]
# Epoch 1:  15%|█▍        | 91/619 [01:57<11:33,  1.31s/it, training_loss=0.201]
# Epoch 1:  15%|█▍        | 92/619 [01:57<11:33,  1.32s/it, training_loss=0.201]
# Epoch 1:  15%|█▍        | 92/619 [01:58<11:33,  1.32s/it, training_loss=0.156]
# Epoch 1:  48%|████▊     | 298/619 [06:37<07:16,  1.36s/it, training_loss=0.191]
# ...
# Epoch 3:  84%|████████▍ | 521/619 [11:52<02:14,  1.37s/it, training_loss=0.030]
# Epoch 3:  84%|████████▍ | 521/619 [11:54<02:14,  1.37s/it, training_loss=0.033]
# Epoch 3:  84%|████████▍ | 522/619 [11:54<02:12,  1.37s/it, training_loss=0.033]
# Epoch 3:  84%|████████▍ | 522/619 [11:55<02:12,  1.37s/it, training_loss=0.023]
# Epoch 3:  84%|████████▍ | 523/619 [11:55<02:11,  1.37s/it, training_loss=0.023]
# Epoch 3:  84%|████████▍ | 523/619 [11:56<02:11,  1.37s/it, training_loss=0.031]
# Epoch 3:  85%|████████▍ | 524/619 [11:56<02:10,  1.37s/it, training_loss=0.031]
# Epoch 3:  85%|████████▍ | 524/619 [11:58<02:10,  1.37s/it, training_loss=0.012]
# Epoch 3:  85%|████████▍ | 525/619 [11:58<02:08,  1.37s/it, training_loss=0.012]
# Epoch 3:  85%|████████▍ | 525/619 [11:59<02:08,  1.37s/it, training_loss=0.080]
# Epoch 3:  85%|████████▍ | 526/619 [11:59<02:07,  1.37s/it, training_loss=0.080]
# Epoch 3:  85%|████████▍ | 526/619 [12:00<02:07,  1.37s/it, training_loss=0.118]
# Epoch 3:  85%|████████▌ | 527/619 [12:00<02:06,  1.37s/it, training_loss=0.118]
# Epoch 3:  85%|████████▌ | 527/619 [12:02<02:06,  1.37s/it, training_loss=0.100]
# Epoch 3:  85%|████████▌ | 528/619 [12:02<02:04,  1.37s/it, training_loss=0.100]
# Epoch 3:  85%|████████▌ | 528/619 [12:03<02:04,  1.37s/it, training_loss=0.078]
# Epoch 3:  85%|████████▌ | 529/619 [12:03<02:03,  1.37s/it, training_loss=0.078]
# Epoch 3:  85%|████████▌ | 529/619 [12:05<02:03,  1.37s/it, training_loss=0.027]
# Epoch 3:  86%|████████▌ | 530/619 [12:05<02:02,  1.37s/it, training_loss=0.027]
# Epoch 3:  86%|████████▌ | 530/619 [12:06<02:02,  1.37s/it, training_loss=0.164]
# Epoch 3:  86%|████████▌ | 531/619 [12:06<02:00,  1.37s/it, training_loss=0.164]
# Epoch 3:  86%|████████▌ | 531/619 [12:07<02:00,  1.37s/it, training_loss=0.031]
# Epoch 3:  86%|████████▌ | 532/619 [12:07<01:59,  1.37s/it, training_loss=0.031]
# Epoch 3:  86%|████████▌ | 532/619 [12:09<01:59,  1.37s/it, training_loss=0.011]
# Epoch 3:  86%|████████▌ | 533/619 [12:09<01:58,  1.37s/it, training_loss=0.011]
# Epoch 3:  86%|████████▌ | 533/619 [12:10<01:58,  1.37s/it, training_loss=0.071]
# Epoch 3:  86%|████████▋ | 534/619 [12:10<01:56,  1.38s/it, training_loss=0.071]
# Epoch 3:  86%|████████▋ | 534/619 [12:11<01:56,  1.38s/it, training_loss=0.114]
# Epoch 3:  86%|████████▋ | 535/619 [12:11<01:55,  1.37s/it, training_loss=0.114]
# Epoch 3:  86%|████████▋ | 535/619 [12:13<01:55,  1.37s/it, training_loss=0.059]
# Epoch 3:  87%|████████▋ | 536/619 [12:13<01:53,  1.37s/it, training_loss=0.059]
# Epoch 3:  87%|████████▋ | 536/619 [12:14<01:53,  1.37s/it, training_loss=0.105]
# Epoch 3:  87%|████████▋ | 537/619 [12:14<01:52,  1.37s/it, training_loss=0.105]
# Epoch 3:  87%|████████▋ | 537/619 [12:16<01:52,  1.37s/it, training_loss=0.140]
# Epoch 3:  87%|████████▋ | 538/619 [12:16<01:50,  1.37s/it, training_loss=0.140]
# Epoch 3:  87%|████████▋ | 538/619 [12:17<01:50,  1.37s/it, training_loss=0.090]
# Epoch 3:  87%|████████▋ | 539/619 [12:17<01:49,  1.37s/it, training_loss=0.090]
# Epoch 3:  87%|████████▋ | 539/619 [12:18<01:49,  1.37s/it, training_loss=0.010]
# Epoch 3:  87%|████████▋ | 540/619 [12:18<01:48,  1.37s/it, training_loss=0.010]
# Epoch 3:  87%|████████▋ | 540/619 [12:20<01:48,  1.37s/it, training_loss=0.028]
# Epoch 3:  87%|████████▋ | 541/619 [12:20<01:46,  1.37s/it, training_loss=0.028]
# Epoch 3:  87%|████████▋ | 541/619 [12:21<01:46,  1.37s/it, training_loss=0.042]
# Epoch 3:  88%|████████▊ | 542/619 [12:21<01:45,  1.37s/it, training_loss=0.042]
# Epoch 3:  88%|████████▊ | 542/619 [12:22<01:45,  1.37s/it, training_loss=0.040]
# Epoch 3:  88%|████████▊ | 543/619 [12:22<01:44,  1.37s/it, training_loss=0.040]
# Epoch 3:  88%|████████▊ | 543/619 [12:24<01:44,  1.37s/it, training_loss=0.054]
# Epoch 3:  88%|████████▊ | 544/619 [12:24<01:42,  1.36s/it, training_loss=0.054]
# Epoch 3:  88%|████████▊ | 544/619 [12:25<01:42,  1.36s/it, training_loss=0.020]
# Epoch 3:  88%|████████▊ | 545/619 [12:25<01:40,  1.36s/it, training_loss=0.020]
# Epoch 3:  88%|████████▊ | 545/619 [12:26<01:40,  1.36s/it, training_loss=0.046]
# Epoch 3:  88%|████████▊ | 546/619 [12:26<01:39,  1.36s/it, training_loss=0.046]
# Epoch 3:  88%|████████▊ | 546/619 [12:28<01:39,  1.36s/it, training_loss=0.048]
# Epoch 3:  88%|████████▊ | 547/619 [12:28<01:38,  1.36s/it, training_loss=0.048]
# Epoch 3:  88%|████████▊ | 547/619 [12:29<01:38,  1.36s/it, training_loss=0.138]
# Epoch 3:  89%|████████▊ | 548/619 [12:29<01:36,  1.36s/it, training_loss=0.138]
# Epoch 3:  89%|████████▊ | 548/619 [12:31<01:36,  1.36s/it, training_loss=0.045]
# Epoch 3:  89%|████████▊ | 549/619 [12:31<01:35,  1.36s/it, training_loss=0.045]
# Epoch 3:  89%|████████▊ | 549/619 [12:32<01:35,  1.36s/it, training_loss=0.052]
# Epoch 3:  89%|████████▉ | 550/619 [12:32<01:33,  1.36s/it, training_loss=0.052]
# Epoch 3:  89%|████████▉ | 550/619 [12:33<01:33,  1.36s/it, training_loss=0.089]
# Epoch 3:  89%|████████▉ | 551/619 [12:33<01:32,  1.36s/it, training_loss=0.089]
# Epoch 3:  89%|████████▉ | 551/619 [12:35<01:32,  1.36s/it, training_loss=0.158]
# Epoch 3:  89%|████████▉ | 552/619 [12:35<01:31,  1.36s/it, training_loss=0.158]
# Epoch 3:  89%|████████▉ | 552/619 [12:36<01:31,  1.36s/it, training_loss=0.069]
# Epoch 3:  89%|████████▉ | 553/619 [12:36<01:30,  1.36s/it, training_loss=0.069]
# Epoch 3:  89%|████████▉ | 553/619 [12:37<01:30,  1.36s/it, training_loss=0.122]
# Epoch 3:  89%|████████▉ | 554/619 [12:37<01:28,  1.36s/it, training_loss=0.122]
# Epoch 3:  89%|████████▉ | 554/619 [12:39<01:28,  1.36s/it, training_loss=0.131]
# Epoch 3:  90%|████████▉ | 555/619 [12:39<01:27,  1.37s/it, training_loss=0.131]
# Epoch 3:  90%|████████▉ | 555/619 [12:40<01:27,  1.37s/it, training_loss=0.078]
# Epoch 3:  90%|████████▉ | 556/619 [12:40<01:26,  1.37s/it, training_loss=0.078]
# Epoch 3:  90%|████████▉ | 556/619 [12:41<01:26,  1.37s/it, training_loss=0.049]
# Epoch 3:  90%|████████▉ | 557/619 [12:42<01:24,  1.37s/it, training_loss=0.049]
# Epoch 3:  90%|████████▉ | 557/619 [12:43<01:24,  1.37s/it, training_loss=0.038]
# Epoch 3:  90%|█████████ | 558/619 [12:43<01:23,  1.37s/it, training_loss=0.038]
# Epoch 3:  90%|█████████ | 558/619 [12:44<01:23,  1.37s/it, training_loss=0.174]
# Epoch 3:  90%|█████████ | 559/619 [12:44<01:21,  1.37s/it, training_loss=0.174]
# Epoch 3:  90%|█████████ | 559/619 [12:46<01:21,  1.37s/it, training_loss=0.023]
# Epoch 3:  90%|█████████ | 560/619 [12:46<01:20,  1.37s/it, training_loss=0.023]
# Epoch 3:  90%|█████████ | 560/619 [12:47<01:20,  1.37s/it, training_loss=0.023]
# Epoch 3:  91%|█████████ | 561/619 [12:47<01:19,  1.37s/it, training_loss=0.023]
# Epoch 3:  91%|█████████ | 561/619 [12:48<01:19,  1.37s/it, training_loss=0.049]
# Epoch 3:  91%|█████████ | 562/619 [12:48<01:17,  1.37s/it, training_loss=0.049]
# Epoch 3:  91%|█████████ | 562/619 [12:50<01:17,  1.37s/it, training_loss=0.040]
# Epoch 3:  91%|█████████ | 563/619 [12:50<01:16,  1.37s/it, training_loss=0.040]
# Epoch 3:  91%|█████████ | 563/619 [12:51<01:16,  1.37s/it, training_loss=0.054]
# Epoch 3:  91%|█████████ | 564/619 [12:51<01:15,  1.37s/it, training_loss=0.054]
# Epoch 3:  91%|█████████ | 564/619 [12:52<01:15,  1.37s/it, training_loss=0.058]
# Epoch 3:  91%|█████████▏| 565/619 [12:52<01:14,  1.37s/it, training_loss=0.058]
# Epoch 3:  91%|█████████▏| 565/619 [12:54<01:14,  1.37s/it, training_loss=0.068]
# Epoch 3:  91%|█████████▏| 566/619 [12:54<01:12,  1.37s/it, training_loss=0.068]
# Epoch 3:  91%|█████████▏| 566/619 [12:55<01:12,  1.37s/it, training_loss=0.088]
# Epoch 3:  92%|█████████▏| 567/619 [12:55<01:11,  1.37s/it, training_loss=0.088]
# Epoch 3:  92%|█████████▏| 567/619 [12:57<01:11,  1.37s/it, training_loss=0.010]
# Epoch 3:  92%|█████████▏| 568/619 [12:57<01:09,  1.37s/it, training_loss=0.010]
# Epoch 3:  92%|█████████▏| 568/619 [12:58<01:09,  1.37s/it, training_loss=0.112]
# Epoch 3:  92%|█████████▏| 569/619 [12:58<01:08,  1.37s/it, training_loss=0.112]
# Epoch 3:  92%|█████████▏| 569/619 [12:59<01:08,  1.37s/it, training_loss=0.012]
# Epoch 3:  92%|█████████▏| 570/619 [12:59<01:07,  1.37s/it, training_loss=0.012]
# Epoch 3:  92%|█████████▏| 570/619 [13:01<01:07,  1.37s/it, training_loss=0.069]
# Epoch 3:  92%|█████████▏| 571/619 [13:01<01:06,  1.38s/it, training_loss=0.069]
# Epoch 3:  92%|█████████▏| 571/619 [13:02<01:06,  1.38s/it, training_loss=0.064]
# Epoch 3:  92%|█████████▏| 572/619 [13:02<01:04,  1.37s/it, training_loss=0.064]
# Epoch 3:  92%|█████████▏| 572/619 [13:03<01:04,  1.37s/it, training_loss=0.160]
# Epoch 3:  93%|█████████▎| 573/619 [13:03<01:03,  1.37s/it, training_loss=0.160]
# Epoch 3:  93%|█████████▎| 573/619 [13:05<01:03,  1.37s/it, training_loss=0.065]
# Epoch 3:  93%|█████████▎| 574/619 [13:05<01:01,  1.37s/it, training_loss=0.065]
# Epoch 3:  93%|█████████▎| 574/619 [13:06<01:01,  1.37s/it, training_loss=0.014]
# Epoch 3:  93%|█████████▎| 575/619 [13:06<01:00,  1.37s/it, training_loss=0.014]
# Epoch 3:  93%|█████████▎| 575/619 [13:08<01:00,  1.37s/it, training_loss=0.003]
# Epoch 3:  93%|█████████▎| 576/619 [13:08<00:58,  1.37s/it, training_loss=0.003]
# Epoch 3:  93%|█████████▎| 576/619 [13:09<00:58,  1.37s/it, training_loss=0.068]
# Epoch 3:  93%|█████████▎| 577/619 [13:09<00:57,  1.36s/it, training_loss=0.068]
# Epoch 3:  93%|█████████▎| 577/619 [13:10<00:57,  1.36s/it, training_loss=0.111]
# Epoch 3:  93%|█████████▎| 578/619 [13:10<00:55,  1.36s/it, training_loss=0.111]
# Epoch 3:  93%|█████████▎| 578/619 [13:12<00:55,  1.36s/it, training_loss=0.139]
# Epoch 3:  94%|█████████▎| 579/619 [13:12<00:54,  1.36s/it, training_loss=0.139]
# Epoch 3:  94%|█████████▎| 579/619 [13:13<00:54,  1.36s/it, training_loss=0.021]
# Epoch 3:  94%|█████████▎| 580/619 [13:13<00:53,  1.36s/it, training_loss=0.021]
# Epoch 3:  94%|█████████▎| 580/619 [13:14<00:53,  1.36s/it, training_loss=0.173]
# Epoch 3:  94%|█████████▍| 581/619 [13:14<00:51,  1.37s/it, training_loss=0.173]
# Epoch 3:  94%|█████████▍| 581/619 [13:16<00:51,  1.37s/it, training_loss=0.076]
# Epoch 3:  94%|█████████▍| 582/619 [13:16<00:50,  1.37s/it, training_loss=0.076]
# Epoch 3:  94%|█████████▍| 582/619 [13:17<00:50,  1.37s/it, training_loss=0.084]
# Epoch 3:  94%|█████████▍| 583/619 [13:17<00:49,  1.38s/it, training_loss=0.084]
# Epoch 3:  94%|█████████▍| 583/619 [13:18<00:49,  1.38s/it, training_loss=0.190]
# Epoch 3:  94%|█████████▍| 584/619 [13:19<00:48,  1.37s/it, training_loss=0.190]
# Epoch 3:  94%|█████████▍| 584/619 [13:20<00:48,  1.37s/it, training_loss=0.075]
# Epoch 3:  95%|█████████▍| 585/619 [13:20<00:46,  1.37s/it, training_loss=0.075]
# Epoch 3:  95%|█████████▍| 585/619 [13:21<00:46,  1.37s/it, training_loss=0.066]
# Epoch 3:  95%|█████████▍| 586/619 [13:21<00:45,  1.37s/it, training_loss=0.066]
# Epoch 3:  95%|█████████▍| 586/619 [13:23<00:45,  1.37s/it, training_loss=0.098]
# Epoch 3:  95%|█████████▍| 587/619 [13:23<00:43,  1.37s/it, training_loss=0.098]
# Epoch 3:  95%|█████████▍| 587/619 [13:24<00:43,  1.37s/it, training_loss=0.037]
# Epoch 3:  95%|█████████▍| 588/619 [13:24<00:42,  1.37s/it, training_loss=0.037]
# Epoch 3:  95%|█████████▍| 588/619 [13:25<00:42,  1.37s/it, training_loss=0.030]
# Epoch 3:  95%|█████████▌| 589/619 [13:25<00:41,  1.37s/it, training_loss=0.030]
# Epoch 3:  95%|█████████▌| 589/619 [13:27<00:41,  1.37s/it, training_loss=0.069]
# Epoch 3:  95%|█████████▌| 590/619 [13:27<00:39,  1.36s/it, training_loss=0.069]
# Epoch 3:  95%|█████████▌| 590/619 [13:28<00:39,  1.36s/it, training_loss=0.181]
# Epoch 3:  95%|█████████▌| 591/619 [13:28<00:38,  1.36s/it, training_loss=0.181]
# Epoch 3:  95%|█████████▌| 591/619 [13:29<00:38,  1.36s/it, training_loss=0.083]
# Epoch 3:  96%|█████████▌| 592/619 [13:29<00:36,  1.36s/it, training_loss=0.083]
# Epoch 3:  96%|█████████▌| 592/619 [13:31<00:36,  1.36s/it, training_loss=0.049]
# Epoch 3:  96%|█████████▌| 593/619 [13:31<00:35,  1.37s/it, training_loss=0.049]
# Epoch 3:  96%|█████████▌| 593/619 [13:32<00:35,  1.37s/it, training_loss=0.066]
# Epoch 3:  96%|█████████▌| 594/619 [13:32<00:34,  1.37s/it, training_loss=0.066]
# Epoch 3:  96%|█████████▌| 594/619 [13:34<00:34,  1.37s/it, training_loss=0.067]
# Epoch 3:  96%|█████████▌| 595/619 [13:34<00:32,  1.37s/it, training_loss=0.067]
# Epoch 3:  96%|█████████▌| 595/619 [13:35<00:32,  1.37s/it, training_loss=0.116]
# Epoch 3:  96%|█████████▋| 596/619 [13:35<00:31,  1.36s/it, training_loss=0.116]
# Epoch 3:  96%|█████████▋| 596/619 [13:36<00:31,  1.36s/it, training_loss=0.021]
# Epoch 3:  96%|█████████▋| 597/619 [13:36<00:30,  1.36s/it, training_loss=0.021]
# Epoch 3:  96%|█████████▋| 597/619 [13:38<00:30,  1.36s/it, training_loss=0.078]
# Epoch 3:  97%|█████████▋| 598/619 [13:38<00:28,  1.37s/it, training_loss=0.078]
# Epoch 3:  97%|█████████▋| 598/619 [13:39<00:28,  1.37s/it, training_loss=0.058]
# Epoch 3:  97%|█████████▋| 599/619 [13:39<00:27,  1.37s/it, training_loss=0.058]
# Epoch 3:  97%|█████████▋| 599/619 [13:40<00:27,  1.37s/it, training_loss=0.125]
# Epoch 3:  97%|█████████▋| 600/619 [13:40<00:26,  1.37s/it, training_loss=0.125]
# Epoch 3:  97%|█████████▋| 600/619 [13:42<00:26,  1.37s/it, training_loss=0.073]
# Epoch 3:  97%|█████████▋| 601/619 [13:42<00:24,  1.37s/it, training_loss=0.073]
# Epoch 3:  97%|█████████▋| 601/619 [13:43<00:24,  1.37s/it, training_loss=0.235]
# Epoch 3:  97%|█████████▋| 602/619 [13:43<00:23,  1.37s/it, training_loss=0.235]
# Epoch 3:  97%|█████████▋| 602/619 [13:44<00:23,  1.37s/it, training_loss=0.102]
# Epoch 3:  97%|█████████▋| 603/619 [13:44<00:21,  1.37s/it, training_loss=0.102]
# Epoch 3:  97%|█████████▋| 603/619 [13:46<00:21,  1.37s/it, training_loss=0.044]
# Epoch 3:  98%|█████████▊| 604/619 [13:46<00:20,  1.37s/it, training_loss=0.044]
# Epoch 3:  98%|█████████▊| 604/619 [13:47<00:20,  1.37s/it, training_loss=0.088]
# Epoch 3:  98%|█████████▊| 605/619 [13:47<00:19,  1.37s/it, training_loss=0.088]
# Epoch 3:  98%|█████████▊| 605/619 [13:49<00:19,  1.37s/it, training_loss=0.096]
# Epoch 3:  98%|█████████▊| 606/619 [13:49<00:17,  1.37s/it, training_loss=0.096]
# Epoch 3:  98%|█████████▊| 606/619 [13:50<00:17,  1.37s/it, training_loss=0.038]
# Epoch 3:  98%|█████████▊| 607/619 [13:50<00:16,  1.37s/it, training_loss=0.038]
# Epoch 3:  98%|█████████▊| 607/619 [13:51<00:16,  1.37s/it, training_loss=0.023]
# Epoch 3:  98%|█████████▊| 608/619 [13:51<00:15,  1.37s/it, training_loss=0.023]
# Epoch 3:  98%|█████████▊| 608/619 [13:53<00:15,  1.37s/it, training_loss=0.155]
# Epoch 3:  98%|█████████▊| 609/619 [13:53<00:13,  1.38s/it, training_loss=0.155]
# Epoch 3:  98%|█████████▊| 609/619 [13:54<00:13,  1.38s/it, training_loss=0.029]
# Epoch 3:  99%|█████████▊| 610/619 [13:54<00:12,  1.37s/it, training_loss=0.029]
# Epoch 3:  99%|█████████▊| 610/619 [13:55<00:12,  1.37s/it, training_loss=0.032]
# Epoch 3:  99%|█████████▊| 611/619 [13:55<00:10,  1.37s/it, training_loss=0.032]
# Epoch 3:  99%|█████████▊| 611/619 [13:57<00:10,  1.37s/it, training_loss=0.057]
# Epoch 3:  99%|█████████▉| 612/619 [13:57<00:09,  1.37s/it, training_loss=0.057]
# Epoch 3:  99%|█████████▉| 612/619 [13:58<00:09,  1.37s/it, training_loss=0.064]
# Epoch 3:  99%|█████████▉| 613/619 [13:58<00:08,  1.37s/it, training_loss=0.064]
# Epoch 3:  99%|█████████▉| 613/619 [14:00<00:08,  1.37s/it, training_loss=0.058]
# Epoch 3:  99%|█████████▉| 614/619 [14:00<00:06,  1.37s/it, training_loss=0.058]
# Epoch 3:  99%|█████████▉| 614/619 [14:01<00:06,  1.37s/it, training_loss=0.033]
# Epoch 3:  99%|█████████▉| 615/619 [14:01<00:05,  1.37s/it, training_loss=0.033]
# Epoch 3:  99%|█████████▉| 615/619 [14:02<00:05,  1.37s/it, training_loss=0.036]
# Epoch 3: 100%|█████████▉| 616/619 [14:02<00:04,  1.37s/it, training_loss=0.036]
# Epoch 3: 100%|█████████▉| 616/619 [14:04<00:04,  1.37s/it, training_loss=0.008]
# Epoch 3: 100%|█████████▉| 617/619 [14:04<00:02,  1.37s/it, training_loss=0.008]
# Epoch 3: 100%|█████████▉| 617/619 [14:05<00:02,  1.37s/it, training_loss=0.140]
# Epoch 3: 100%|█████████▉| 618/619 [14:05<00:01,  1.37s/it, training_loss=0.140]
# Epoch 3: 100%|█████████▉| 618/619 [14:06<00:01,  1.37s/it, training_loss=0.009]
# Epoch 3: 100%|██████████| 619/619 [14:06<00:00,  1.21s/it, training_loss=0.009]
#  67%|██████▋   | 2/3 [45:58<15:53, 953.11s/it]
# Epoch 3
# Training loss: 0.20104253273126285
# 100%|██████████| 3/3 [47:40<00:00, 953.47s/it]
# Validation loss: 0.4803624086729858
# F1 Score (Weighted): 0.8632209842144002

# %%
accuracy_per_class(predictions, true_vals)
# Out:
# Class: Yes
# Accuracy: 3014/3326 = 0.9061936259771497
#
# Class: No
# Accuracy: 2178/2566 = 0.8487918939984411
#
# Class: In the middle, neither yes nor no
# Accuracy: 53/190 = 0.2789473684210526
#
# Class: Yes, subject to some conditions
# Accuracy: 471/517 = 0.9110251450676983

# %%
print('Dev Accuracy:', end = ' ')
flat_accuracy(predictions, true_vals)
# Out:
# Dev Accuracy:
# 0.8661918472495833

# %%
encoded_data_test = tokenizer.batch_encode_plus(
    df[df.data_type=='test'].YN_r.values, 
    add_special_tokens=True, 
    return_attention_mask=True, 
    pad_to_max_length=True, 
    max_length=256, 
    return_tensors='pt'
)

input_ids_test = encoded_data_test['input_ids']
attention_masks_test = encoded_data_test['attention_mask']
labels_test = torch.tensor(df[df.data_type=='test'].relaxed.values)

dataset_test = TensorDataset(input_ids_test, attention_masks_test, labels_test)

dataloader_test = DataLoader(dataset_test, 
                                   sampler=SequentialSampler(dataset_test), 
                                   batch_size=batch_size)

test_loss, test_predictions, test_true_vals = evaluate(dataloader_test)
test_f1 = f1_score_func(test_predictions, test_true_vals)

# %%
accuracy_per_class(test_predictions, test_true_vals)
print('Test Accuracy:', end = ' ')
flat_accuracy(test_predictions, test_true_vals)
# Out:
# Class: Yes
# Accuracy: 3052/3326 = 0.9176187612748046
#
# Class: No
# Accuracy: 2144/2567 = 0.835216205687573
#
# Class: In the middle, neither yes nor no
# Accuracy: 57/190 = 0.3
#
# Class: Yes, subject to some conditions
# Accuracy: 454/516 = 0.8798449612403101
#
# Test Accuracy:
# 0.8648280042430672
